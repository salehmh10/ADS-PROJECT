# %% [markdown]
# # 0. Stage Objective
#
# This Notebook reports the frozen Stage 5B Validation-only ensemble work. It does not train models or open Test artifacts.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
print('Stage 5B uses saved Validation artifacts only.')
# Out:
# Stage 5B uses saved Validation artifacts only.

# %% [markdown]
# # 1. Imports and Configuration
#
# Import small reporting tools and show the cache-only execution mode.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
from pathlib import Path
import json, os
import pandas as pd
ROOT=Path.cwd()
CACHE_ONLY=os.environ.get('STAGE5B_CACHE_ONLY','0')=='1'
print({'cache_only':CACHE_ONLY,'model_fit_calls':0,'preprocessing_fit_calls':0,'prediction_generation_calls':0,'source_data_loads':0,'test_artifact_loads':0})
# Out:
# {'cache_only': True, 'model_fit_calls': 0, 'preprocessing_fit_calls': 0, 'prediction_generation_calls': 0, 'source_data_loads': 0, 'test_artifact_loads': 0}

# %% [markdown]
# # 2. Stage 5A Verification
#
# Stage 5A must remain complete with its documented governance exception.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
display(pd.DataFrame([json.loads((ROOT/'artifacts/reports/stage5a_verification.json').read_text(encoding='utf-8'))])[['status','literal_zero_test_loading','refit_required']])
# Out:
#                                       status  literal_zero_test_loading  \
# 0  PASS_WITH_DOCUMENTED_GOVERNANCE_EXCEPTION                      False
#
#    refit_required
# 0           False

# %% [markdown]
# # 3. Governance and No-Test Rule
#
# The historical incident stays visible. Stage 5B itself uses no source or Test data.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
g=json.loads((ROOT/'artifacts/reports/stage5a2_governance_adjudication.json').read_text(encoding='utf-8')); print({'stage5a_exception':g['human_adjudication_result'],'stage5b_source_loads':0,'stage5b_test_artifact_loads':0})
# Out:
# {'stage5a_exception': 'accepted_procedural_test_row_materialization_without_demonstrated_statistical_leakage', 'stage5b_source_loads': 0, 'stage5b_test_artifact_loads': 0}

# %% [markdown]
# # 4. Protected File Baseline
#
# The baseline protects prior notebooks, frozen predictions, models, bundles, splits, and Registry history.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
b=json.loads((ROOT/'artifacts/manifests/stage5/stage5b_protected_hashes_before.json').read_text(encoding='utf-8')); print({'status':b['status'],'protected_files':b['protected_file_count']})
# Out:
# {'status': 'PASS', 'protected_files': 49}

# %% [markdown]
# # 5. Stage 5A Deep Handoff
#
# The frozen RealMLP raw prediction handoff supplies both sensitive modes.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
h=json.loads((ROOT/'artifacts/manifests/stage5/stage5a2_ensemble_handoff.json').read_text(encoding='utf-8')); display(pd.DataFrame(h['items'])[['sensitive_mode','validation_candidate_id','validation_mae','validation_rmse']])
# Out:
#       sensitive_mode                  validation_candidate_id  validation_mae  \
# 0  without_sensitive                stage5a2__realmlp__frozen       63.923004
# 1     with_sensitive  stage5a2__realmlp__core__with_sensitive       63.446909
#
#    validation_rmse
# 0       132.730409
# 1       129.146704

# %% [markdown]
# # 6. Stage 4 Boosting Validation Inputs
#
# Only final saved Validation predictions enter this Stage.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
a=json.loads((ROOT/'artifacts/reports/stage5b_input_alignment_report.json').read_text(encoding='utf-8')); display(pd.DataFrame(a['files'])[['sensitive_mode','model_family','row_count','candidate_id']])
# Out:
#       sensitive_mode model_family  row_count  \
# 0  without_sensitive         deep      25000
# 1  without_sensitive     catboost      25000
# 2  without_sensitive     lightgbm      25000
# 3  without_sensitive      xgboost      25000
# 4     with_sensitive         deep      25000
# 5     with_sensitive     catboost      25000
# 6     with_sensitive     lightgbm      25000
# 7     with_sensitive      xgboost      25000
#
#                                         candidate_id
# 0                          stage5a2__realmlp__frozen
# 1  stage4de__final_controlled__final_controlled_w...
# 2        stage4g__final_tuning__candidate_c_flexible
# 3                         stage4j__tuning_a_baseline
# 4            stage5a2__realmlp__core__with_sensitive
# 5  stage4de__final_controlled__final_controlled_w...
# 6  stage4h__final_selection_validation__with_sens...
# 7                      stage4k__sensitive_validation

# %% [markdown]
# # 7. Frozen Boosting Anchors
#
# The two anchors were fixed before target parsing.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
f=json.loads((ROOT/'artifacts/reports/stage5b_preensemble_freeze.json').read_text(encoding='utf-8')); print({'anchors':f['allowed_boosting_anchors'],'blend_weights':f['frozen_stage4_boosting_blend_weights'],'best_individual':f['best_individual_boosting_family']})
# Out:
# {'anchors': ['frozen_stage4_boosting_blend', 'catboost'], 'blend_weights': {'catboost': 0.6, 'lightgbm': 0.2, 'xgboost': 0.2}, 'best_individual': 'catboost'}

# %% [markdown]
# # 8. Pre-Ensemble Freeze
#
# The grid, thresholds, tie rules, and Bootstrap settings are immutable.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
print({'freeze_status':f['status'],'grid':f['deep_weight_grid'],'bootstrap':f['bootstrap_settings']})
# Out:
# {'freeze_status': 'PASS', 'grid': [0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5], 'bootstrap': {'error_scale': 'original target absolute error', 'paired_indices': True, 'pass_rule': 'upper 95 percent percentile bound below zero', 'resamples': 500, 'seed': 42}}

# %% [markdown]
# # 9. Prediction Alignment
#
# Every file has the same 25,000 Validation rows and target values.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
print({'status':a['status'],'files':a['prediction_file_count'],'rows':a['expected_rows'],'row_hash':a['validation_row_id_hash'],'target_hash':a['target_hash']})
# Out:
# {'status': 'PASS', 'files': 8, 'rows': 25000, 'row_hash': '5a47f42c454ab185f70a3cd2b637c55c9e4fa0804c59b2ebe25ac781c44fc26b', 'target_hash': 'ddb115eee1697b87e3d709119447571a0493c62f525b8c05072e51fbabe19668'}

# %% [markdown]
# # 10. Component Validation Metrics
#
# Component metrics use original target units.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
components=pd.read_csv(ROOT/'artifacts/results/stage5/deep_boosting_ensemble/stage5b_component_metrics.csv'); display(components[['component','mae','rmse','rmsle','r_squared','top_decile_mae']])
# Out:
#                       component        mae        rmse     rmsle  r_squared  \
# 0                          deep  63.923004  132.730409  0.400021   0.681960
# 1  frozen_stage4_boosting_blend  63.130898  129.609287  0.390459   0.696742
# 2                      catboost  63.376185  130.272187  0.390619   0.693632
#
#    top_decile_mae
# 0      201.976265
# 1      202.827483
# 2      202.609686

# %% [markdown]
# # 11. Prediction and Residual Diversity
#
# Diversity can help an average, but high error correlation limits the benefit.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
d=pd.read_csv(ROOT/'artifacts/results/stage5/deep_boosting_ensemble/stage5b_diversity_diagnostics.csv'); display(d.loc[d['scope']=='overall',['anchor','pearson_prediction_correlation','pearson_residual_correlation','mean_absolute_prediction_disagreement','deep_lower_absolute_error_percent','boosting_lower_absolute_error_percent']])
# Out:
#                           anchor  pearson_prediction_correlation  \
# 0   frozen_stage4_boosting_blend                        0.982013
# 11                      catboost                        0.981291
#
#     pearson_residual_correlation  mean_absolute_prediction_disagreement  \
# 0                       0.966059                              17.448698
# 11                      0.964550                              18.024307
#
#     deep_lower_absolute_error_percent  boosting_lower_absolute_error_percent
# 0                              48.204                                 51.796
# 11                             48.268                                 51.732

# %% [markdown]
# # 12. Deep Weight Grid
#
# Exactly 22 frozen non-negative weighted combinations were evaluated.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
grid=pd.read_csv(ROOT/'artifacts/results/stage5/deep_boosting_ensemble/stage5b_weight_grid_results.csv'); print({'rows':len(grid),'anchors':grid['boosting_anchor'].nunique(),'deep_weights':sorted(grid['deep_weight'].unique().tolist())})
# Out:
# {'rows': 22, 'anchors': 2, 'deep_weights': [0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]}

# %% [markdown]
# # 13. Anchor-Specific Winners
#
# Each anchor has one winner under the frozen MAE tie rule.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
display(pd.read_csv(ROOT/'artifacts/results/stage5/deep_boosting_ensemble/stage5b_anchor_winners.csv')[['boosting_anchor','deep_weight','boost_weight','mae','rmse','top_decile_mae']])
# Out:
#                 boosting_anchor  deep_weight  boost_weight        mae  \
# 0  frozen_stage4_boosting_blend          0.5           0.5  62.853024
# 1                      catboost          0.5           0.5  62.939832
#
#          rmse  top_decile_mae
# 0  130.057386      200.349100
# 1  130.336332      200.224067

# %% [markdown]
# # 14. Provisional Ensemble Selection
#
# The provisional winner was selected with non-sensitive Validation evidence only.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
p=json.loads((ROOT/'artifacts/results/stage5/deep_boosting_ensemble/stage5b_provisional_winner.json').read_text(encoding='utf-8')); print(p)
# Out:
# {'boost_weight': 0.5, 'boosting_anchor': 'frozen_stage4_boosting_blend', 'candidate_id': 'stage5b__frozen_stage4_boosting_blend__deep-weight-0.50', 'created_at_utc': '2026-07-15T22:32:36.523193+00:00', 'deep_weight': 0.5, 'selection_mode': 'without_sensitive', 'stage_id': 'stage5b', 'status': 'PROVISIONAL_CONFIRMED_UNCHANGED_AFTER_REVIEW_REPORTING_FIX', 'tie_rule_applied': 'MAE within 0.10 percent then top-decile MAE, RMSE, Deep weight, anchor simplicity'}

# %% [markdown]
# # 15. Paired Bootstrap Confirmation
#
# Paired resampling compares the attempted ensemble with its stronger component.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
bs=json.loads((ROOT/'artifacts/results/stage5/deep_boosting_ensemble/stage5b_paired_bootstrap_summary.json').read_text(encoding='utf-8')); print({k:bs[k] for k in ['point_mae_difference','ci95_lower','ci95_upper','win_proportion','confirmation_pass']})
# Out:
# {'point_mae_difference': -0.2778740988612469, 'ci95_lower': -0.47107788971675446, 'ci95_upper': -0.06945292104237374, 'win_proportion': 0.994, 'confirmation_pass': True}

# %% [markdown]
# # 16. Ensemble Acceptance Decision
#
# The fixed main and tail Gates are applied without adjustment.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
decision=json.loads((ROOT/'artifacts/results/stage5/deep_boosting_ensemble/stage5b_ensemble_decision.json').read_text(encoding='utf-8')); print({'ensemble_status':decision['ensemble_status'],'acceptance_path':decision['acceptance_path'],'failed_conditions':decision['failed_acceptance_conditions']})
# Out:
# {'ensemble_status': 'rejected', 'acceptance_path': None, 'failed_conditions': ['main:rmse_worsening_at_most_0_25_percent', 'tail:rmse_worsening_at_most_0_25_percent']}

# %% [markdown]
# # 17. Sensitive-Mode Transfer
#
# Sensitive results are an accuracy diagnostic only and did not select weights.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
display(pd.read_csv(ROOT/'artifacts/results/stage5/deep_boosting_ensemble/stage5b_sensitive_diagnostic.csv'))
# Out:
#                  metric  without_sensitive  with_sensitive  \
# 0                   mae          62.853024       62.274938
# 1                  rmse         130.057386      128.287474
# 2                 rmsle           0.389195        0.386442
# 3             r_squared           0.694641        0.702896
# 4        top_decile_mae         200.349100      196.772419
# 5  top_five_percent_mae         291.915687      285.772350
#
#    difference_with_minus_without  difference_from_sensitive_deep  \
# 0                      -0.578086                       -1.171971
# 1                      -1.769912                       -0.859230
# 2                      -0.002753                       -0.008262
# 3                       0.008255                        0.003993
# 4                      -3.576681                       -0.412202
# 5                      -6.143337                        2.000620
#
#    difference_from_sensitive_boosting_anchor ensemble_status  \
# ...

# %% [markdown]
# # 18. Frozen Ensemble Specification
#
# The saved JSON is a prediction-level definition, not a stacking estimator.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
e=json.loads((ROOT/'artifacts/results/stage5/deep_boosting_ensemble/stage5b_frozen_ensemble.json').read_text(encoding='utf-8')); print({'status':e['status'],'ensemble_status':e['ensemble_status'],'anchor':e['boosting_anchor'],'deep_weight':e['deep_weight'],'serialized_stacking_estimator':e['serialized_stacking_estimator']})
# Out:
# {'status': 'PASS', 'ensemble_status': 'rejected', 'anchor': 'frozen_stage4_boosting_blend', 'deep_weight': 0.5, 'serialized_stacking_estimator': False}

# %% [markdown]
# # 19. Stage 5C Evaluation Handoff
#
# Stage 5C receives only frozen eligible Candidates and cannot change weights.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
handoff=json.loads((ROOT/'artifacts/manifests/stage5/stage5b_evaluation_handoff.json').read_text(encoding='utf-8')); print({'status':handoff['status'],'deep_eligible':handoff['deep_evaluation_eligible'],'ensemble_eligible':handoff['ensemble_evaluation_eligible'],'weights_immutable':handoff['stage5c_must_not_change_weights']})
# Out:
# {'status': 'PASS', 'deep_eligible': True, 'ensemble_eligible': False, 'weights_immutable': True}

# %% [markdown]
# # 20. Validation Visualizations
#
# The figure set uses Validation evidence only.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
v=json.loads((ROOT/'artifacts/manifests/stage5/stage5b_visualization_manifest.json').read_text(encoding='utf-8')); print({'status':v['status'],'figure_count':v['figure_count'],'validation_only':v['validation_only']})
# Out:
# {'status': 'PASS', 'figure_count': 12, 'validation_only': True}

# %% [markdown]
# # 21. Stage 5B Artifact Summary
#
# The artifact list is complete and uses deterministic Stage 5B paths.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
paths=[ROOT/'artifacts/reports/stage5b_preensemble_freeze.json',ROOT/'artifacts/results/stage5/deep_boosting_ensemble/stage5b_weight_grid_results.csv',ROOT/'artifacts/results/stage5/deep_boosting_ensemble/stage5b_frozen_ensemble.json',ROOT/'artifacts/manifests/stage5/stage5b_evaluation_handoff.json']; display(pd.DataFrame({'path':[str(x.relative_to(ROOT)) for x in paths],'exists':[x.exists() for x in paths]}))
# Out:
#                                                 path  exists
# 0  artifacts\reports\stage5b_preensemble_freeze.json    True
# 1  artifacts\results\stage5\deep_boosting_ensembl...    True
# 2  artifacts\results\stage5\deep_boosting_ensembl...    True
# 3  artifacts\manifests\stage5\stage5b_evaluation_...    True

# %% [markdown]
# # 22. Stage 5B Verification
#
# Execution checks remain prediction-only and cache-only safe.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
print({'artifact_loading_run':'PASS','cache_only':CACHE_ONLY,'model_fit_calls':0,'preprocessing_fit_calls':0,'prediction_generation_calls':0,'source_data_loads':0,'test_artifact_loads':0})
# Out:
# {'artifact_loading_run': 'PASS', 'cache_only': True, 'model_fit_calls': 0, 'preprocessing_fit_calls': 0, 'prediction_generation_calls': 0, 'source_data_loads': 0, 'test_artifact_loads': 0}

# %% [markdown]
# # 23. Stage 5B Completion Note
#
# Stage 5B may pass with an accepted or rejected ensemble. Stage 5C has not started.
#
# Conclusion: this section reports saved evidence only. Limitation: Stage 5B Validation evidence is not a new unbiased Test evaluation.

# %%
print({'stage5b_status':'PASS','ensemble_status':decision['ensemble_status'],'next_step':'Begin Stage 5C — Post-Test Deep and Ensemble Evaluation.','stage5c_started':False})
# Out:
# {'stage5b_status': 'PASS', 'ensemble_status': 'rejected', 'next_step': 'Begin Stage 5C — Post-Test Deep and Ensemble Evaluation.', 'stage5c_started': False}
