# %% [markdown]
# # Stage 5C — Post-Test Deep and Ensemble Evaluation

# %% [markdown]
# ## 0. Stage Objective and Post-Test Disclosure
#
# This section checks stage objective and post-test disclosure from saved, validated artifacts. It does not train, tune, or generate predictions. Stage 4L remains the official pre-registered Test evaluation. Stage 5C is descriptive only.

# %%
from pathlib import Path
import hashlib, json, os
import pandas as pd
from IPython.display import display
ROOT = Path.cwd()
CACHE_ONLY = os.environ.get('STAGE5C_CACHE_ONLY', '0') == '1'
path=ROOT/'artifacts/results/stage5/posttest_evaluation/stage5c_evaluation_summary.json'
data=json.loads(path.read_text(encoding='utf-8'))
print({'stage_status':data['stage_status'],'evaluation_label':data['evaluation_label'],'stage4l_remains_official':data['stage4l_remains_official'],'stage6_started':data['stage6_started']})
# Out:
# {'stage_status': 'PASS', 'evaluation_label': 'Post-Test Extension', 'stage4l_remains_official': True, 'stage6_started': False}

# %% [markdown]
# ## 1. Imports and Configuration
#
# This section checks imports and configuration from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
from pathlib import Path
import hashlib, json, os
import pandas as pd
from IPython.display import display
ROOT = Path.cwd()
CACHE_ONLY = os.environ.get('STAGE5C_CACHE_ONLY', '0') == '1'
print({'stage':'stage5c','cache_only':CACHE_ONLY,'model_fit_calls':0,'preprocessing_fit_calls':0,'prediction_generation_calls':0,'source_access_calls':0})
# Out:
# {'stage': 'stage5c', 'cache_only': False, 'model_fit_calls': 0, 'preprocessing_fit_calls': 0, 'prediction_generation_calls': 0, 'source_access_calls': 0}

# %% [markdown]
# ## 2. State Reconstruction
#
# This section checks state reconstruction from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
text=(ROOT/'TASK.md').read_text(encoding='utf-8')
print(text.split('# Previous Stage Snapshot')[0][-3000:])
# Out:
# 31. Frozen RealMLP observed Post-Test MAE is 62.159745 without sensitive Features and 61.821114 with sensitive Features. Stage 4L remains official; Stage 6 has not started.
#
# # Open Questions
#
# - None.
#
# # Blockers
#
# - Human authorization is required to exceed the explicit maximum of three Notebook attempts for one clean artifact-loading rerun. This rerun will load Stage 5C artifacts only and will perform zero source/model access, prediction generation, fitting, Bootstrap recomputation, or Registry writes.
#
# # Verification Results
#
# - Stage 4L Verification: PASS
# - Stage 4L pre-Test freeze hash: PASS
# - Stage 5A Verification: PASS_WITH_DOCUMENTED_GOVERNANCE_EXCEPTION
# - Historical literal zero-Test-loading: FAIL, preserved
# - Stage 5B Verification and Reviewer: PASS
# - Stage 5B ensemble status: rejected
# - Deep evaluation eligible: true
# - Ensemble evaluation eligible: false
# - Frozen RealMLP bundle/model hashes: PASS for both modes
# ...

# %% [markdown]
# ## 3. Stage 4L Official Evaluation Status
#
# This section checks stage 4l official evaluation status from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/reports/stage5c_stage4l_primary_validation.json'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
# {
#   "candidate_id": "stage4l__blend__without_sensitive",
#   "canonical_target_hash": "889e4253fb584c2a52a06d8b8e956beefad997ba18e4d736af0cd1738fb34a1a",
#   "checks": {
#     "candidate_id_exact": true,
#     "finite_prediction": true,
#     "finite_y_true": true,
#     "official_metric_reproduction": true,
#     "prediction_hash_exact": true,
#     "row_count_exact": true,
#     "row_ids_unique": true,
#     "test_membership_exact": true,
#     "zero_train_overlap": true
#   },
#   "evaluation_label": "Post-Test Extension",
#   "first_stage5c_test_artifact_access_at_utc": "2026-07-15T23:50:30.857409+00:00",
#   "metrics": {
#     "mae": 61.511631217701016,
#     "mape_percent": 33.13209268417578,
#     "mean_signed_error": -9.554174474222766,
#     "median_absolute_error": 35.5897020672497,
#     "mse": 15822.736757025375,
#     "negative_prediction_rate": 2.0010405410813623e-05,
#     "p90_absolute_error": 131.5079529827791,
#     "r_squared": 0.7122061518962177,
# ...

# %% [markdown]
# ## 4. Stage 5A Frozen Deep Bundles
#
# This section checks stage 5a frozen deep bundles from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/manifests/stage5/stage5a2_full_train_manifest.json'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
# {
#   "checks": {
#     "all_effective_configs_match": true,
#     "all_proof_checks_pass": true,
#     "all_reload_checks_pass": true,
#     "both_results_pass": true,
#     "direct_no_refit_contract": true,
#     "epoch_30_both": true,
#     "global_steps_exact": true,
#     "no_early_stopping_or_restoration": true,
#     "no_test_or_stage4l_evidence_used": true,
#     "same_train_row_ids": true,
#     "same_train_rows": true,
#     "sensitive_attempt1_preserved": true,
#     "sensitive_retry_used_once": true,
#     "two_final_models": true,
#     "zero_test_rows": true,
#     "zero_validation_rows": true
#   },
#   "core_winner_family": "realmlp",
#   "feature_schema": "deep_core_v1",
#   "fixed_epoch": 30,
#   "historical_lineage": {
#     "deployed_refit_blocker": "artifacts/reports/stage5a2_fulltrain_blocker.json",
#     "recovery1_blocker": "artifacts/reports/stage5a2_fulltrain_recovery_1_blocker.json",
# ...

# %% [markdown]
# ## 5. Stage 5A Governance Exception
#
# This section checks stage 5a governance exception from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/reports/stage5a2_governance_adjudication.json'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
# {
#   "adjudication_id": "stage5a2_governance_adjudication_1",
#   "assessments": {
#     "artifact_validity": "Both final Train-only-membership models and bundles are accepted without refit.",
#     "procedural_compliance": "The literal no-Test-loading rule failed and is accepted only as this documented exception.",
#     "refit_required": false,
#     "statistical_leakage": "Not demonstrated: Train filtering preceded every learned or decision operation."
#   },
#   "classifications": {
#     "bundle_validity": "accepted",
#     "literal_zero_test_loading": false,
#     "model_artifact_validity": "accepted",
#     "procedural_compliance": "accepted_exception",
#     "refit_required": false,
#     "stage5_test_predictions_generated": false,
#     "stage5a2_completion_allowed": true,
#     "statistical_test_leakage": "not_demonstrated",
#     "test_based_model_selection": false,
#     "test_based_preprocessing": false,
#     "test_based_training": false
#   },
# ...

# %% [markdown]
# ## 6. Stage 5B Decision and Candidate Eligibility
#
# This section checks stage 5b decision and candidate eligibility from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/manifests/stage5/stage5b_evaluation_handoff.json'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
# {
#   "boost_weight": 0.5,
#   "boosting_anchor_candidate_ids": {
#     "catboost": "stage4l__catboost__without_sensitive",
#     "lightgbm": "stage4l__lightgbm__without_sensitive",
#     "xgboost": "stage4l__xgboost__without_sensitive"
#   },
#   "bootstrap_result": {
#     "best_component_candidate_id": "stage4l__blend__without_sensitive",
#     "boost_candidate_id": "stage4l__blend__without_sensitive",
#     "bootstrap_mean": -0.2769272464378641,
#     "bootstrap_median": -0.2787620559220554,
#     "ci95_lower": -0.47107788971675446,
#     "ci95_upper": -0.06945292104237374,
#     "confirmation_pass": true,
#     "ensemble_candidate_id": "stage5b__frozen_stage4_boosting_blend__deep-weight-0.50",
#     "point_mae_difference": -0.2778740988612469,
#     "resample_count": 500,
#     "seed": 42,
#     "win_proportion": 0.994
#   },
#   "deep_evaluation_eligible": true,
#   "deep_final_bundle_paths_and_hashes": {
#     "with_sensitive": {
# ...

# %% [markdown]
# ## 7. Protected File Baseline
#
# This section checks protected file baseline from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/manifests/stage5/stage5c_protected_hashes_before.json'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
# {
#   "created_at_utc": "2026-07-15T23:48:44.912995+00:00",
#   "elapsed_seconds": 6.099675499979639,
#   "entries": [
#     {
#       "path": "D:\\SHARIF\\TERM7\\DATA\\PROJECT\\main\\REGRESION_PART1.ipynb",
#       "sha256": "990ced79600bfa4d7a0ba0bf3326b85812f36faa4df0367d689752284aafc0bf",
#       "size_bytes": 4196401
#     },
#     {
#       "path": "artifacts/data_contract/feature_inventory.csv",
#       "sha256": "2a4f85d8862d9ea3d49b85665f0650a3094111d0b08849b5908afed00238ae0e",
#       "size_bytes": 4735
#     },
#     {
#       "path": "artifacts/manifests/stage4/catboost/catboost_feature_engineer_v2_manifest.json",
#       "sha256": "55359c68ee563948882dbb7c63cdc47500aaa4d7e0bef5947c06d0b2cab7dd85",
#       "size_bytes": 2154
#     },
#     {
#       "path": "artifacts/manifests/stage4/catboost/catboost_feature_engineer_v2_smoke.joblib",
#       "sha256": "d661b4250a154186555b7bf6e7a4d5d16c873bb62e6071d03d0ca83dc585a142",
#       "size_bytes": 975
#     },
#     {
# ...

# %% [markdown]
# ## 8. Pre-Evaluation Freeze
#
# This section checks pre-evaluation freeze from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/reports/stage5c_preevaluation_freeze.json'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
# {
#   "best_checkpoint_restoration": false,
#   "bootstrap_settings": {
#     "paired_indices": true,
#     "resamples": 500,
#     "seed": 42
#   },
#   "canonical_target_source": "artifacts/predictions/final_test/stage4l__blend__without_sensitive.csv",
#   "deep_candidate_count": 2,
#   "deep_evaluation_candidate_ids": [
#     "stage5c__realmlp__without_sensitive__test_evaluation",
#     "stage5c__realmlp__with_sensitive__test_evaluation"
#   ],
#   "deep_evaluation_eligible": true,
#   "deep_modes": {
#     "with_sensitive": {
#       "bundle_candidate_id": "stage5a2__realmlp__full_train__with_sensitive__fixed_epoch30__technical_retry1",
#       "bundle_path": "artifacts/models/deep/core_final/stage5a2__realmlp__full_train__with_sensitive__fixed_epoch30__technical_retry1.joblib",
#       "bundle_sha256": "d8b74180385cae7c0cfb9570ef124e9061c4ee398a68a7a9266aca3de299f600",
# ...

# %% [markdown]
# ## 9. Safe Test-Row Loader
#
# This section checks safe test-row loader from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/reports/stage5c_safe_loader_sentinel.json'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
# {
#   "checks": {
#     "excluded_feature_values_not_converted": true,
#     "excluded_target_values_not_converted": true,
#     "only_allowed_ids_returned": true,
#     "row_order_preserved": true,
#     "source_unchanged": true,
#     "target_not_requested": true
#   },
#   "converter_call_counts": {
#     "feature_cat": 2,
#     "feature_num": 2,
#     "target": 0
#   },
#   "created_at_utc": "2026-07-15T23:49:54.848428+00:00",
#   "evaluation_label": "Post-Test Extension",
#   "excluded_rows_converted": 0,
#   "loader_path": "stage5_safe_row_loader.py",
#   "loader_sha256": "f981866b42351df1bae6d0a7b0148ccbc72ec9b49414eb706d524295fb86c4d0",
#   "source_target_values_materialized": 0,
#   "stage_id": "stage5c",
#   "status": "PASS"
# }

# %% [markdown]
# ## 10. Test Access Audit
#
# This section checks test access audit from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/reports/stage5c_test_access_audit.json'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
# {
#   "authorization_source": "Attached Stage 5C user specification",
#   "bundle_load_timestamps": {
#     "with_sensitive": "2026-07-15T23:52:27.512221+00:00",
#     "without_sensitive": "2026-07-15T23:52:09.460163+00:00"
#   },
#   "canonical_target_hash": "889e4253fb584c2a52a06d8b8e956beefad997ba18e4d736af0cd1738fb34a1a",
#   "canonical_target_path": "artifacts/predictions/final_test/stage4l__blend__without_sensitive.csv",
#   "dataframe_materialization_scope": "99,948 Test Feature rows per sensitive mode",
#   "ensemble_test_access": "none",
#   "evaluation_label": "Post-Test Extension",
#   "excluded_rows_converted": 0,
#   "first_source_feature_access_at_utc": "2026-07-15T23:52:07.915625+00:00",
#   "first_stage5c_test_artifact_access_at_utc": "2026-07-15T23:50:30.857409+00:00",
#   "loader_path": "stage5_safe_row_loader.py",
#   "loader_sha256": "f981866b42351df1bae6d0a7b0148ccbc72ec9b49414eb706d524295fb86c4d0",
# ...

# %% [markdown]
# ## 11. Canonical Test Target and Official Comparator
#
# This section checks canonical test target and official comparator from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/reports/stage5c_stage4l_primary_validation.json'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
# {
#   "candidate_id": "stage4l__blend__without_sensitive",
#   "canonical_target_hash": "889e4253fb584c2a52a06d8b8e956beefad997ba18e4d736af0cd1738fb34a1a",
#   "checks": {
#     "candidate_id_exact": true,
#     "finite_prediction": true,
#     "finite_y_true": true,
#     "official_metric_reproduction": true,
#     "prediction_hash_exact": true,
#     "row_count_exact": true,
#     "row_ids_unique": true,
#     "test_membership_exact": true,
#     "zero_train_overlap": true
#   },
#   "evaluation_label": "Post-Test Extension",
#   "first_stage5c_test_artifact_access_at_utc": "2026-07-15T23:50:30.857409+00:00",
#   "metrics": {
#     "mae": 61.511631217701016,
#     "mape_percent": 33.13209268417578,
#     "mean_signed_error": -9.554174474222766,
#     "median_absolute_error": 35.5897020672497,
#     "mse": 15822.736757025375,
#     "negative_prediction_rate": 2.0010405410813623e-05,
#     "p90_absolute_error": 131.5079529827791,
#     "r_squared": 0.7122061518962177,
# ...

# %% [markdown]
# ## 12. Test Feature Alignment
#
# This section checks test feature alignment from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/reports/stage5c_test_input_alignment_report.json'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
# {
#   "canonical_target_hash": "889e4253fb584c2a52a06d8b8e956beefad997ba18e4d736af0cd1738fb34a1a",
#   "canonical_targets_align_exactly": true,
#   "common_feature_column_count": 31,
#   "common_feature_values_equal": true,
#   "evaluation_label": "Post-Test Extension",
#   "excluded_rows_converted": 0,
#   "loader_path": "stage5_safe_row_loader.py",
#   "loader_sha256": "f981866b42351df1bae6d0a7b0148ccbc72ec9b49414eb706d524295fb86c4d0",
#   "prediction_rows_align_exactly": true,
#   "schema_hashes": {
#     "with_sensitive": "415c973266ff04d826d8ccf5725c6ed43f1a9364fdebc40a66084fa82f695f9e",
#     "without_sensitive": "89cb6ec8688d4b74a79f0979b0ff5e7e6c3d2b9a8f7fcb1bed8568d806b9738c"
#   },
#   "sensitive_columns_only_in_expected_mode": true,
#   "sentinel_status": "PASS",
#   "source_frames_unchanged": true,
#   "source_hashes": {
#     "with_sensitive": "6dc52dca5a8a7196a75213fab4a5a5c0a541f84390219459afb0b2be7b77aede",
# ...

# %% [markdown]
# ## 13. Frozen Deep Prediction — Without Sensitive
#
# This section checks frozen deep prediction — without sensitive from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/manifests/stage5/stage5c_prediction_manifest_without_sensitive.json'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
# {
#   "attempt_id": "without_sensitive_attempt2_technical_retry1",
#   "attempt_lineage": [
#     "without_sensitive_attempt1",
#     "without_sensitive_attempt2_technical_retry1"
#   ],
#   "bundle_candidate_id": "stage5a2__realmlp__full_train__without_sensitive__direct_no_refit_recovery2",
#   "bundle_checks": {
#     "best_checkpoint_restoration_false": true,
#     "device_cpu": true,
#     "early_stopping_false": true,
#     "family_realmlp": true,
#     "features_exact": true,
#     "fixed_epoch_30": true,
#     "precision_float32": true,
#     "row_id_not_feature": true,
#     "sensitive_mode_match": true,
#     "target_mode_raw": true,
#     "target_not_feature": true,
#     "test_rows_in_fit_zero": true,
#     "training_rows_exact": true
#   },
#   "bundle_loaded_at_utc": "2026-07-15T23:52:09.460163+00:00",
#   "bundle_path": "artifacts/models/deep/core_final/stage5a2__realmlp__full_train__without_sensitive__direct_no_refit_recovery2.joblib",
# ...

# %% [markdown]
# ## 14. Frozen Deep Prediction — With Sensitive
#
# This section checks frozen deep prediction — with sensitive from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/manifests/stage5/stage5c_prediction_manifest_with_sensitive.json'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
# {
#   "attempt_id": "with_sensitive_attempt1",
#   "attempt_lineage": [
#     "with_sensitive_attempt1"
#   ],
#   "bundle_candidate_id": "stage5a2__realmlp__full_train__with_sensitive__fixed_epoch30__technical_retry1",
#   "bundle_checks": {
#     "best_checkpoint_restoration_false": true,
#     "device_cpu": true,
#     "early_stopping_false": true,
#     "family_realmlp": true,
#     "features_exact": true,
#     "fixed_epoch_30": true,
#     "precision_float32": true,
#     "row_id_not_feature": true,
#     "sensitive_mode_match": true,
#     "target_mode_raw": true,
#     "target_not_feature": true,
#     "test_rows_in_fit_zero": true,
#     "training_rows_exact": true
#   },
#   "bundle_loaded_at_utc": "2026-07-15T23:52:27.512221+00:00",
#   "bundle_path": "artifacts/models/deep/core_final/stage5a2__realmlp__full_train__with_sensitive__fixed_epoch30__technical_retry1.joblib",
#   "bundle_sha256": "d8b74180385cae7c0cfb9570ef124e9061c4ee398a68a7a9266aca3de299f600",
# ...

# %% [markdown]
# ## 15. Prediction Artifact Validation
#
# This section checks prediction artifact validation from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/reports/stage5c_prediction_attempts.json'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
# {
#   "attempts": [
#     {
#       "attempt_id": "with_sensitive_attempt1",
#       "completed_at_utc": "2026-07-15T23:52:35.064052+00:00",
#       "evaluation_label": "Post-Test Extension",
#       "excluded_rows_converted": 0,
#       "first_source_feature_access_at_utc": "2026-07-15T23:52:25.611786+00:00",
#       "manifest_path": "artifacts/manifests/stage5/stage5c_prediction_manifest_with_sensitive.json",
#       "mode": "with_sensitive",
#       "model_fit_calls": 0,
#       "parent_timeout_seconds": 1200,
#       "peak_process_tree_ram_mib": 584.703125,
#       "prediction_calls": 1,
#       "prediction_path": "artifacts/predictions/stage5/posttest_evaluation/stage5c_test_predictions_with_sensitive.csv",
#       "prediction_sha256": "b4b11779a2d85209b2082c003ce79db2b657acd52c816c5e5345aaa6671f5e99",
#       "preprocessing_fit_calls": 0,
#       "runtime_seconds": 10.054521899990505,
#       "source_target_values_materialized": 0,
# ...

# %% [markdown]
# ## 16. Common Test Metrics
#
# This section checks common test metrics from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/results/stage5/posttest_evaluation/stage5c_test_metrics.csv'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
#                                         candidate_id  \
# 0                  stage4l__blend__without_sensitive
# 1  stage5c__realmlp__without_sensitive__test_eval...
# 2  stage5c__realmlp__with_sensitive__test_evaluation
#
#                     model_family     sensitive_mode evaluation_stage  \
# 0  Frozen Stage 4 Boosting Blend  without_sensitive         Stage 4L
# 1                        RealMLP  without_sensitive         Stage 5C
# 2                        RealMLP     with_sensitive         Stage 5C
#
#                      evaluation_label               official_result_role  \
# 0  Official pre-registered evaluation    official_pre_registered_primary
# 1                 Post-Test Extension                post_test_extension
# 2                 Post-Test Extension  post_test_extension_accuracy_only
#
#                                      prediction_path  \
# 0  artifacts/predictions/final_test/stage4l__blen...
# 1  artifacts/predictions/stage5/posttest_evaluati...
# ...

# %% [markdown]
# ## 17. Official Stage 4L Comparison
#
# This section checks official stage 4l comparison from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/results/stage5/posttest_evaluation/stage5c_official_comparison.csv'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
#                    metric  stage4l_value    deep_value  deep_minus_stage4l  \
# 0                     mae      61.511631     62.159745            0.648114
# 1                     mse   15822.736757  15788.279771          -34.456986
# 2                    rmse     125.788460    125.651422           -0.137039
# 3               r_squared       0.712206      0.712833            0.000627
# 4                   rmsle       0.383861      0.389685            0.005824
# 5            mape_percent      33.132093     33.592208            0.460116
# 6   median_absolute_error      35.589702     36.401075            0.811373
# 7            wape_percent      24.949970     25.212854            0.262884
# 8       mean_signed_error      -9.554174     -7.013757            2.540418
# 9      p90_absolute_error     131.507953    132.683744            1.175791
# 10         top_decile_mae     195.498099    191.740517           -3.757582
# ...

# %% [markdown]
# ## 18. Paired Bootstrap
#
# This section checks paired bootstrap from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/results/stage5/posttest_evaluation/stage5c_paired_bootstrap.csv'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
#                            comparison_id  \
# 0  realmlp_without_minus_stage4l_primary
# 1   realmlp_with_minus_without_sensitive
#
#                                   first_candidate_id  \
# 0  stage5c__realmlp__without_sensitive__test_eval...
# 1  stage5c__realmlp__with_sensitive__test_evaluation
#
#                                  second_candidate_id  point_mae_difference  \
# 0                  stage4l__blend__without_sensitive              0.648114
# 1  stage5c__realmlp__without_sensitive__test_eval...             -0.338631
#
#    bootstrap_mean  bootstrap_median    ci_2_5   ci_97_5  \
# 0        0.647066          0.643701  0.453880  0.845481
# 1       -0.336300         -0.332808 -0.499985 -0.185015
#
#    first_candidate_win_proportion  resamples  seed     evaluation_label  \
# 0                             0.0        500    42  Post-Test Extension
# 1                             1.0        500    42  Post-Test Extension
#
# ...

# %% [markdown]
# ## 19. Sensitive Accuracy Comparison
#
# This section checks sensitive accuracy comparison from saved, validated artifacts. It does not train, tune, or generate predictions. This is accuracy evidence, not a fairness audit or causal result.

# %%
path=ROOT/'artifacts/results/stage5/posttest_evaluation/stage5c_sensitive_accuracy_comparison.csv'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
#                    metric  without_sensitive_value  with_sensitive_value  \
# 0                     mae                62.159745             61.821114
# 1                     mse             15788.279771          15630.041315
# 2                    rmse               125.651422            125.020164
# 3               r_squared                 0.712833              0.715711
# 4                   rmsle                 0.389685              0.389633
# 5            mape_percent                33.592208             33.696017
# 6   median_absolute_error                36.401075             36.132471
# 7            wape_percent                25.212854             25.075500
# 8       mean_signed_error                -7.013757             -6.440910
# 9      p90_absolute_error               132.683744            131.474865
# 10         top_decile_mae               191.740517            190.956326
# 11   top_five_percent_mae               278.545533            277.236066
#
# ...

# %% [markdown]
# ## 20. Target-Decile and Tail Summary
#
# This section checks target-decile and tail summary from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/results/stage5/posttest_evaluation/stage5c_target_decile_metrics.csv'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
#                                          candidate_id  target_decile  \
# 0                   stage4l__blend__without_sensitive              1
# 1                   stage4l__blend__without_sensitive              2
# 2                   stage4l__blend__without_sensitive              3
# 3                   stage4l__blend__without_sensitive              4
# 4                   stage4l__blend__without_sensitive              5
# 5                   stage4l__blend__without_sensitive              6
# 6                   stage4l__blend__without_sensitive              7
# 7                   stage4l__blend__without_sensitive              8
# 8                   stage4l__blend__without_sensitive              9
# 9                   stage4l__blend__without_sensitive             10
# 10  stage5c__realmlp__without_sensitive__test_eval...              1
# 11  stage5c__realmlp__without_sensitive__test_eval...              2
#
# ...

# %% [markdown]
# ## 21. Prediction and Residual Disagreement
#
# This section checks prediction and residual disagreement from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/results/stage5/posttest_evaluation/stage5c_disagreement_summary.csv'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
#                         comparison_id  pearson_prediction_correlation  \
# 0  realmlp_without_vs_stage4l_primary                        0.984343
# 1   realmlp_with_vs_without_sensitive                        0.989189
#
#    spearman_prediction_correlation  pearson_residual_correlation  \
# 0                         0.988733                      0.964374
# 1                         0.992052                      0.974628
#
#    spearman_residual_correlation  mean_absolute_prediction_disagreement  \
# 0                       0.943720                              16.691883
# 1                       0.958913                              14.214083
#
#    median_absolute_prediction_disagreement  \
# 0                                 9.292099
# 1                                 8.302328
#
#    first_candidate_lower_absolute_error_percent  \
# 0                                     47.682795
# 1                                     50.656341
#
# ...

# %% [markdown]
# ## 22. Post-Test Interpretation
#
# This section checks post-test interpretation from saved, validated artifacts. It does not train, tune, or generate predictions. Stage 4L remains the official pre-registered Test evaluation. Stage 5C is descriptive only.

# %%
path=ROOT/'artifacts/results/stage5/posttest_evaluation/stage5c_evaluation_summary.json'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
# {
#   "bootstrap_summaries": [
#     {
#       "bootstrap_mean": 0.6470662879579675,
#       "bootstrap_median": 0.6437009448438786,
#       "ci_2_5": 0.4538804170824676,
#       "ci_97_5": 0.8454810733773875,
#       "comparison_id": "realmlp_without_minus_stage4l_primary",
#       "evaluation_label": "Post-Test Extension",
#       "first_candidate_id": "stage5c__realmlp__without_sensitive__test_evaluation",
#       "first_candidate_win_proportion": 0.0,
#       "interpretation": "Negative values favor the first-named Candidate. This is descriptive and caused no selection.",
#       "point_mae_difference": 0.6481138711769034,
#       "resamples": 500,
#       "row_hash": "e58e4d078c761f60405e644d4dd7ba368f364daffb73b44abb39095938ece95e",
#       "second_candidate_id": "stage4l__blend__without_sensitive",
#       "seed": 42,
#       "target_hash": "889e4253fb584c2a52a06d8b8e956beefad997ba18e4d736af0cd1738fb34a1a"
#     },
#     {
#       "bootstrap_mean": -0.336300459564,
# ...

# %% [markdown]
# ## 23. Test Evaluation Visualizations
#
# This section checks test evaluation visualizations from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/manifests/stage5/stage5c_visualization_manifest.json'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
# {
#   "evaluation_label": "Post-Test Extension",
#   "figure_count": 10,
#   "figures": [
#     {
#       "candidate_ids": [
#         "stage4l__blend__without_sensitive",
#         "stage5c__realmlp__without_sensitive__test_evaluation",
#         "stage5c__realmlp__with_sensitive__test_evaluation"
#       ],
#       "evaluation_label": "Post-Test Extension",
#       "figure_path": "artifacts/figures/stage5c/stage5c_test_mae_comparison.png",
#       "figure_sha256": "17de57d6c5383b7ea0ccd85f8d411615858f6c2b696ebecdd7c863619591af7c",
#       "interpretation_scope": "Descriptive Test evaluation only; no model selection.",
#       "plotting_data_path": "artifacts/figures/stage5c/plotting_data/stage5c_test_mae_comparison.csv",
#       "plotting_data_sha256": "947f78da519015c2bfe7180930896d331cc355305b063f7190400c8da49c2007",
#       "test_row_hash": "e58e4d078c761f60405e644d4dd7ba368f364daffb73b44abb39095938ece95e",
#       "title": "MAE Comparison\nPost-Test Extension"
#     },
#     {
# ...

# %% [markdown]
# ## 24. Registry Update
#
# This section checks registry update from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/reports/stage5c_registry_update.json'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
# {
#   "action": "REUSED",
#   "evaluation_label": "Post-Test Extension",
#   "prior_byte_count": 247798,
#   "prior_prefix_preserved": true,
#   "prior_sha256": "da5501ee01e2131c642ca34af570ea7775cdce8a1cfa5a373a54c6cef66b4b5c",
#   "registry_row_count": 362,
#   "registry_sha256": "27b0ef62e59dec653c6a68459db765790b8ad1947f62fa5caaca6e84cf975522",
#   "registry_unique_ids": true,
#   "second_action": "REUSED",
#   "stage5c_registry_ids": [
#     "stage5c__realmlp__without_sensitive__test_evaluation",
#     "stage5c__realmlp__with_sensitive__test_evaluation",
#     "stage5c__realmlp_vs_stage4l__official_comparison",
#     "stage5c__realmlp_vs_stage4l__paired_bootstrap",
#     "stage5c__realmlp__sensitive_accuracy_comparison",
#     "stage5c__evaluation_summary",
#     "stage5c__stage6_handoff"
#   ],
#   "stage5c_row_count": 7,
#   "stage_id": "stage5c",
#   "status": "PASS"
# }

# %% [markdown]
# ## 25. Stage 6 Handoff
#
# This section checks stage 6 handoff from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/manifests/stage5/stage5c_stage6_handoff.json'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
# {
#   "accepted_ensemble_count": 0,
#   "artifact_paths_and_hashes": {
#     "bootstrap": {
#       "path": "artifacts/results/stage5/posttest_evaluation/stage5c_paired_bootstrap.csv",
#       "sha256": "9e49560e3a7fbb997e42018143bb945974157b6af8a97cf095767fac8a1e6b17"
#     },
#     "common_metrics": {
#       "path": "artifacts/results/stage5/posttest_evaluation/stage5c_test_metrics.csv",
#       "sha256": "6c95dfaa3b5873880159b0f9f90df2e59bc202a90832df176e80a8a877b0d575"
#     },
#     "decile_metrics": {
#       "path": "artifacts/results/stage5/posttest_evaluation/stage5c_target_decile_metrics.csv",
#       "sha256": "da0ca727d2ea4131c8c51b9f54003c3d7f24051690ce08c0ab47ede37d6be99d"
#     },
#     "disagreement_by_decile": {
#       "path": "artifacts/results/stage5/posttest_evaluation/stage5c_disagreement_by_target_decile.csv",
#       "sha256": "7480d6fd8791d22e21d090fd29a60f27b5c94317d3989cb17bb037aac4896f00"
#     },
#     "disagreement_summary": {
# ...

# %% [markdown]
# ## 26. Stage 5C Artifact Summary
#
# This section checks stage 5c artifact summary from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/results/stage5/posttest_evaluation/stage5c_evaluation_summary.json'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
# {
#   "bootstrap_summaries": [
#     {
#       "bootstrap_mean": 0.6470662879579675,
#       "bootstrap_median": 0.6437009448438786,
#       "ci_2_5": 0.4538804170824676,
#       "ci_97_5": 0.8454810733773875,
#       "comparison_id": "realmlp_without_minus_stage4l_primary",
#       "evaluation_label": "Post-Test Extension",
#       "first_candidate_id": "stage5c__realmlp__without_sensitive__test_evaluation",
#       "first_candidate_win_proportion": 0.0,
#       "interpretation": "Negative values favor the first-named Candidate. This is descriptive and caused no selection.",
#       "point_mae_difference": 0.6481138711769034,
#       "resamples": 500,
#       "row_hash": "e58e4d078c761f60405e644d4dd7ba368f364daffb73b44abb39095938ece95e",
#       "second_candidate_id": "stage4l__blend__without_sensitive",
#       "seed": 42,
#       "target_hash": "889e4253fb584c2a52a06d8b8e956beefad997ba18e4d736af0cd1738fb34a1a"
#     },
#     {
#       "bootstrap_mean": -0.336300459564,
# ...

# %% [markdown]
# ## 27. Independent Review and Repairs
#
# This section checks independent review and repairs from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/reports/stage5c_reviewer.md'
print(path.read_text(encoding='utf-8') if path.exists() else 'Independent review runs after Notebook execution; no finding is hidden.')
# Out:
# # Stage 5C Independent Review
#
# Review scope: read-only independent review of `Stage 5C — Post-Test Deep and Ensemble Evaluation`. I independently inspected the frozen prerequisites, hashes, Test governance, loader implementation and sentinel, all prediction attempts, prediction files, metrics, paired Bootstrap, sensitive accuracy wording, disagreement and tail results, figures, Registry evidence, Notebook executions, protected recheck, State files, and Stage 6 handoff. I changed no model, prediction, result, Registry, Notebook, State file, or prior-Stage artifact.
#
# Review outcome: blocked by one unresolved Major deliverable-consistency issue. There are zero Critical and one Minor issue.
#
# ## Evidence that passes
#
# ### Stage 4L official identity and reproduction
#
# - `artifacts/reports/stage4l_verification.json` is PASS. The official pre-registered primary is `stage4l__blend__without_sensitive`, not a Candidate chosen from the observed Test leaderboard.
# ...

# %% [markdown]
# ## 28. Stage 5C Verification
#
# This section checks stage 5c verification from saved, validated artifacts. It does not train, tune, or generate predictions.

# %%
path=ROOT/'artifacts/reports/stage5c_preliminary_verification.json'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
# {
#   "checks": {
#     "all_required_artifacts_exist": true,
#     "ensemble_test_prediction_absent": true,
#     "model_fit_calls_zero": true,
#     "new_boosting_prediction_count_zero": true,
#     "preprocessing_fit_calls_zero": true,
#     "source_target_values_zero": true,
#     "train_feature_rows_zero": true,
#     "two_prediction_artifacts": true
#   },
#   "created_at_utc": "2026-07-15T23:54:01.157924+00:00",
#   "evaluation_label": "Post-Test Extension",
#   "stage_id": "stage5c",
#   "status": "PASS"
# }

# %% [markdown]
# ## 29. Stage 5C Completion Note
#
# This section checks stage 5c completion note from saved, validated artifacts. It does not train, tune, or generate predictions. Stage 4L remains the official pre-registered Test evaluation. Stage 5C is descriptive only.

# %%
path=ROOT/'artifacts/results/stage5/posttest_evaluation/stage5c_evaluation_summary.json'
assert path.exists(), path
if path.suffix == '.json':
    data=json.loads(path.read_text(encoding='utf-8'))
    print(json.dumps(data, indent=2, ensure_ascii=False)[:12000])
elif path.suffix == '.csv':
    data=pd.read_csv(path)
    display(data.head(12))
    print({'rows':len(data),'columns':list(data.columns)})
else:
    print(path.read_text(encoding='utf-8')[:12000])
# Out:
# {
#   "bootstrap_summaries": [
#     {
#       "bootstrap_mean": 0.6470662879579675,
#       "bootstrap_median": 0.6437009448438786,
#       "ci_2_5": 0.4538804170824676,
#       "ci_97_5": 0.8454810733773875,
#       "comparison_id": "realmlp_without_minus_stage4l_primary",
#       "evaluation_label": "Post-Test Extension",
#       "first_candidate_id": "stage5c__realmlp__without_sensitive__test_evaluation",
#       "first_candidate_win_proportion": 0.0,
#       "interpretation": "Negative values favor the first-named Candidate. This is descriptive and caused no selection.",
#       "point_mae_difference": 0.6481138711769034,
#       "resamples": 500,
#       "row_hash": "e58e4d078c761f60405e644d4dd7ba368f364daffb73b44abb39095938ece95e",
#       "second_candidate_id": "stage4l__blend__without_sensitive",
#       "seed": 42,
#       "target_hash": "889e4253fb584c2a52a06d8b8e956beefad997ba18e4d736af0cd1738fb34a1a"
#     },
#     {
#       "bootstrap_mean": -0.336300459564,
# ...
