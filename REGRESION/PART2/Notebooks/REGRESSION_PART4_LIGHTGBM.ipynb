# %% [markdown]
# # Complete LightGBM Track
#
# ## Stage 4F — Initial LightGBM Model and Importance Analysis
#
# ### 0. Stage 4F Objective
#
# Reason: Stage 4F uses only the saved non-sensitive Discovery sample.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: The LightGBM track starts with Test locked.

# %%
from pathlib import Path
import json, os
import pandas as pd
from IPython.display import display, Image, Markdown
ROOT = Path.cwd().resolve()
CACHE_ONLY = os.environ.get('STAGE4_LIGHTGBM_CACHE_ONLY', '0') == '1'
assert (ROOT / 'artifacts/reports/stage4g_gate_verification.json').is_file()

def show_json(relative, keys=None):
    value = json.loads((ROOT / relative).read_text(encoding='utf-8'))
    if keys is None:
        display(value)
    else:
        display({key: value.get(key) for key in keys})
    return value

def show_csv(relative, columns=None, rows=10):
    frame = pd.read_csv(ROOT / relative)
    view = frame if columns is None else frame.loc[:, columns]
    display(view.head(rows))
    return frame

print({'project_root': str(ROOT), 'cache_only': CACHE_ONLY, 'fit_calls': 0, 'test_predictions': 0})
# Out:
# {'project_root': 'D:\\SHARIF\\TERM7\\DATA\\PROJECT\\regresionpart2', 'cache_only': True, 'fit_calls': 0, 'test_predictions': 0}

# %% [markdown]
# ### 1. Imports and Configuration
#
# Reason: This section checks the saved evidence for Imports and Configuration.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: The notebook is a cache reader and contains no fit call.

# %%
print({'cache_reader': True, 'heavy_fit_calls': 0, 'thread_count': 2, 'seed': 42})
# Out:
# {'cache_reader': True, 'heavy_fit_calls': 0, 'thread_count': 2, 'seed': 42}

# %% [markdown]
# ### 2. Previous-Stage Validation
#
# Reason: This section checks the saved evidence for Previous-Stage Validation.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Every required earlier Stage reports PASS.

# %%
reports = {name: json.loads((ROOT / 'artifacts/reports' / name).read_text(encoding='utf-8'))['status'] for name in ['prompt1_verification.json','prompt2_verification.json','stage3_verification.json','stage4a_verification.json','stage4b_verification.json','stage4c_verification.json','stage4de_verification.json']}
display(reports)
assert set(reports.values()) == {'PASS'}
# Out:
# {'prompt1_verification.json': 'PASS',
#  'prompt2_verification.json': 'PASS',
#  'stage3_verification.json': 'PASS',
#  'stage4a_verification.json': 'PASS',
#  'stage4b_verification.json': 'PASS',
#  'stage4c_verification.json': 'PASS',
#  'stage4de_verification.json': 'PASS'}

# %% [markdown]
# ### 3. Protected File Check
#
# Reason: This section checks the saved evidence for Protected File Check.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Protected source and prior-stage files remain unchanged.

# %%
show_json('artifacts/manifests/stage4/lightgbm/stage4g_protected_hashes_after.json', ['file_count','mismatches','status'])
# Out:
# {'file_count': 852, 'mismatches': {}, 'status': 'PASS'}
# {'created_at_utc': '2026-07-14T17:56:50.783070+00:00',
#  'file_count': 852,
#  'hashes': {'D:\\SHARIF\\TERM7\\DATA\\PROJECT\\main\\REGRESION_PART1.ipynb': '990ced79600bfa4d7a0ba0bf3326b85812f36faa4df0367d689752284aafc0bf',
#   '__pycache__/build_prompt1_notebook.cpython-312.pyc': '2605b60551f682496cfa767e393895358c6a23a86425f402ee729a621001c7dc',
#   '__pycache__/build_stage3_notebook.cpython-312.pyc': '6d6cb45eb599fd716a021ecea0f80fa0d1242c62ac4acee8876d10e6a4ef3990',
#   '__pycache__/build_stage4a_notebook.cpython-312.pyc': '310335f8a4f9c58f5c9c03d9af1c6d4a9942b4aca974c5edef5fa51d957c9797',
#   'artifacts/backups/stage3_recovery_20260714_112543/DECISIONS.md': '4d73094cc6af15d5d280918e7a26ede0c8c7e4bff6bacb0304995104e75b4e3e',
#   'artifacts/backups/stage3_recovery_20260714_112543/LOG.md': '129bbdd07f7ebed3691d83e02c9b05c2130107a945ab43eeaf70dda194100eed',
#   'artifacts/backups/stage3_recovery_20260714_112543/PLAN.md': '84323a812acf1d3cfd7908d41626926facc71c3440b7fd3095cc96b6fca48d3f',
#   'artifacts/backups/stage3_recovery_20260714_112543/REGRESSION_PART3_TREE_MODELS.ipynb': '63da3be9403a66d9959fec1144702a4f580bb2690fd00daf95575472de8ae9da',
#   'artifacts/backups/stage3_recovery_20260714_112543/stage3_tree_utils.py': '270ed40d82b589efda2217de0eeb58650cc7ac6e47ee9c35ed054fc08f726fb1',
#   'artifacts/backups/stage3_recovery_20260714_112543/TASK.md': '9a515a7c24513b3a5b58817f6f22ad48b87b1bc5d27621615ac1867e17154da5',
#   'artifacts/backups/stage4_boosting_utils_stage4a_final_20260714.py': 'eab4816c05eb86d6dc2325ff52e1bebd7c730b1dd7b4cfe21b483ea541858d7e',
#   'artifacts/checkpoints/stage4/atomic_smoke/sample.csv': '16b01c5eff34a783a3b221c4298ed9caa9eb094c81e426328aac43a041b2e822',
#   'artifacts/checkpoints/stage4/atomic_smoke/sample.joblib': '1d5862be4cf040d3e279b4ea3841a60a83d8091fab56734200b99ad5380656b2',
#   'artifacts/checkpoints/stage4/atomic_smoke/sample.json': '9162e4c73982c56b20678a5aa170d9cea13fa028d7f294ed2d42248a96601295',
#   'artifacts/checkpoints/stage4/cache_validation_smoke.csv': '623a27b89a1eafb7d132531c7d03349dfd3bb6f1d4f9a9db50e5598927ababd4',
#   'artifacts/checkpoints/stage4/cache_validation_smoke.json': 'a6af66ee9cb50b6deb9b3c6fee3dd8a86a90fb6c42f4a5bd5de9b0980166199e',
#   'artifacts/checkpoints/stage4/catboost/candidate_01_base_raw.json': 'fd5960c07fd57b8e7c57c0b059d59a9c1414d1bd800b33bfa56a7aeb712cc8e7',
#   'artifacts/checkpoints/stage4/catboost/candidate_01_base_raw__config.json': 'b7c20a9b860746433f2ee38b8cf1644c6e760f5a5955853fc4c194c3473e8303',
#   'artifacts/checkpoints/stage4/catboost/candidate_02_native_raw.json': '7abd5d3150c86a4e613aa6ff2b35184496801abf55015196ea9934616946a241',
#   'artifacts/checkpoints/stage4/catboost/candidate_02_native_raw__config.json': '7227497397df897419dae3563799c2c48b81d5c1d00d1ab311bb03edc1629d40',
#   'artifacts/checkpoints/stage4/catboost/candidate_03_native_log1p.json': '5cefe62258af42d5f07f911e57bddf9b84ba41a2da496748281eb4d15a1d4608',
#   'artifacts/checkpoints/stage4/catboost/candidate_03_native_log1p__config.json': '3ffbf62a64cb849bdffbeaf267a75250220ca46ac8d7122a89e76d8c2287a82b',
#   'artifacts/checkpoints/stage4/catboost/candidate_04_safer_refinement.json': 'b734add96d5265577e3499eda2d8266eadebb2c991bb512c538aed2440d3337a',

#   'artifacts/checkpoints/stage4/catboost/stage4de/tuning_b_safer.json': '1bec39a40d6850ba8a3569f93a9eef202aea10fc1abc6afa8298ced41196d301',
#   'artifacts/checkpoints/stage4/catboost/stage4de/tuning_b_safer__config.json': '6d8305ef9ffc6c66fac55509d8c7aaef05b03f0a23e0bbebc367bafb661cf7f7',
#   'artifacts/checkpoints/stage4/catboost/stage4de/tuning_c_flexible.json': '616a8c704ec791321f76d4a5b3b614d490358c3ecbbf8b601d829543d3cd933c',
#   'artifacts/checkpoints/stage4/catboost/stage4de/tuning_c_flexible__config.json': 'c1be616b392447bcffecd08887209befe9cf8ae1b88bc27112b8d843384dfe58',
#   'artifacts/checkpoints/stage4/stage4a_notebook_heartbeat.json': '1c9eac57fa0787b1e35609ef3208fa19d0bd90669ea877be55b8420c51835049',
#   'artifacts/checkpoints/stage4/stage4a_progress.json': 'ecdf6c5a7e48990a9804f1fcc64eb0ed212cba91ee7929aabb939e74980d68ee',
#   'artifacts/checkpoints/stage4/stage4a_registry_smoke.csv': '22b94bdceea910d92bffc01dc879c6bbc89308cad58a7297fe8e905f035879e4',
#   'artifacts/checkpoints/stage4/stage4b_catboost_smoke.json': '64f54977321a11e8ec30ee33655e1a67c2a005bb6fb17d1011a5454cccbc02d5',
#   'artifacts/checkpoints/stage4/stage4b_lightgbm_smoke.json': '3feaec5f463b624b67c458bc9941d9c66dd2193659482a96ec1e630eb55a4d78',
#   'artifacts/checkpoints/stage4/stage4b_transformer_roundtrip.joblib': 'f81e05d8d70d953264e3e0b24fc19ddceba0ba8bc957fe687bb3eb5812d0b0f1',
#   'artifacts/checkpoints/stage4/stage4b_transformer_roundtrip_sample.csv': '76703e9d362ede1f12f6a0378f86cad93fe10f7507d9278b39cb8881eb5902f3',
#   'artifacts/checkpoints/stage4/stage4b_xgboost_smoke.json': '5d440765968df22dfa6123abf7a92d3acd26ea54847949d49b8dedf52e3b4e80',
#   'artifacts/checkpoints/stage4/timeout_smoke_heartbeat.json': '693b455aeb0d6a7c19286e3d39bab7e1f9ec54ca5c7dc7a5cce67a42a723535e',
#   'artifacts/data_contract/feature_inventory.csv': '2a4f85d8862d9ea3d49b85665f0650a3094111d0b08849b5908afed00238ae0e',
#   'artifacts/data_contract/feature_sets.json': '4af22330551216f04eab7da2f3677631e3aae8433ea7bf7052446445169308e3',
#   'artifacts/data_contract/leakage_and_suspicious_columns.csv': '800f117f596f04827f0de3d119ce763d4e1661e2836529863b4420e0659e25e7',
#   'artifacts/data_contract/metric_schema.json': '4f73596e5608d59747f119367daa12ed11408f334a6c1c7f52484c8306e2f853',
#   'artifacts/data_contract/source_hashes_after.json': '021dcb7d7dc46c43d37a638516055b261cdf26c508291a3c0d3862f1c1fcef27',
#   'artifacts/data_contract/source_hashes_before.json': '021dcb7d7dc46c43d37a638516055b261cdf26c508291a3c0d3862f1c1fcef27',
#   'artifacts/environment/stage4_packages/catboost-1.2.10.dist-info/INSTALLER': 'ceebae7b8927a3227e5303cf5e0f1f7b34bb542ad7250ac03fbcde36ec2f1508',
#   'artifacts/environment/stage4_packages/catboost-1.2.10.dist-info/METADATA': '85af1f342f4d02c92ef3a8930606c26197effe99b675144b1fd77bee63604350',
#   'artifacts/environment/stage4_packages/catboost-1.2.10.dist-info/RECORD': '36fac4b92eae5f1386a70b991eabac08e88d2ab720de14bf812877cc71a03268',
#   'artifacts/environment/stage4_packages/catboost-1.2.10.dist-info/REQUESTED': 'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855',
#   'artifacts/environment/stage4_packages/catboost-1.2.10.dist-info
#   'artifacts/results/stage4/catboost/initial/catboost_initial_screening.csv': '83a2a3ffaa77db7e23a59ee554999cc16c33db6937fb27359b9fcd339b749cae',
#   'artifacts/results/stage4/catboost/initial/catboost_preliminary_configuration.json': 'cf3f33a5218deb05baf26682aaa268cd85d8f8b45a38c239212a4bcb5eb03ebb',
#   'artifacts/results/stage4/catboost/initial/catboost_sensitive_comparison.csv': 'a456c94371a31fdadd238f5bf912073ec13458ea7bb5fb2b91b1ad11e5a267fc',
#   'artifacts/results/stage4/catboost/initial/catboost_tail_error.csv': 'aac6c87343908f21cc554a036b56c6dd5298c5e81ce8652bf769aa7e4b9a5fcc',
#   'artifacts/results/stage4/catboost/initial/stage4c_registry_rows.csv': '094fddd1de0c9dd092cb334447cf0a377e40e6d5bcf0b333443485cf2951327b',
#   'artifacts/runtime/stage4c_recovery/ipython/profile_default/startup/README': '638ec6b584245b2ea977392aca550d2fa7814993142111b04f15cf505fc10417',
#   'artifacts/runtime/stage4de_notebook/ipython/profile_default/startup/README': '638ec6b584245b2ea977392aca550d2fa7814993142111b04f15cf505fc10417',
#   'artifacts/splits/cv_fold_assignments.csv': 'c8401959ea98c61e20600fec3f5a014d66991821555bd575fa4d1bc7022278f0',
#   'artifacts/splits/prompt2_development_sample.csv': 'ace1d076e18310403f5e5bc83170ef67fcd6a9acd03a22c17bfeef5ad48873d3',
#   'artifacts/splits/split_config.json': 'e723f02a92fe3d252e0113c13263385449a0093edd34ac834f770852befae079',
#   'artifacts/splits/split_verification.json': '45e16e639f8e443ccdb6b3bca4c449e4731fecedd224b854c38be5f0408e7077',
#   'artifacts/splits/stage4/stage4_discovery_sample.csv': '79cf8051552f1edc1e68b9284d0a3ccfb49f5ceb3afd4b767a0da5dee372320e',
#   'artifacts/splits/stage4/stage4_feature_confirmation_sample.csv': '2dabbdc5e6b0fee9bc50e63feeb912e3096a5408cafbbf1685c1e00332380cf4',
#   'artifacts/splits/stage4/stage4_final_selection_sample.csv': '445a077b3fc1963bec38d8ba90384df2e1400e3897b25f0ecbfce78cb96c49ef',
#   'artifacts/splits/stage4/stage4_sample_verification.json': 'd3a83478bfcec4a9ae97690e8af0dcfb45768728b7e716817025b031638d7954',
#   'artifacts/splits/stage4/stage4c_screening_subset.csv': '0e34eb9899f00342beb04717b03829dc60b8dadc816d759636184256c606ec23',
#   'artifacts/splits/test_row_ids.csv': 'b01edf609d3102351b848d166e4db885da56db66a1fe441496e470dcf57770cb',
#   'artifacts/splits/train_row_ids.csv': '5abb11436c4661f304c3b06ade1882cbfd7689c8befcda756f6986f14ee13f26',
#   'build_prompt1_notebook.py': '89ff02b6bf83e6160cf389e83554f07a8bf5b367a88fb5d9353894afdaa21f1b',
#   'build_stage3_notebook.py': 'fdd26163142757112e07a059aea324ef84c253d8d5c97392c5a8cfb8fb35022b',
#   'build_stage4a_notebook.py': 'e81b901e7b028d709780cf5360952c8f63e7482189ab92cc261edd6c026efb92',
#   'build_stage4c_notebook.py': 'ebf642520a2fb8c469cd7e79dd9fd6889f8aeeed0546bce99f050ec053a8838c',
#   'build_stage4de_notebook.py': '4d7012d0d52a7e43fe1c4996fe99ce353a2abaaff3c519ab13238df84bacd083',
#   'capture_stage4de_baseline.py': '4460fba201246bc40617ff9c7c127ed534fd4134bf968c0807c2aa8d4c2f7ce6',
#   'data/regression_with_sensitive_features.csv': '6dc52dca5a8a7196a75213fab4a5a5c0a541f84390219459afb0b2be7b77aede',
#   'data/regression_without_sensitive_features.csv': 'e90f7bb49cce5584c7ab250c1db6a107de5cf640c7839f318d7f3cb995edd93c',
#   'extend_prompt2_notebook.py': 'e1f9b1bd64958ce19ddbc400a329432c6be8ab6310e217667a523e3f93e94bb5',
#   'finalize_prompt1.py': '817efaed871b10e10f2ed9c43b8ac7e04eb0c7dfedfb3741a6aa69413984359d',
#   'finalize_stage3_recovery.py': '36fe89f4a694407f5050ee4ef859854d3b357d9aa92183b755fbaaba5b76b41c',
#   'finalize_stage4b.py': 'c621d5b9c8d96217af4cd1af9247f324ccd838c78d66f101e9dde68e0bbc0d92',
#   'finalize_stage4c.py': '24df32a8b45e5532bd4aaf90453e02f60267640fdf07fa3727d585be9d030ca1',
#   'finalize_stage4de.py': '0c4660d9c9cf14d406e03d4c20951c7c41b8de5fe2c07a926090c88b25bff985',
#   'prepare_stage2_completion.py': 'cd849a59548eb87a9f7d6504e343d32f8c7b53353d99f1f7376c2d17ebe1596a',
#   'prepare_stage3_recovery_notebook.py': '301c97aa7212525643e5677e8297fd79e12f597f0ac3971de29a8c510657dfaa',
#   'prepare_stage4a_recovery.py': 'b7d11620a6c81adfccbb427e2435aad96bc2694b42e98a4c9071095353a90360',
#   'prepare_stage4b_extension.py': '18c62a97ad618235066eedb43562f3fac7d4f7ea9ddecac51f34b50f540e2ac5',
#   'prompt2_pipeline_utils.py': '2be740d8d678ab3b1c7295eded8f350ac191861859d3ebefcadfaf6c115d5ead',
#   'REGRESSION_PART2_MODELING.ipynb': 'c4fc258a56a87572cd5dde0ce661631241c32e9a3c650e1f6afd465c8e2cb072',
#   'REGRESSION_PART3_TREE_MODELS.ipynb': '1d677bb6f7a7ae800944241055940195beb6e29d57f8000c882935178c8fbf84',
#   'REGRESSION_PART4_BOOSTING_FOUNDATION.ipynb': '4ba6c0d8cfe823907cedb335d1f4f5321f199666c8f950359482fdbcb22b6688',
#   'REGRESSION_PART4_CATBOOST.ipynb': '9de78f070a470382bbe992107183e5632647b7f62a94803117df878706f4196a',
#   'run_stage4a_notebook.py': '5c41a351a542d7ca5574304e4cda0b529a8742ed4909d27719da6e2587271006',
#   'run_stage4b_notebook.py': '8fcd27a5f18b02b2a713db17d70b2b4a5fbc828940a706542bfce6950e3aa854',
#   'run_stage4c.py': '3c606784264d908bf0b7e05ef563fc51cbc5918bc08c1b0fe1e2b03b3ba03f00',
#   'run_stage4c_notebook.py': '6b76b0d7f571765bf7bdbf040e0cd32519b8837c717137c772b690b0d5492ac0',
#   'run_stage4c_recovery.py': '4426b70e7b0ee47827358e2104b3ba266c5d6714ae2b7a4b4a0bcd40a711f0fa',
#   'run_stage4de.py': '94aed815d97e447824964892959c88dca51d7cb3cbb2df262960bc485bd81cba',
#   'run_stage4de_notebook.py': '199be551272f0cfa9ccfe8114fb0bb311e1ae5db95a4eaa8fed7b80323151d6b',
#   'stage2_completion_summary.md': '31b07ae79827d98dd4793545878892c09551060d7f8623bd72946c2d1da03cc1',
#   'stage2_completion_tools.py': '47968a588b009242c0b96f164f516d9f6a80e419ef9bd69aa4415af5c03f501d',
#   'stage3_completion_summary.md': '8081cf843ed2a1ab57e438d06708c1386711037cf9496e3bd784540b0f52cec6',
#   'stage3_fold_worker.py': 'ab0e98748b751a4f02affe59fab53e3f2131e89d0862f1684891fc1b0ae3c748',
#   'stage3_notebook_runner.py': '952853c770d9a5c5ab40051b0d3a55a8c8c68de077bd23b8e8fd266ed2c20ff1',
#   'stage3_recovery_runner.py': '73732582c7abaabd155fe29cf6b9c42b0497c0e6666804f46771cf5a81b44c5d',
#   'stage3_recovery_utils.py': 'b5beb28278ac638b1a19b9cfd7e435be9690cc202b2a5ea00906b62a3ba9341d',
#   'stage3_tree_utils.py': '270ed40d82b589efda2217de0eeb58650cc7ac6e47ee9c35ed054fc08f726fb1',
#   'stage4_boosting_utils.py': '1a3fed96c76e25907750e664dbdb997e007361e32ab92ebd822bc264ab0daed2',
#   'stage4_catboost_utils.py': '3dfb3e1474317923df7ee71cac88c2b166fafee865763a804f532c46be5f31af',
#   'stage4_catboost_worker.py': 'b665707db7862ab1c186e11e3e1b2592b49617cb8e056e88b6a74f20053dd3b3',
#   'stage4b_clean_model_roundtrip.py': '662bdd0d8d0263c47d0d731e3c02dedc1c425e3d861141942c90f628e30d14ed',
#   'stage4b_feature_builder.py': 'cf0b64f2425f64e99950ddbde1ffda744325368fc45210b6027f977bc9e59f72',
#   'stage4de_catboost_utils.py': '71037d266789313fac863d4f34fd541f23fffae9b380ed088e367acdb2a504bd',
#   'stage4de_catboost_worker.py': 'abbe4a239f1df8165de7436893573b2a0f81c56bd66cfbd3cde1728baabaad90',
#   'verify_prompt2_models.py': '2548bcff5e6020d8b2002a96289cb2985bfcfb79b5546088b0d159bb66680b90'},
#  'mismatches': {},
#  'status': 'PASS'}

# %% [markdown]
# ### 4. Discovery Sample
#
# Reason: This section checks the saved evidence for Discovery Sample.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: The exact saved Discovery roles were used.

# %%
sample_check = show_json('artifacts/splits/stage4/stage4_sample_verification.json', ['source_train_rows','test_overlap_rows','samples','status'])
# Out:
# {'source_train_rows': 399788,
#  'test_overlap_rows': 0,
#  'samples': {'discovery': {'rows': 65000,
#    'train_rows': 50000,
#    'validation_rows': 15000,
#    'expected_rows': 65000,
#    'row_ids_unique': True,
#    'maximum_target_bin_proportion_difference': 8.993074021537706e-06,
#    'role_maximum_target_bin_proportion_difference': {'train': 1.2069997098462792e-05,
#     'validation': 3.2547250042522236e-05},
#    'sha256': '79cf8051552f1edc1e68b9284d0a3ccfb49f5ceb3afd4b767a0da5dee372320e',
#    'valid': True},
#   'feature_confirmation': {'rows': 100000,
#    'train_rows': 80000,
#    'validation_rows': 20000,
#    'expected_rows': 100000,
#    'row_ids_unique': True,
#    'maximum_target_bin_proportion_difference': 1.2069997098462792e-05,
#    'role_maximum_target_bin_proportion_difference': {'train': 7.06999709847167e-06,
#     'validation': 3.2069997098468916e-05},
#    'sha256': '2dabbdc5e6b0fee9bc50e63feeb912e3096a5408cafbbf1685c1e00332380cf4',
#    'valid': True},
#   'final_selection': {'rows': 125000,
#    'train_rows': 100000,
#    'validation_rows': 25000,
#    'expected_rows': 125000,
#    'row_ids_unique': True,
#    'maximum_target_bin_proportion_difference': 7.974866679333337e-06,
#    'role_maximum_target_bin_proportion_difference': {'train': 5.974866679345214e-06,
#     'validation': 1.5974866679341337e-05},
#    'sha256': '445a077b3fc1963bec38d8ba90384df2e1400e3897b25f0ecbfce78cb96c49ef',
#    'valid': True}},
#  'status': 'PASS'}

# %% [markdown]
# ### 5. LightGBM Feature Packs
#
# Reason: This section checks the saved evidence for LightGBM Feature Packs.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Only the two allowed Stage 4F packs were compared.

# %%
packs = show_json('artifacts/features/stage4/boosting_feature_packs.json', ['version'])
display({name: len(packs['packs'][name]['raw']) for name in ['boosting_base_v1','lightgbm_encoded_v1']})
# Out:
# {'version': 'stage4b_initial_boosting_packs_v1_20260714'}
# {'boosting_base_v1': 23, 'lightgbm_encoded_v1': 27}

# %% [markdown]
# ### 6. LightGBM Pipeline
#
# Reason: This section checks the saved evidence for LightGBM Pipeline.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: All learned mappings stayed inside each fitted Pipeline.

# %%
show_json('artifacts/checkpoints/stage4/stage4b_lightgbm_smoke.json', ['model','fit_rows','validation_rows','feature_name_count','serialization_reload_match','test_rows','status'])
# Out:
# {'model': 'lightgbm',
#  'fit_rows': 4000,
#  'validation_rows': 1000,
#  'feature_name_count': 35,
#  'serialization_reload_match': True,
#  'test_rows': 0,
#  'status': 'PASS'}
# {'stage': 'stage4b',
#  'version': 'stage4b_initial_boosting_packs_v1_20260714',
#  'model': 'lightgbm',
#  'package_available': True,
#  'fit_rows': 4000,
#  'validation_rows': 1000,
#  'total_rows': 5000,
#  'iterations_or_trees': 5,
#  'fit_seconds': 0.09084140000049956,
#  'finite_predictions': True,
#  'prediction_count': 1000,
#  'feature_name_count': 35,
#  'transformed_columns': 35,
#  'feature_names_stable': True,
#  'serialization_reload_match': True,
#  'row_order_preserved': True,
#  'source_frames_unchanged': True,
#  'representation_sparse': False,
#  'test_rows': 0,
#  'screening_performed': False,
#  'status': 'PASS'}

# %% [markdown]
# ### 7. Three Required Candidates
#
# Reason: This section checks the saved evidence for Three Required Candidates.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: All three required Candidates completed sequentially.

# %%
show_csv('artifacts/results/stage4/lightgbm/initial/lightgbm_initial_screening.csv', ['candidate_id','required','feature_pack','target_mode','mae','rmse','top_decile_mae','best_iteration'], 3)
# Out:
#                  candidate_id  required         feature_pack target_mode  \
# 0       candidate_01_base_raw      True     boosting_base_v1         raw
# 1    candidate_02_encoded_raw      True  lightgbm_encoded_v1         raw
# 2  candidate_03_encoded_log1p      True  lightgbm_encoded_v1       log1p
#
#          mae        rmse  top_decile_mae  best_iteration
# 0  65.313598  139.014434      205.638295            1259
# 1  64.604607  138.551284      202.700003            1499
# 2  64.322391  138.014576      205.739272            1474
#                       candidate_id  required         feature_pack target_mode  \
# 0            candidate_01_base_raw      True     boosting_base_v1         raw
# 1         candidate_02_encoded_raw      True  lightgbm_encoded_v1         raw
# 2       candidate_03_encoded_log1p      True  lightgbm_encoded_v1       log1p
# 3  candidate_04_safer_leaves23_raw     False  lightgbm_encoded_v1         raw
#
#    num_leaves  best_iteration  fit_time_seconds  prediction_time_seconds  \
# 0          31            1259          3.451557                 1.010985
# 1          31            1499          6.167098                 1.251105
# 2          31            1474          6.182766                 1.250069
# 3          23            1492          5.406063                 1.164148
#
#          mae           mse  ...  p90_absolute_error  negative_prediction_rate  \
# 0  65.313598  19325.012748  ...          138.768874                  0.004867
# 1  64.604607  19196.458397  ...          137.067743                  0.005067
# 2  64.322391  19048.023318  ...          137.098376                  0.000000
# 3  64.904466  19405.596626  ...          137.361170                  0.005000
#
#         mae_usd       rmse_usd  original_scale  top_decile_mae  \
# 0  65313.598402  139014.433597            True      205.638295
# 1  64604.606623  138551.284357            True      202.700003
# 2  64322.390765  138014.576468            True      205.739272
# 3  64904.466073  139303.972039            True      205.010825
#
#    top_five_percent_mae  underestimation_rate  overestimation_rate  mae_rank
# 0            297.261288              0.497067             0.502933         4
# 1            292.843458              0.503467             0.496533         2
# 2            295.859633              0.503533             0.496467         1
# 3            296.783960              0.501867             0.498133         3
#
# [4 rows x 28 columns]

# %% [markdown]
# ### 8. Optional Refinement
#
# Reason: This section checks the saved evidence for Optional Refinement.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: The one allowed safer refinement was rejected.

# %%
show_csv('artifacts/results/stage4/lightgbm/initial/lightgbm_initial_screening.csv', ['candidate_id','num_leaves','mae','top_decile_mae'], 4).tail(1)
# Out:
#                       candidate_id  num_leaves        mae  top_decile_mae
# 0            candidate_01_base_raw          31  65.313598      205.638295
# 1         candidate_02_encoded_raw          31  64.604607      202.700003
# 2       candidate_03_encoded_log1p          31  64.322391      205.739272
# 3  candidate_04_safer_leaves23_raw          23  64.904466      205.010825
#                       candidate_id  required         feature_pack target_mode  \
# 3  candidate_04_safer_leaves23_raw     False  lightgbm_encoded_v1         raw
#
#    num_leaves  best_iteration  fit_time_seconds  prediction_time_seconds  \
# 3          23            1492          5.406063                 1.164148
#
#          mae           mse  ...  p90_absolute_error  negative_prediction_rate  \
# 3  64.904466  19405.596626  ...           137.36117                     0.005
#
#         mae_usd       rmse_usd  original_scale  top_decile_mae  \
# 3  64904.466073  139303.972039            True      205.010825
#
#    top_five_percent_mae  underestimation_rate  overestimation_rate  mae_rank
# 3             296.78396              0.501867             0.498133         3
#
# [1 rows x 28 columns]

# %% [markdown]
# ### 9. Candidate Results
#
# Reason: This section checks the saved evidence for Candidate Results.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: The encoded raw-target Candidate won under the fixed tie rule.

# %%
show_csv('artifacts/results/stage4/lightgbm/initial/lightgbm_initial_screening.csv', ['candidate_id','mae','rmse','rmsle','rmsle_clipped_zero','top_decile_mae','fit_time_seconds'], 4)
# Out:
#                       candidate_id        mae        rmse     rmsle  \
# 0            candidate_01_base_raw  65.313598  139.014434       NaN
# 1         candidate_02_encoded_raw  64.604607  138.551284       NaN
# 2       candidate_03_encoded_log1p  64.322391  138.014576  0.400074
# 3  candidate_04_safer_leaves23_raw  64.904466  139.303972       NaN
#
#    rmsle_clipped_zero  top_decile_mae  fit_time_seconds
# 0            0.472937      205.638295          3.451557
# 1            0.462890      202.700003          6.167098
# 2            0.400074      205.739272          6.182766
# 3            0.463411      205.010825          5.406063
#                       candidate_id  required         feature_pack target_mode  \
# 0            candidate_01_base_raw      True     boosting_base_v1         raw
# 1         candidate_02_encoded_raw      True  lightgbm_encoded_v1         raw
# 2       candidate_03_encoded_log1p      True  lightgbm_encoded_v1       log1p
# 3  candidate_04_safer_leaves23_raw     False  lightgbm_encoded_v1         raw
#
#    num_leaves  best_iteration  fit_time_seconds  prediction_time_seconds  \
# 0          31            1259          3.451557                 1.010985
# 1          31            1499          6.167098                 1.251105
# 2          31            1474          6.182766                 1.250069
# 3          23            1492          5.406063                 1.164148
#
#          mae           mse  ...  p90_absolute_error  negative_prediction_rate  \
# 0  65.313598  19325.012748  ...          138.768874                  0.004867
# 1  64.604607  19196.458397  ...          137.067743                  0.005067
# 2  64.322391  19048.023318  ...          137.098376                  0.000000
# 3  64.904466  19405.596626  ...          137.361170                  0.005000
#
#         mae_usd       rmse_usd  original_scale  top_decile_mae  \
# 0  65313.598402  139014.433597            True      205.638295
# 1  64604.606623  138551.284357            True      202.700003
# 2  64322.390765  138014.576468            True      205.739272
# 3  64904.466073  139303.972039            True      205.010825
#
#    top_five_percent_mae  underestimation_rate  overestimation_rate  mae_rank
# 0            297.261288              0.497067             0.502933         4
# 1            292.843458              0.503467             0.496533         2
# 2            295.859633              0.503533             0.496467         1
# 3            296.783960              0.501867             0.498133         3
#
# [4 rows x 28 columns]

# %% [markdown]
# ### 10. Preliminary Configuration
#
# Reason: This section checks the saved evidence for Preliminary Configuration.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: The preliminary configuration is frozen.

# %%
show_json('artifacts/results/stage4/lightgbm/initial/lightgbm_preliminary_configuration.json', ['selected_candidate','selection_rule','feature_pack','target_mode','best_iteration','thread_count'])
# Out:
# {'selected_candidate': 'candidate_02_encoded_raw',
#  'selection_rule': 'Candidate 3 had 0.437% lower MAE, but the difference was below 0.5%; Candidate 2 had 1.48% lower top-decile MAE and the tie rule prefers raw target when effectively equal.',
#  'feature_pack': 'lightgbm_encoded_v1',
#  'target_mode': 'raw',
#  'best_iteration': 1499,
#  'thread_count': 2}
# {'stage_id': 'stage4f',
#  'stage_name': 'Stage 4F — Initial LightGBM Model and Importance Analysis',
#  'selected_candidate': 'candidate_02_encoded_raw',
#  'selection_rule': 'Candidate 3 had 0.437% lower MAE, but the difference was below 0.5%; Candidate 2 had 1.48% lower top-decile MAE and the tie rule prefers raw target when effectively equal.',
#  'feature_pack': 'lightgbm_encoded_v1',
#  'target_mode': 'raw',
#  'parameters': {'n_estimators': 1500,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'max_depth': -1,
#   'min_child_samples': 50,
#   'subsample': 0.8,
#   'subsample_freq': 1,
#   'colsample_bytree': 0.8,
#   'reg_alpha': 0.0,
#   'reg_lambda': 5.0,
#   'random_state': 42,
#   'n_jobs': 2,
#   'objective': 'regression_l1',
#   'verbosity': -1},
#  'best_iteration': 1499,
#  'random_seed': 42,
#  'thread_count': 2,
#  'encoding_policy': 'training-fit frequency encoding plus training-fit ordinal encoding inside the complete Pipeline',
#  'test_rows': 0}

# %% [markdown]
# ### 11. Preliminary Model Saving
#
# Reason: This section checks the saved evidence for Preliminary Model Saving.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Only the selected preliminary bundle was promoted.

# %%
show_json('artifacts/manifests/stage4/lightgbm/stage4f_preliminary_model_manifest.json', ['model_path','native_model_path','prediction_path','metrics','status'])
# Out:
# {'model_path': 'artifacts\\models\\lightgbm\\preliminary\\lightgbm_preliminary_without_sensitive.joblib',
#  'native_model_path': 'artifacts\\models\\lightgbm\\preliminary\\lightgbm_preliminary_without_sensitive.txt',
#  'prediction_path': 'artifacts\\predictions\\lightgbm\\initial\\lightgbm_preliminary_without_sensitive.csv',
#  'metrics': {'mae': 64.60460662344825,
#   'mse': 19196.458397110997,
#   'rmse': 138.55128435749342,
#   'mape_percent': 38.90762684701193,
#   'r_squared': 0.663108860373976,
#   'rmsle': None,
#   'rmsle_clipped_zero': 0.4628896928494735,
#   'median_absolute_error': 38.01791991371087,
#   'wape_percent': 26.20227414524823,
#   'mean_signed_error': -9.723597807992691,
#   'p90_absolute_error': 137.06774315741663,
#   'negative_prediction_rate': 0.005066666666666666,
#   'mae_usd': 64604.60662344825,
#   'rmse_usd': 138551.28435749342,
#   'original_scale': True,
#   'top_decile_mae': 202.70000253059425,
#   'top_five_percent_mae': 292.84345809387196,
#   'underestimation_rate': 0.5034666666666666,
#   'overestimation_rate': 0.4965333333333333},
#  'status': 'PASS'}
# {'stage_id': 'stage4f',
#  'selected_candidate': 'candidate_02_encoded_raw',
#  'model_path': 'artifacts\\models\\lightgbm\\preliminary\\lightgbm_preliminary_without_sensitive.joblib',
#  'native_model_path': 'artifacts\\models\\lightgbm\\preliminary\\lightgbm_preliminary_without_sensitive.txt',
#  'prediction_path': 'artifacts\\predictions\\lightgbm\\initial\\lightgbm_preliminary_without_sensitive.csv',
#  'model_sha256': 'c7d92160e1d79d7f7a3d36f26e55e3bc42d9b6424f99cc9dc06d3fa22fabc7d8',
#  'native_sha256': '8d46e68e51326fc3a26e9bcdbe65c17d013436a2db61362c1c115f72fd3892c0',
#  'prediction_sha256': '9fda6ea6559fe56522b5f3efefa870308304157c2fb672d1389cc8f872cb43a0',
#  'reference_predictions': 'artifacts\\predictions\\lightgbm\\initial\\lightgbm_preliminary_without_sensitive.csv',
#  'metrics': {'mae': 64.60460662344825,
#   'mse': 19196.458397110997,
#   'rmse': 138.55128435749342,
#   'mape_percent': 38.90762684701193,
#   'r_squared': 0.663108860373976,
#   'rmsle': None,
#   'rmsle_clipped_zero': 0.4628896928494735,
#   'median_absolute_error': 38.01791991371087,
#   'wape_percent': 26.20227414524823,
#   'mean_signed_error': -9.723597807992691,
#   'p90_absolute_error': 137.06774315741663,
#   'negative_prediction_rate': 0.005066666666666666,
#   'mae_usd': 64604.60662344825,
#   'rmse_usd': 138551.28435749342,
#   'original_scale': True,
#   'top_decile_mae': 202.70000253059425,
#   'top_five_percent_mae': 292.84345809387196,
#   'underestimation_rate': 0.5034666666666666,
#   'overestimation_rate': 0.4965333333333333},
#  'best_iteration': 1499,
#  'feature_names': ['numeric__applicant_income_000s',
#   'numeric__population',
#   'numeric__hud_median_family_income',
#   'numeric__number_of_owner_occupied_units',
#   'numeric__number_of_1_to_4_family_units',
#   'numeric__applicant_income_to_area_income',
#   'numeric__tract_income_ratio',
#   'numeric__owner_occupied_unit_ratio',
#   'numeric__family_units_per_1000_people',
#   'numeric__owner_occupied_units_per_1000_people',
#   'numeric__has_co_applicant',
#   'numeric__estimated_tract_family_income_000s',
#   'numeric__applicant_vs_area_income_gap_000s',
#   'numeric__respondent_id__frequency',
#   'numeric__msamd_name__frequency',
#   'numeric__county_name__frequency',
#   'numeric__census_tract_number__frequency',
#   'categorical__agency_name',
#   'categorical__loan_type_name',
#   'categorical__property_type_name',
#   'categorical__loan_purpose_name',
#   'categorical__owner_occupancy_name',
#   'categorical__preapproval_name',
#   'categorical__state_name',
#   'categorical__lien_status_name',
#   'categorical__loan_program_group',
#   'categorical__applicant_income_area_group',
#   'categorical__tract_income_level',
#   'categorical__us_region',
#   'categorical__purpose_lien_status_group',
#   'categorical__occupancy_lien_status_group',
#   'categorical__loan_type_lien_status_group',
#   'categorical__state_lien_status_group',
#   'categorical__property_purpose_group',
#   'categorical__agency_lien_status_group'],
#  'reload_report': 'artifacts\\reports\\stage4f_preliminary_reload.json',
#  'status': 'PASS'}

# %% [markdown]
# ### 12. Clean Reload
#
# Reason: This section checks the saved evidence for Clean Reload.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: The preliminary bundle and native Booster reload correctly.

# %%
show_json('artifacts/reports/stage4f_preliminary_reload.json', ['rows','finite_predictions','source_frame_unchanged','reference_prediction_match','native_prediction_match','status'])
# Out:
# {'rows': 500,
#  'finite_predictions': True,
#  'source_frame_unchanged': True,
#  'reference_prediction_match': True,
#  'native_prediction_match': True,
#  'status': 'PASS'}
# {'model_path': 'D:\\SHARIF\\TERM7\\DATA\\PROJECT\\regresionpart2\\artifacts\\models\\lightgbm\\preliminary\\lightgbm_preliminary_without_sensitive.joblib',
#  'native_model_path': 'D:\\SHARIF\\TERM7\\DATA\\PROJECT\\regresionpart2\\artifacts\\models\\lightgbm\\preliminary\\lightgbm_preliminary_without_sensitive.txt',
#  'prediction_path': 'D:\\SHARIF\\TERM7\\DATA\\PROJECT\\regresionpart2\\artifacts\\predictions\\lightgbm\\initial\\lightgbm_preliminary_without_sensitive.csv',
#  'rows': 500,
#  'finite_predictions': True,
#  'output_length_matches': True,
#  'source_frame_unchanged': True,
#  'reference_prediction_match': True,
#  'native_prediction_match': True,
#  'inverse_target_verified': True,
#  'native_booster_loaded': True,
#  'status': 'PASS'}

# %% [markdown]
# ### 13. Gain and Split Importance
#
# Reason: This section checks the saved evidence for Gain and Split Importance.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Income, local-income, lien, and geography signals lead Importance.

# %%
show_csv('artifacts/features/stage4/lightgbm/stage4f_importance_top20.csv', ['source_feature','feature_origin','gain_importance','split_importance'], 10)
# Out:
#                        source_feature      feature_origin  gain_importance  \
# 0               applicant_income_000s            original    131695.885405
# 1                    lien_status_name            original     54830.640569
# 2  estimated_tract_family_income_000s  stage4b_engineered     54519.324910
# 3            hud_median_family_income            original     35933.634517
# 4                           us_region            original     31931.682809
# 5   applicant_vs_area_income_gap_000s  stage4b_engineered     31616.938190
# 6     applicant_income_to_area_income            original     28872.978832
# 7              property_purpose_group  stage4b_engineered     26611.248791
# 8                         county_name    high_cardinality     21570.643809
# 9                       respondent_id    high_cardinality     21227.478898
#
#    split_importance
# 0              2829
# 1               301
# 2              2511
# 3              1995
# 4               610
# 5              2051
# 6              2311
# 7               365
# 8              2282
# 9              3095
#                           source_feature      feature_origin  gain_importance  \
# 0                  applicant_income_000s            original    131695.885405
# 1                       lien_status_name            original     54830.640569
# 2     estimated_tract_family_income_000s  stage4b_engineered     54519.324910
# 3               hud_median_family_income            original     35933.634517
# 4                              us_region            original     31931.682809
# 5      applicant_vs_area_income_gap_000s  stage4b_engineered     31616.938190
# 6        applicant_income_to_area_income            original     28872.978832
# 7                 property_purpose_group  stage4b_engineered     26611.248791
# 8                            county_name    high_cardinality     21570.643809
# 9                          respondent_id    high_cardinality     21227.478898
# 10          family_units_per_1000_people            original     19954.659547
# 11                            msamd_name    high_cardinality     19664.882897
# 12             owner_occupied_unit_ratio            original     17590.685124
# 13           occupancy_lien_status_group  stage4b_engineered     16833.731791
# 14                    tract_income_ratio            original     15809.612765
# 15             purpose_lien_status_group  stage4b_engineered     15638.090383
# 16                            population            original     14930.656323
# 17  owner_occupied_units_per_1000_people            original     14892.410133
# 18        number_of_owner_occupied_units            original     13886.216236
# 19         number_of_1_to_4_family_units            original     13828.766364
#
#     split_importance
# 0               2829
# 1                301
# 2               2511
# 3               1995
# 4                610
# 5               2051
# 6               2311
# 7                365
# 8               2282
# 9               3095
# 10              2525
# 11              1987
# 12              2509
# 13               333
# 14              2389
# 15               423
# 16              2328
# 17              2309
# 18              2118
# 19              2112

# %% [markdown]
# ### 14. Bounded SHAP
#
# Reason: This section checks the saved evidence for Bounded SHAP.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Bounded Tree SHAP supports the same broad signal pattern.

# %%
show_csv('artifacts/features/stage4/lightgbm/stage4f_shap_top20.csv', ['source_feature','mean_absolute_shap'], 10)
display(Image(filename=str(ROOT / 'artifacts/figures/stage4/lightgbm/stage4f_shap_summary.png')))
# Out:
#                        source_feature  mean_absolute_shap
# 0               applicant_income_000s           56.309610
# 1  estimated_tract_family_income_000s           30.796845
# 2                           us_region           22.074960
# 3                    lien_status_name           14.974798
# 4            hud_median_family_income           14.858143
# 5              property_purpose_group           11.005612
# 6   applicant_vs_area_income_gap_000s           10.155437
# 7         occupancy_lien_status_group            8.673513
# 8           purpose_lien_status_group            7.868090
# 9                          state_name            7.350388

# %% [markdown]
# ### 15. Error Analysis
#
# Reason: This section checks the saved evidence for Error Analysis.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: The extreme target tail remains the hardest region.

# %%
show_csv('artifacts/results/stage4/lightgbm/initial/stage4f_error_by_target_decile.csv', None, 10)
show_json('artifacts/results/stage4/lightgbm/initial/stage4f_error_summary.json')
# Out:
#    target_decile  rows         mae  mean_signed_error  underestimation_rate  \
# 0              1  1502   31.155278          24.411229              0.278961
# 1              2  1517   43.474814          36.139638              0.199077
# 2              3  1493   41.402619          27.056241              0.335566
# 3              4  1515   39.489238          19.591935              0.411881
# 4              5  1485   39.212441           9.788914              0.477441
# 5              6  1491   47.498839           6.750380              0.539235
# 6              7  1503   51.647818          -8.984547              0.622754
# 7              8  1513   65.181295         -18.948825              0.656312
# 8              9  1483   84.116830         -36.850778              0.700607
# 9             10  1498  203.364352        -157.008357              0.817757
#
#    overestimation_rate
# 0             0.721039
# 1             0.800923
# 2             0.664434
# 3             0.588119
# 4             0.522559
# 5             0.460765
# 6             0.377246
# 7             0.343688
# 8             0.299393
# 9             0.182243
# {'top_decile_mae': 202.70000253059425,
#  'top_five_percent_mae': 292.84345809387196,
#  'underestimation_rate': 0.5034666666666666,
#  'overestimation_rate': 0.4965333333333333,
#  'worst_decile_by_mae': 10,
#  'status': 'PASS'}
# {'top_decile_mae': 202.70000253059425,
#  'top_five_percent_mae': 292.84345809387196,
#  'underestimation_rate': 0.5034666666666666,
#  'overestimation_rate': 0.4965333333333333,
#  'worst_decile_by_mae': 10,
#  'status': 'PASS'}

# %% [markdown]
# ### 16. Stage 4G Feature Proposals
#
# Reason: This section checks the saved evidence for Stage 4G Feature Proposals.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Three safe proposals moved to independent confirmation.

# %%
show_csv('artifacts/features/stage4/lightgbm/stage4f_feature_proposals.csv', ['name','expected_benefit','target_derived','sensitive_derived','leakage_review'], 3)
# Out:
#                                         name  \
# 0  applicant_to_estimated_tract_income_ratio
# 1                   respondent_purpose_group
# 2              income_band_lien_status_group
#
#                                     expected_benefit  target_derived  \
# 0  Adds a direct applicant-versus-local-income sc...           False
# 1  Lets the model distinguish lender-purpose conc...           False
# 2  Adds a compact nonlinear interaction that may ...           False
#
#    sensitive_derived                                     leakage_review
# 0              False  PASS: uses current-row non-sensitive predictor...
# 1              False  PASS: frequency mapping fits on training rows ...
# 2              False  PASS: quantiles fit on non-sensitive training ...
#                                         name  \
# 0  applicant_to_estimated_tract_income_ratio
# 1                   respondent_purpose_group
# 2              income_band_lien_status_group
#
#                                              formula  \
# 0  applicant_income_000s / max(abs(estimated_trac...
# 1  respondent_id + ' | ' + loan_purpose_name, the...
# 2  training-fit applicant-income quantile band + ...
#
#                                       source_columns  \
# 0  applicant_income_000s|hud_median_family_income...
# 1                    respondent_id|loan_purpose_name
# 2             applicant_income_000s|lien_status_name
#
#                                             evidence  \
# 0  Income and area-income signals appear in gain/...
# 1  High-cardinality frequency and loan-purpose ev...
# 2  Income/lien structure is important and signed ...
#
#                                     expected_benefit  \
# 0  Adds a direct applicant-versus-local-income sc...
# 1  Lets the model distinguish lender-purpose conc...
# 2  Adds a compact nonlinear interaction that may ...
#
#                                     fixed_or_learned  \
# 0                 fixed safe ratio; epsilon is fixed
# 1  fixed interaction plus training-fit frequency ...
# 2  training-fit income quantiles inside Pipeline ...
#
#                                     missing_handling  \
# 0  Missing or non-finite source gives missing for...
# 1  Missing parts use <MISSING>; unseen Validation...
# 2  Missing income or lien uses <MISSING>; unseen ...
#
#                            zero_denominator_handling  target_derived  \
# 0  Use epsilon only for finite near-zero denomina...           False
# 1                                    Not applicable.           False
# 2                                    Not applicable.           False
#
#    sensitive_derived                                     leakage_review  \
# 0              False  PASS: uses current-row non-sensitive predictor...
# 1              False  PASS: frequency mapping fits on training rows ...
# 2              False  PASS: quantiles fit on non-sensitive training ...
#
#                                     duplicate_review
# 0  PASS: not present in Stage 4B packs; not an ex...
# 1      PASS: the pair is absent from Stage 4B packs.
# 2      PASS: the pair is absent from Stage 4B packs.

# %% [markdown]
# ### 17. Stage 4F Gate Summary
#
# Reason: This section checks the saved evidence for Stage 4F Gate Summary.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Stage 4F Gate reports PASS.

# %%
show_json('artifacts/reports/stage4f_gate_verification.json', ['candidate_count','optional_refinement_count','selected_candidate','checks','status'])
# Out:
# {'candidate_count': 4,
#  'optional_refinement_count': 1,
#  'selected_candidate': 'candidate_02_encoded_raw',
#  'checks': {'discovery_sample_valid': True,
#   'zero_test_overlap': True,
#   'three_required_candidates_complete': True,
#   'candidate_count_at_most_four': True,
#   'raw_and_log_targets_evaluated': True,
#   'preliminary_configuration_frozen': True,
#   'preliminary_model_saved': True,
#   'clean_reload_pass': True,
#   'gain_importance_exists': True,
#   'split_importance_exists': True,
#   'bounded_shap_exists': True,
#   'error_analysis_exists': True,
#   'safe_feature_proposals_at_most_three': True,
#   'registry_ids_unique': True,
#   'prior_registry_rows_preserved': True,
#   'protected_hashes_unchanged': True},
#  'status': 'PASS'}
# {'stage_id': 'stage4f',
#  'stage_name': 'Stage 4F — Initial LightGBM Model and Importance Analysis',
#  'created_at_utc': '2026-07-14T17:51:00.372621+00:00',
#  'candidate_count': 4,
#  'required_candidate_count': 3,
#  'optional_refinement_count': 1,
#  'selected_candidate': 'candidate_02_encoded_raw',
#  'checks': {'discovery_sample_valid': True,
#   'zero_test_overlap': True,
#   'three_required_candidates_complete': True,
#   'candidate_count_at_most_four': True,
#   'raw_and_log_targets_evaluated': True,
#   'preliminary_configuration_frozen': True,
#   'preliminary_model_saved': True,
#   'clean_reload_pass': True,
#   'gain_importance_exists': True,
#   'split_importance_exists': True,
#   'bounded_shap_exists': True,
#   'error_analysis_exists': True,
#   'safe_feature_proposals_at_most_three': True,
#   'registry_ids_unique': True,
#   'prior_registry_rows_preserved': True,
#   'protected_hashes_unchanged': True},
#  'status': 'PASS',
#  'runtime_seconds': 8.785763300009421}

# %% [markdown]
# ## Stage 4G — Feature Confirmation and Final Tuning
#
# ### 18. Stage 4G Objective
#
# Reason: Stage 4G uses independent non-sensitive samples for Feature confirmation and tuning.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Stage 4G keeps all selection non-sensitive.

# %%
print({'selection_mode': 'without_sensitive', 'confirmation_rows': '80000/20000', 'tuning_rows': '100000/25000', 'test_rows': 0})
# Out:
# {'selection_mode': 'without_sensitive', 'confirmation_rows': '80000/20000', 'tuning_rows': '100000/25000', 'test_rows': 0}

# %% [markdown]
# ### 19. Stage 4F Gate Validation
#
# Reason: This section checks the saved evidence for Stage 4F Gate Validation.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Stage 4G started only after Stage 4F PASS.

# %%
show_json('artifacts/reports/stage4f_gate_verification.json', ['status'])
# Out:
# {'status': 'PASS'}
# {'stage_id': 'stage4f',
#  'stage_name': 'Stage 4F — Initial LightGBM Model and Importance Analysis',
#  'created_at_utc': '2026-07-14T17:51:00.372621+00:00',
#  'candidate_count': 4,
#  'required_candidate_count': 3,
#  'optional_refinement_count': 1,
#  'selected_candidate': 'candidate_02_encoded_raw',
#  'checks': {'discovery_sample_valid': True,
#   'zero_test_overlap': True,
#   'three_required_candidates_complete': True,
#   'candidate_count_at_most_four': True,
#   'raw_and_log_targets_evaluated': True,
#   'preliminary_configuration_frozen': True,
#   'preliminary_model_saved': True,
#   'clean_reload_pass': True,
#   'gain_importance_exists': True,
#   'split_importance_exists': True,
#   'bounded_shap_exists': True,
#   'error_analysis_exists': True,
#   'safe_feature_proposals_at_most_three': True,
#   'registry_ids_unique': True,
#   'prior_registry_rows_preserved': True,
#   'protected_hashes_unchanged': True},
#  'status': 'PASS',
#  'runtime_seconds': 8.785763300009421}

# %% [markdown]
# ### 20. Feature Proposal Review
#
# Reason: This section checks the saved evidence for Feature Proposal Review.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: All proposals passed safety review before testing.

# %%
show_csv('artifacts/features/stage4/lightgbm/stage4g_proposal_review.csv', ['name','formula_valid','target_independent','sensitive_independent','approved_for_confirmation','final_status'], 3)
# Out:
#                                         name  formula_valid  \
# 0  applicant_to_estimated_tract_income_ratio           True
# 1                   respondent_purpose_group           True
# 2              income_band_lien_status_group           True
#
#    target_independent  sensitive_independent  approved_for_confirmation  \
# 0                True                   True                       True
# 1                True                   True                       True
# 2                True                   True                       True
#
#                            final_status
# 0  REJECTED_BY_INDEPENDENT_CONFIRMATION
# 1  REJECTED_BY_INDEPENDENT_CONFIRMATION
# 2  REJECTED_BY_INDEPENDENT_CONFIRMATION
#                                         name  \
# 0  applicant_to_estimated_tract_income_ratio
# 1                   respondent_purpose_group
# 2              income_band_lien_status_group
#
#                                              formula  \
# 0  applicant_income_000s / max(abs(estimated_trac...
# 1  respondent_id + ' | ' + loan_purpose_name, the...
# 2  training-fit applicant-income quantile band + ...
#
#                                       source_columns  \
# 0  applicant_income_000s|hud_median_family_income...
# 1                    respondent_id|loan_purpose_name
# 2             applicant_income_000s|lien_status_name
#
#                                             evidence  \
# 0  Income and area-income signals appear in gain/...
# 1  High-cardinality frequency and loan-purpose ev...
# 2  Income/lien structure is important and signed ...
#
#                                     expected_benefit  \
# 0  Adds a direct applicant-versus-local-income sc...
# 1  Lets the model distinguish lender-purpose conc...
# 2  Adds a compact nonlinear interaction that may ...
#
#                                     fixed_or_learned  \
# 0                 fixed safe ratio; epsilon is fixed
# 1  fixed interaction plus training-fit frequency ...
# 2  training-fit income quantiles inside Pipeline ...
#
#                                     missing_handling  \
# 0  Missing or non-finite source gives missing for...
# 1  Missing parts use <MISSING>; unseen Validation...
# 2  Missing income or lien uses <MISSING>; unseen ...
#
#                            zero_denominator_handling  target_derived  \
# 0  Use epsilon only for finite near-zero denomina...           False
# 1                                    Not applicable.           False
# 2                                    Not applicable.           False
#
#    sensitive_derived                                     leakage_review  \
# 0              False  PASS: uses current-row non-sensitive predictor...
# 1              False  PASS: frequency mapping fits on training rows ...
# 2              False  PASS: quantiles fit on non-sensitive training ...
#
#                                     duplicate_review  formula_valid  \
# 0  PASS: not present in Stage 4B packs; not an ex...           True
# 1      PASS: the pair is absent from Stage 4B packs.           True
# 2      PASS: the pair is absent from Stage 4B packs.           True
#
#    sources_available  target_independent  sensitive_independent  \
# 0               True                True                   True
# 1               True                True                   True
# 2               True                True                   True
#
#    approved_for_confirmation  accepted_after_confirmation  \
# 0                       True                        False
# 1                       True                        False
# 2                       True                        False
#
#                            final_status
# 0  REJECTED_BY_INDEPENDENT_CONFIRMATION
# 1  REJECTED_BY_INDEPENDENT_CONFIRMATION
# 2  REJECTED_BY_INDEPENDENT_CONFIRMATION

# %% [markdown]
# ### 21. LightGBM Feature Engineer v2
#
# Reason: This section checks the saved evidence for LightGBM Feature Engineer v2.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Feature Engineer v2 is serializable and does not mutate inputs.

# %%
show_json('artifacts/reports/stage4g_feature_engineer_v2_roundtrip.json', ['feature_engineer_version','fit_rows','check_rows','source_unchanged','row_order_preserved','stable_columns','joblib_reload','status'])
# Out:
# {'feature_engineer_version': 'lightgbm_feature_engineer_v2_20260714',
#  'fit_rows': 200,
#  'check_rows': 50,
#  'source_unchanged': True,
#  'row_order_preserved': True,
#  'stable_columns': True,
#  'joblib_reload': True,
#  'status': 'PASS'}
# {'stage_id': 'stage4g',
#  'feature_engineer_version': 'lightgbm_feature_engineer_v2_20260714',
#  'selected_proposals': ['applicant_to_estimated_tract_income_ratio',
#   'respondent_purpose_group',
#   'income_band_lien_status_group'],
#  'fit_rows': 200,
#  'check_rows': 50,
#  'source_unchanged': True,
#  'row_order_preserved': True,
#  'stable_columns': True,
#  'joblib_reload': True,
#  'clean_process_return_code': 0,
#  'clean_process_stdout': 'PASS 50 39\n',
#  'clean_process_stderr': '',
#  'target_used': False,
#  'sensitive_sources_used': False,
#  'status': 'PASS'}

# %% [markdown]
# ### 22. Feature Confirmation Sample
#
# Reason: This section checks the saved evidence for Feature Confirmation Sample.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: The independent 80,000/20,000 roles were used.

# %%
display(sample_check['samples']['feature_confirmation'])
# Out:
# {'rows': 100000,
#  'train_rows': 80000,
#  'validation_rows': 20000,
#  'expected_rows': 100000,
#  'row_ids_unique': True,
#  'maximum_target_bin_proportion_difference': 1.2069997098462792e-05,
#  'role_maximum_target_bin_proportion_difference': {'train': 7.06999709847167e-06,
#   'validation': 3.2069997098468916e-05},
#  'sha256': '2dabbdc5e6b0fee9bc50e63feeb912e3096a5408cafbbf1685c1e00332380cf4',
#  'valid': True}

# %% [markdown]
# ### 23. Lean Feature Confirmation
#
# Reason: This section checks the saved evidence for Lean Feature Confirmation.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Neither combined nor ratio-only v2 met acceptance rules.

# %%
show_csv('artifacts/results/stage4/lightgbm/feature_confirmation/lightgbm_feature_confirmation_results.csv', None, 3)
# Out:
#                          fit_id                  feature_pack  \
# 0         confirmation_original           lightgbm_encoded_v1
# 1      confirmation_combined_v2  lightgbm_encoded_v2_combined
# 2  confirmation_ratio_rescue_v2     lightgbm_encoded_v2_ratio
#
#                                   selected_proposals        mae  \
# 0                                                NaN  65.216082
# 1  applicant_to_estimated_tract_income_ratio|resp...  65.085851
# 2          applicant_to_estimated_tract_income_ratio  65.131164
#
#    mae_change_percent_vs_original        rmse  \
# 0                        0.000000  136.944704
# 1                       -0.199693  137.362228
# 2                       -0.130211  136.855877
#
#    rmse_change_percent_vs_original  top_decile_mae  \
# 0                         0.000000      206.705861
# 1                         0.304885      206.496610
# 2                        -0.064863      206.368943
#
#    top_decile_change_percent_vs_original  p90_absolute_error  \
# 0                               0.000000          137.717701
# 1                              -0.101231          138.757580
# 2                              -0.162994          138.477112
#
#    mean_signed_error  fit_time_seconds  best_iteration
# 0          -8.365230         10.883856            1500
# 1          -8.600328         11.153973            1499
# 2          -8.454009         10.546426            1483
#                          fit_id                  feature_pack  \
# 0         confirmation_original           lightgbm_encoded_v1
# 1      confirmation_combined_v2  lightgbm_encoded_v2_combined
# 2  confirmation_ratio_rescue_v2     lightgbm_encoded_v2_ratio
#
#                                   selected_proposals        mae  \
# 0                                                NaN  65.216082
# 1  applicant_to_estimated_tract_income_ratio|resp...  65.085851
# 2          applicant_to_estimated_tract_income_ratio  65.131164
#
#    mae_change_percent_vs_original        rmse  \
# 0                        0.000000  136.944704
# 1                       -0.199693  137.362228
# 2                       -0.130211  136.855877
#
#    rmse_change_percent_vs_original  top_decile_mae  \
# 0                         0.000000      206.705861
# 1                         0.304885      206.496610
# 2                        -0.064863      206.368943
#
#    top_decile_change_percent_vs_original  p90_absolute_error  \
# 0                               0.000000          137.717701
# 1                              -0.101231          138.757580
# 2                              -0.162994          138.477112
#
#    mean_signed_error  fit_time_seconds  best_iteration
# 0          -8.365230         10.883856            1500
# 1          -8.600328         11.153973            1499
# 2          -8.454009         10.546426            1483

# %% [markdown]
# ### 24. Final Feature Pack
#
# Reason: This section checks the saved evidence for Final Feature Pack.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: The original encoded pack remained final.

# %%
show_json('artifacts/results/stage4/lightgbm/feature_confirmation/lightgbm_final_feature_pack.json', ['accepted_features','rejected_features','final_feature_pack','reason','status'])
# Out:
# {'accepted_features': [],
#  'rejected_features': ['applicant_to_estimated_tract_income_ratio',
#   'respondent_purpose_group',
#   'income_band_lien_status_group'],
#  'final_feature_pack': 'lightgbm_encoded_v1',
#  'reason': 'Combined v2 improved MAE by only 0.200% and worsened RMSE, P90 error, and signed bias. The ratio-only rescue improved MAE by only 0.130% and tail MAE by only 0.163%, while P90 and signed bias worsened. Neither met the main, tail, or stability rule.',
#  'status': 'PASS'}
# {'stage_id': 'stage4g',
#  'original_feature_pack': 'lightgbm_encoded_v1',
#  'combined_feature_pack': 'lightgbm_encoded_v2_combined',
#  'optional_rescue_feature_pack': 'lightgbm_encoded_v2_ratio',
#  'accepted_features': [],
#  'rejected_features': ['applicant_to_estimated_tract_income_ratio',
#   'respondent_purpose_group',
#   'income_band_lien_status_group'],
#  'final_feature_pack': 'lightgbm_encoded_v1',
#  'selected_proposals': [],
#  'reason': 'Combined v2 improved MAE by only 0.200% and worsened RMSE, P90 error, and signed bias. The ratio-only rescue improved MAE by only 0.130% and tail MAE by only 0.163%, while P90 and signed bias worsened. Neither met the main, tail, or stability rule.',
#  'acceptance_rules': {'main_mae_improvement_percent': 0.5,
#   'tail_improvement_percent': 2.0,
#   'maximum_overall_worsening_percent': 0.2},
#  'fit_count': 3,
#  'sensitive_mode': 'without_sensitive',
#  'test_rows': 0,
#  'status': 'PASS'}

# %% [markdown]
# ### 25. Final Selection Sample
#
# Reason: This section checks the saved evidence for Final Selection Sample.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: The independent 100,000/25,000 roles were used.

# %%
display(sample_check['samples']['final_selection'])
# Out:
# {'rows': 125000,
#  'train_rows': 100000,
#  'validation_rows': 25000,
#  'expected_rows': 125000,
#  'row_ids_unique': True,
#  'maximum_target_bin_proportion_difference': 7.974866679333337e-06,
#  'role_maximum_target_bin_proportion_difference': {'train': 5.974866679345214e-06,
#   'validation': 1.5974866679341337e-05},
#  'sha256': '445a077b3fc1963bec38d8ba90384df2e1400e3897b25f0ecbfce78cb96c49ef',
#  'valid': True}

# %% [markdown]
# ### 26. Three Final Tuning Candidates
#
# Reason: This section checks the saved evidence for Three Final Tuning Candidates.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Exactly three tuning Candidates completed.

# %%
show_csv('artifacts/results/stage4/lightgbm/final/lightgbm_final_tuning_results.csv', ['candidate_id','num_leaves','min_child_samples','reg_lambda','mae','rmse','top_decile_mae','best_iteration'], 3)
# Out:
#         candidate_id  num_leaves  min_child_samples  reg_lambda        mae  \
# 0  tuning_a_baseline          31                 50         5.0  64.783622
# 1     tuning_b_safer          23                 80        10.0  64.964520
# 2  tuning_c_flexible          47                 50         5.0  64.456751
#
#          rmse  top_decile_mae  best_iteration
# 0  133.257522      204.055699            1500
# 1  134.262362      204.946252            1499
# 2  131.956170      203.032071            1500
#         candidate_id  num_leaves  min_child_samples  reg_lambda  \
# 0  tuning_a_baseline          31                 50         5.0
# 1     tuning_b_safer          23                 80        10.0
# 2  tuning_c_flexible          47                 50         5.0
#
#    best_iteration  fit_time_seconds        mae           mse        rmse  \
# 0            1500         12.596510  64.783622  17757.567082  133.257522
# 1            1499         11.574149  64.964520  18026.381732  134.262362
# 2            1500         14.205618  64.456751  17412.430780  131.956170
#
#    mape_percent  ...  p90_absolute_error  negative_prediction_rate  \
# 0     38.712147  ...          137.477174                   0.00492
# 1     38.677460  ...          137.270940                   0.00544
# 2     38.233347  ...          137.075353                   0.00456
#
#         mae_usd       rmse_usd  original_scale  top_decile_mae  \
# 0  64783.622151  133257.521670            True      204.055699
# 1  64964.519972  134262.361563            True      204.946252
# 2  64456.751122  131956.169919            True      203.032071
#
#    top_five_percent_mae  underestimation_rate  overestimation_rate  mae_rank
# 0            299.120778               0.49968              0.50032         2
# 1            300.720083               0.50000              0.50000         3
# 2            297.460231               0.49732              0.50268         1
#
# [3 rows x 26 columns]

# %% [markdown]
# ### 27. Final Non-Sensitive Configuration
#
# Reason: This section checks the saved evidence for Final Non-Sensitive Configuration.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Candidate C froze 47 leaves and 1,500 iterations.

# %%
show_json('artifacts/results/stage4/lightgbm/final/lightgbm_final_configuration.json', ['selected_candidate','selection_reason','feature_pack','target_mode','parameters','fixed_iteration','thread_count','status'])
# Out:
# {'selected_candidate': 'tuning_c_flexible',
#  'selection_reason': 'Candidate C had the lowest MAE, tail MAE, RMSE, clipped-zero RMSLE, and better signed error than the baseline; the MAE gain exceeded the 0.25 percent tie band.',
#  'feature_pack': 'lightgbm_encoded_v1',
#  'target_mode': 'raw',
#  'parameters': {'n_estimators': 1500,
#   'learning_rate': 0.05,
#   'num_leaves': 47,
#   'max_depth': -1,
#   'min_child_samples': 50,
#   'subsample': 0.8,
#   'subsample_freq': 1,
#   'colsample_bytree': 0.8,
#   'reg_alpha': 0.0,
#   'reg_lambda': 5.0,
#   'random_state': 42,
#   'n_jobs': 2,
#   'objective': 'regression_l1',
#   'verbosity': -1},
#  'fixed_iteration': 1500,
#  'thread_count': 2,
#  'status': 'FROZEN'}
# {'stage_id': 'stage4g',
#  'stage_name': 'Stage 4G — LightGBM Feature Confirmation and Final Tuning',
#  'selected_candidate': 'tuning_c_flexible',
#  'selection_reason': 'Candidate C had the lowest MAE, tail MAE, RMSE, clipped-zero RMSLE, and better signed error than the baseline; the MAE gain exceeded the 0.25 percent tie band.',
#  'feature_pack': 'lightgbm_encoded_v1',
#  'selected_proposals': [],
#  'accepted_features': [],
#  'rejected_features': ['applicant_to_estimated_tract_income_ratio',
#   'respondent_purpose_group',
#   'income_band_lien_status_group'],
#  'target_mode': 'raw',
#  'parameters': {'n_estimators': 1500,
#   'learning_rate': 0.05,
#   'num_leaves': 47,
#   'max_depth': -1,
#   'min_child_samples': 50,
#   'subsample': 0.8,
#   'subsample_freq': 1,
#   'colsample_bytree': 0.8,
#   'reg_alpha': 0.0,
#   'reg_lambda': 5.0,
#   'random_state': 42,
#   'n_jobs': 2,
#   'objective': 'regression_l1',
#   'verbosity': -1},
#  'fixed_iteration': 1500,
#  'random_seed': 42,
#  'thread_count': 2,
#  'encoding_policy': 'training-fit frequency and ordinal mappings inside each complete Pipeline',
#  'sensitive_selection_used': False,
#  'test_rows': 0,
#  'status': 'FROZEN'}

# %% [markdown]
# ### 28. Winning Non-Sensitive Validation Model
#
# Reason: This section checks the saved evidence for Winning Non-Sensitive Validation Model.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: The winning non-sensitive model is saved for reuse.

# %%
show_json('artifacts/manifests/stage4/lightgbm/stage4g_winning_non_sensitive_manifest.json', ['experiment_id','model_path','native_model_path','prediction_path','metrics','reuse_required_in_stage4h','status'])
# Out:
# {'experiment_id': 'stage4g__final_tuning__candidate_c_flexible',
#  'model_path': 'artifacts\\models\\lightgbm\\final\\lightgbm_final_selection_without_sensitive.joblib',
#  'native_model_path': 'artifacts\\models\\lightgbm\\final\\lightgbm_final_selection_without_sensitive.txt',
#  'prediction_path': 'artifacts\\predictions\\lightgbm\\final\\lightgbm_final_selection_without_sensitive.csv',
#  'metrics': {'mae': 64.45675112229286,
#   'mse': 17412.430779767787,
#   'rmse': 131.95616991928716,
#   'mape_percent': 38.233346757275214,
#   'r_squared': 0.6856598010936056,
#   'rmsle': None,
#   'rmsle_clipped_zero': 0.44555123751585085,
#   'median_absolute_error': 37.863387791917035,
#   'wape_percent': 26.1100156045356,
#   'mean_signed_error': -8.54457832711679,
#   'p90_absolute_error': 137.07535259409207,
#   'negative_prediction_rate': 0.00456,
#   'mae_usd': 64456.75112229286,
#   'rmse_usd': 131956.16991928717,
#   'original_scale': True,
#   'top_decile_mae': 203.03207088207972,
#   'top_five_percent_mae': 297.4602312076121,
#   'underestimation_rate': 0.49732,
#   'overestimation_rate': 0.50268},
#  'reuse_required_in_stage4h': True,
#  'status': 'PASS'}
# {'stage_id': 'stage4g',
#  'experiment_id': 'stage4g__final_tuning__candidate_c_flexible',
#  'selected_candidate': 'tuning_c_flexible',
#  'model_path': 'artifacts\\models\\lightgbm\\final\\lightgbm_final_selection_without_sensitive.joblib',
#  'native_model_path': 'artifacts\\models\\lightgbm\\final\\lightgbm_final_selection_without_sensitive.txt',
#  'prediction_path': 'artifacts\\predictions\\lightgbm\\final\\lightgbm_final_selection_without_sensitive.csv',
#  'model_sha256': 'bc2ed4187bdad9fed21ee40491153a836f997d192dfbd69314d7122343e01ec8',
#  'native_model_sha256': '73bf9635f4dac253454e06d42ed5376ddb08266fe4546165ee059da9c4c51e22',
#  'prediction_sha256': '3b48e7ed45ad1c7c4f5f947833b0de251758d8f1b39c59c4a049152f7815407a',
#  'metrics': {'mae': 64.45675112229286,
#   'mse': 17412.430779767787,
#   'rmse': 131.95616991928716,
#   'mape_percent': 38.233346757275214,
#   'r_squared': 0.6856598010936056,
#   'rmsle': None,
#   'rmsle_clipped_zero': 0.44555123751585085,
#   'median_absolute_error': 37.863387791917035,
#   'wape_percent': 26.1100156045356,
#   'mean_signed_error': -8.54457832711679,
#   'p90_absolute_error': 137.07535259409207,
#   'negative_prediction_rate': 0.00456,
#   'mae_usd': 64456.75112229286,
#   'rmse_usd': 131956.16991928717,
#   'original_scale': True,
#   'top_decile_mae': 203.03207088207972,
#   'top_five_percent_mae': 297.4602312076121,
#   'underestimation_rate': 0.49732,
#   'overestimation_rate': 0.50268},
#  'fixed_iteration': 1500,
#  'reuse_required_in_stage4h': True,
#  'reload_report': 'artifacts\\reports\\stage4g_winning_model_reload.json',
#  'status': 'PASS'}

# %% [markdown]
# ### 29. Clean Reload
#
# Reason: This section checks the saved evidence for Clean Reload.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: The winning model reloads and prediction-matches.

# %%
show_json('artifacts/reports/stage4g_winning_model_reload.json', ['rows','reference_prediction_match','native_prediction_match','source_frame_unchanged','status'])
# Out:
# {'rows': 500,
#  'reference_prediction_match': True,
#  'native_prediction_match': True,
#  'source_frame_unchanged': True,
#  'status': 'PASS'}
# {'model_path': 'D:\\SHARIF\\TERM7\\DATA\\PROJECT\\regresionpart2\\artifacts\\models\\lightgbm\\final\\lightgbm_final_selection_without_sensitive.joblib',
#  'native_model_path': 'D:\\SHARIF\\TERM7\\DATA\\PROJECT\\regresionpart2\\artifacts\\models\\lightgbm\\final\\lightgbm_final_selection_without_sensitive.txt',
#  'prediction_path': 'D:\\SHARIF\\TERM7\\DATA\\PROJECT\\regresionpart2\\artifacts\\predictions\\lightgbm\\final\\lightgbm_final_selection_without_sensitive.csv',
#  'rows': 500,
#  'finite_predictions': True,
#  'output_length_matches': True,
#  'source_frame_unchanged': True,
#  'reference_prediction_match': True,
#  'native_prediction_match': True,
#  'inverse_target_verified': True,
#  'native_booster_loaded': True,
#  'status': 'PASS'}

# %% [markdown]
# ### 30. Stage 4G Gate Summary
#
# Reason: This section checks the saved evidence for Stage 4G Gate Summary.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Stage 4G Gate reports PASS.

# %%
show_json('artifacts/reports/stage4g_gate_verification.json', ['feature_confirmation_fit_count','tuning_candidate_count','selected_candidate','final_feature_pack','fixed_iteration','checks','status'])
# Out:
# {'feature_confirmation_fit_count': 3,
#  'tuning_candidate_count': 3,
#  'selected_candidate': 'tuning_c_flexible',
#  'final_feature_pack': 'lightgbm_encoded_v1',
#  'fixed_iteration': 1500,
#  'checks': {'stage4f_gate_pass': True,
#   'feature_confirmation_sample_valid': True,
#   'final_selection_sample_valid': True,
#   'no_test_rows_used': True,
#   'proposal_count_at_most_three': True,
#   'feature_confirmation_fit_count_at_most_three': True,
#   'feature_engineer_v2_serializable': True,
#   'final_feature_pack_frozen': True,
#   'exactly_three_tuning_candidates_complete': True,
#   'tuning_non_sensitive_only': True,
#   'final_configuration_frozen': True,
#   'winning_non_sensitive_model_saved': True,
#   'validation_predictions_complete': True,
#   'winning_model_reload_pass': True,
#   'registry_ids_unique': True,
#   'protected_hashes_unchanged': True},
#  'status': 'PASS'}
# {'stage_id': 'stage4g',
#  'stage_name': 'Stage 4G — LightGBM Feature Confirmation and Final Tuning',
#  'created_at_utc': '2026-07-14T17:56:50.844102+00:00',
#  'feature_confirmation_fit_count': 3,
#  'tuning_candidate_count': 3,
#  'selected_candidate': 'tuning_c_flexible',
#  'final_feature_pack': 'lightgbm_encoded_v1',
#  'fixed_iteration': 1500,
#  'checks': {'stage4f_gate_pass': True,
#   'feature_confirmation_sample_valid': True,
#   'final_selection_sample_valid': True,
#   'no_test_rows_used': True,
#   'proposal_count_at_most_three': True,
#   'feature_confirmation_fit_count_at_most_three': True,
#   'feature_engineer_v2_serializable': True,
#   'final_feature_pack_frozen': True,
#   'exactly_three_tuning_candidates_complete': True,
#   'tuning_non_sensitive_only': True,
#   'final_configuration_frozen': True,
#   'winning_non_sensitive_model_saved': True,
#   'validation_predictions_complete': True,
#   'winning_model_reload_pass': True,
#   'registry_ids_unique': True,
#   'protected_hashes_unchanged': True},
#  'status': 'PASS',
#  'finalization_runtime_seconds': 6.890628900000593}

# %% [markdown]
# ## Stage 4H — Sensitive Comparison and Full-Train Models
#
# ### 31. Stage 4H Objective
#
# Reason: Stage 4H reuses the non-sensitive winner, compares one sensitive model, and saves two full-Train bundles.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Stage 4H uses one frozen comparison and two final fits.

# %%
print({'non_sensitive_action': 'reuse', 'new_sensitive_validation_fits': 1, 'full_train_fits': 2, 'test_rows': 0})
# Out:
# {'non_sensitive_action': 'reuse', 'new_sensitive_validation_fits': 1, 'full_train_fits': 2, 'test_rows': 0}

# %% [markdown]
# ### 32. Stage 4G Gate Validation
#
# Reason: This section checks the saved evidence for Stage 4G Gate Validation.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Stage 4H started only after Stage 4G PASS.

# %%
show_json('artifacts/reports/stage4g_gate_verification.json', ['status'])
# Out:
# {'status': 'PASS'}
# {'stage_id': 'stage4g',
#  'stage_name': 'Stage 4G — LightGBM Feature Confirmation and Final Tuning',
#  'created_at_utc': '2026-07-14T17:56:50.844102+00:00',
#  'feature_confirmation_fit_count': 3,
#  'tuning_candidate_count': 3,
#  'selected_candidate': 'tuning_c_flexible',
#  'final_feature_pack': 'lightgbm_encoded_v1',
#  'fixed_iteration': 1500,
#  'checks': {'stage4f_gate_pass': True,
#   'feature_confirmation_sample_valid': True,
#   'final_selection_sample_valid': True,
#   'no_test_rows_used': True,
#   'proposal_count_at_most_three': True,
#   'feature_confirmation_fit_count_at_most_three': True,
#   'feature_engineer_v2_serializable': True,
#   'final_feature_pack_frozen': True,
#   'exactly_three_tuning_candidates_complete': True,
#   'tuning_non_sensitive_only': True,
#   'final_configuration_frozen': True,
#   'winning_non_sensitive_model_saved': True,
#   'validation_predictions_complete': True,
#   'winning_model_reload_pass': True,
#   'registry_ids_unique': True,
#   'protected_hashes_unchanged': True},
#  'status': 'PASS',
#  'finalization_runtime_seconds': 6.890628900000593}

# %% [markdown]
# ### 33. Frozen Final Configuration
#
# Reason: This section checks the saved evidence for Frozen Final Configuration.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: The same frozen configuration is used in both modes.

# %%
show_json('artifacts/results/stage4/lightgbm/final/lightgbm_final_configuration.json', ['feature_pack','selected_proposals','target_mode','parameters','fixed_iteration','random_seed','thread_count'])
# Out:
# {'feature_pack': 'lightgbm_encoded_v1',
#  'selected_proposals': [],
#  'target_mode': 'raw',
#  'parameters': {'n_estimators': 1500,
#   'learning_rate': 0.05,
#   'num_leaves': 47,
#   'max_depth': -1,
#   'min_child_samples': 50,
#   'subsample': 0.8,
#   'subsample_freq': 1,
#   'colsample_bytree': 0.8,
#   'reg_alpha': 0.0,
#   'reg_lambda': 5.0,
#   'random_state': 42,
#   'n_jobs': 2,
#   'objective': 'regression_l1',
#   'verbosity': -1},
#  'fixed_iteration': 1500,
#  'random_seed': 42,
#  'thread_count': 2}
# {'stage_id': 'stage4g',
#  'stage_name': 'Stage 4G — LightGBM Feature Confirmation and Final Tuning',
#  'selected_candidate': 'tuning_c_flexible',
#  'selection_reason': 'Candidate C had the lowest MAE, tail MAE, RMSE, clipped-zero RMSLE, and better signed error than the baseline; the MAE gain exceeded the 0.25 percent tie band.',
#  'feature_pack': 'lightgbm_encoded_v1',
#  'selected_proposals': [],
#  'accepted_features': [],
#  'rejected_features': ['applicant_to_estimated_tract_income_ratio',
#   'respondent_purpose_group',
#   'income_band_lien_status_group'],
#  'target_mode': 'raw',
#  'parameters': {'n_estimators': 1500,
#   'learning_rate': 0.05,
#   'num_leaves': 47,
#   'max_depth': -1,
#   'min_child_samples': 50,
#   'subsample': 0.8,
#   'subsample_freq': 1,
#   'colsample_bytree': 0.8,
#   'reg_alpha': 0.0,
#   'reg_lambda': 5.0,
#   'random_state': 42,
#   'n_jobs': 2,
#   'objective': 'regression_l1',
#   'verbosity': -1},
#  'fixed_iteration': 1500,
#  'random_seed': 42,
#  'thread_count': 2,
#  'encoding_policy': 'training-fit frequency and ordinal mappings inside each complete Pipeline',
#  'sensitive_selection_used': False,
#  'test_rows': 0,
#  'status': 'FROZEN'}

# %% [markdown]
# ### 34. Reused Non-Sensitive Validation Result
#
# Reason: This section checks the saved evidence for Reused Non-Sensitive Validation Result.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: The non-sensitive Validation model was reused without refitting.

# %%
show_json('artifacts/reports/stage4h_non_sensitive_reuse_verification.json', ['reused_stage4g_experiment_id','metrics','checks','status'])
# Out:
# {'reused_stage4g_experiment_id': 'stage4g__final_tuning__candidate_c_flexible',
#  'metrics': {'mae': 64.45675112229286,
#   'mse': 17412.430779767787,
#   'rmse': 131.95616991928716,
#   'mape_percent': 38.233346757275214,
#   'r_squared': 0.6856598010936056,
#   'rmsle': None,
#   'rmsle_clipped_zero': 0.44555123751585085,
#   'median_absolute_error': 37.863387791917035,
#   'wape_percent': 26.1100156045356,
#   'mean_signed_error': -8.54457832711679,
#   'p90_absolute_error': 137.07535259409207,
#   'negative_prediction_rate': 0.00456,
#   'mae_usd': 64456.75112229286,
#   'rmse_usd': 131956.16991928717,
#   'original_scale': True,
#   'top_decile_mae': 203.03207088207972,
#   'top_five_percent_mae': 297.4602312076121,
#   'underestimation_rate': 0.49732,
#   'overestimation_rate': 0.50268},
#  'checks': {'stage4g_gate_pass': True,
#   'model_hash_match': True,
#   'native_hash_match': True,
#   'prediction_hash_match': True,
#   'validation_row_ids_match': True,
#   'validation_rows_25000': True,
#   'sensitive_mode_without': True,
#   'frozen_pack_match': True,
#   'frozen_iteration_match': True,
#   'reload_pass': True,
#   'refit_performed_in_stage4h': False},
#  'status': 'PASS'}
# {'stage_id': 'stage4h',
#  'reused_stage4g_experiment_id': 'stage4g__final_tuning__candidate_c_flexible',
#  'model_path': 'artifacts\\models\\lightgbm\\final\\lightgbm_final_selection_without_sensitive.joblib',
#  'native_model_path': 'artifacts\\models\\lightgbm\\final\\lightgbm_final_selection_without_sensitive.txt',
#  'prediction_path': 'artifacts\\predictions\\lightgbm\\final\\lightgbm_final_selection_without_sensitive.csv',
#  'metrics': {'mae': 64.45675112229286,
#   'mse': 17412.430779767787,
#   'rmse': 131.95616991928716,
#   'mape_percent': 38.233346757275214,
#   'r_squared': 0.6856598010936056,
#   'rmsle': None,
#   'rmsle_clipped_zero': 0.44555123751585085,
#   'median_absolute_error': 37.863387791917035,
#   'wape_percent': 26.1100156045356,
#   'mean_signed_error': -8.54457832711679,
#   'p90_absolute_error': 137.07535259409207,
#   'negative_prediction_rate': 0.00456,
#   'mae_usd': 64456.75112229286,
#   'rmse_usd': 131956.16991928717,
#   'original_scale': True,
#   'top_decile_mae': 203.03207088207972,
#   'top_five_percent_mae': 297.4602312076121,
#   'underestimation_rate': 0.49732,
#   'overestimation_rate': 0.50268},
#  'checks': {'stage4g_gate_pass': True,
#   'model_hash_match': True,
#   'native_hash_match': True,
#   'prediction_hash_match': True,
#   'validation_row_ids_match': True,
#   'validation_rows_25000': True,
#   'sensitive_mode_without': True,
#   'frozen_pack_match': True,
#   'frozen_iteration_match': True,
#   'reload_pass': True,
#   'refit_performed_in_stage4h': False},
#  'status': 'PASS'}

# %% [markdown]
# ### 35. Single Sensitive Validation Fit
#
# Reason: This section checks the saved evidence for Single Sensitive Validation Fit.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Exactly one sensitive Validation fit completed.

# %%
show_json('artifacts/checkpoints/stage4/lightgbm/sensitive_validation.json', ['experiment_id','training_row_count','validation_row_count','fixed_or_best_iteration','metrics','status'])
# Out:
# {'experiment_id': 'stage4h__final_selection_validation__with_sensitive',
#  'training_row_count': 100000,
#  'validation_row_count': 25000,
#  'fixed_or_best_iteration': 1500,
#  'metrics': {'mae': 64.33219557514754,
#   'mse': 17546.94773126264,
#   'rmse': 132.46489244800918,
#   'mape_percent': 38.26158059241634,
#   'r_squared': 0.6832314161182977,
#   'rmsle': None,
#   'rmsle_clipped_zero': 0.4480312510294626,
#   'median_absolute_error': 37.823662304587,
#   'wape_percent': 26.059560885317357,
#   'mean_signed_error': -8.512014868239051,
#   'p90_absolute_error': 136.50835971598585,
#   'negative_prediction_rate': 0.00444,
#   'mae_usd': 64332.19557514754,
#   'rmse_usd': 132464.89244800917,
#   'original_scale': True,
#   'top_decile_mae': 202.72249327652963,
#   'top_five_percent_mae': 296.48447349153815,
#   'underestimation_rate': 0.49992,
#   'overestimation_rate': 0.50008},
#  'status': 'PASS'}
# {'stage_id': 'stage4h',
#  'stage_name': 'Stage 4H — Final LightGBM Sensitive Comparison and Full-Train Models',
#  'experiment_id': 'stage4h__final_selection_validation__with_sensitive',
#  'job_type': 'validation',
#  'feature_pack': 'lightgbm_encoded_v1',
#  'feature_engineer_version': 'stage4b_initial_boosting_packs_v1_20260714',
#  'selected_proposals': [],
#  'target_mode': 'raw',
#  'sensitive_mode': 'with_sensitive',
#  'parameters': {'n_estimators': 1500,
#   'learning_rate': 0.05,
#   'num_leaves': 47,
#   'max_depth': -1,
#   'min_child_samples': 50,
#   'subsample': 0.8,
#   'subsample_freq': 1,
#   'colsample_bytree': 0.8,
#   'reg_alpha': 0.0,
#   'reg_lambda': 5.0,
#   'random_state': 42,
#   'n_jobs': 2,
#   'objective': 'regression_l1',
#   'verbosity': -1},
#  'fixed_or_best_iteration': 1500,
#  'random_seed': 42,
#  'thread_count': 2,
#  'sample_name': 'final_selection',
#  'sample_digest': '445a077b3fc1963bec38d8ba90384df2e1400e3897b25f0ecbfce78cb96c49ef',
#  'feature_pack_digest': 'd19338809beb7afdd3df1e804c8d83cf45f86ee4f93b2ca99ec65c4e332007da',
#  'source_hash_digest': '6dc52dca5a8a7196a75213fab4a5a5c0a541f84390219459afb0b2be7b77aede',
#  'training_row_count': 100000,
#  'validation_row_count': 25000,
#  'test_row_count': 0,
#  'fit_time_seconds': 15.309391699993284,
#  'prediction_time_seconds': 2.366741199992248,
#  'metrics': {'mae': 64.33219557514754,
#   'mse': 17546.94773126264,
#   'rmse': 132.46489244800918,
#   'mape_percent': 38.26158059241634,
#   'r_squared': 0.6832314161182977,
#   'rmsle': None,
#   'rmsle_clipped_zero': 0.4480312510294626,
#   'median_absolute_error': 37.823662304587,
#   'wape_percent': 26.059560885317357,
#   'mean_signed_error': -8.512014868239051,
#   'p90_absolute_error': 136.50835971598585,
#   'negative_prediction_rate': 0.00444,
#   'mae_usd': 64332.19557514754,
#   'rmse_usd': 132464.89244800917,
#   'original_scale': True,
#   'top_decile_mae': 202.72249327652963,
#   'top_five_percent_mae': 296.48447349153815,
#   'underestimation_rate': 0.49992,
#   'overestimation_rate': 0.50008},
#  'model_path': 'artifacts\\models\\lightgbm\\final\\lightgbm_final_selection_with_sensitive.joblib',
#  'native_model_path': 'artifacts\\models\\lightgbm\\final\\lightgbm_final_selection_with_sensitive.txt',
#  'prediction_path': 'artifacts\\predictions\\lightgbm\\final\\lightgbm_final_selection_with_sensitive.csv',
#  'model_sha256': '5430cde54092210dd7b1ad0376a9ba5f15d9ea66625941618b122caac9753b53',
#  'native_model_sha256': 'fb4899fe7a9c8e0ebd56d2b0826be49a3a4a1d2b2c9f535bd4a1294ac94b8ed1',
#  'prediction_sha256': '09ddc127a4f57ab147a9e19aea61bfd0af02bce4338a9182207be76a01a1cd31',
#  'warnings': [],
#  'errors': [],
#  'status': 'PASS',
#  'created_at_utc': '2026-07-14T17:58:37.492389+00:00'}

# %% [markdown]
# ### 36. Controlled Sensitive Comparison
#
# Reason: This section checks the saved evidence for Controlled Sensitive Comparison.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Sensitive differences are accuracy evidence, not a fairness result.

# %%
show_csv('artifacts/results/stage4/lightgbm/final/lightgbm_sensitive_validation_comparison.csv', None, 2)
show_json('artifacts/results/stage4/lightgbm/final/lightgbm_sensitive_validation_differences.json', ['difference_definition','not_test_evaluation','not_complete_fairness_result','differences','status'])
# Out:
#             evaluation_design     sensitive_mode        mae           mse  \
# 0  Final Selection Validation  without_sensitive  64.456751  17412.430780
# 1  Final Selection Validation     with_sensitive  64.332196  17546.947731
#
#          rmse  mape_percent  r_squared  rmsle  rmsle_clipped_zero  \
# 0  131.956170     38.233347   0.685660    NaN            0.445551
# 1  132.464892     38.261581   0.683231    NaN            0.448031
#
#    median_absolute_error  wape_percent  mean_signed_error  p90_absolute_error  \
# 0              37.863388     26.110016          -8.544578          137.075353
# 1              37.823662     26.059561          -8.512015          136.508360
#
#    negative_prediction_rate  top_decile_mae  top_five_percent_mae  \
# 0                   0.00456      203.032071            297.460231
# 1                   0.00444      202.722493            296.484473
#
#    fit_time_seconds  prediction_time_seconds  reused
# 0          0.000000                 0.000000    True
# 1         15.309392                 2.366741   False
# {'difference_definition': 'with_sensitive - without_sensitive',
#  'not_test_evaluation': True,
#  'not_complete_fairness_result': True,
#  'differences': {'mae': -0.12455554714532013,
#   'mse': 134.51695149485386,
#   'rmse': 0.5087225287220178,
#   'mape_percent': 0.028233835141122654,
#   'r_squared': -0.00242838497530784,
#   'rmsle': None,
#   'rmsle_clipped_zero': 0.0024800135136117674,
#   'median_absolute_error': -0.03972548733003123,
#   'wape_percent': -0.05045471921824429,
#   'mean_signed_error': 0.03256345887773904,
#   'p90_absolute_error': -0.5669928781062197,
#   'negative_prediction_rate': -0.00011999999999999945,
#   'top_decile_mae': -0.3095776055500892,
#   'top_five_percent_mae': -0.9757577160739288},
#  'status': 'PASS'}
# {'stage_id': 'stage4h',
#  'evaluation_design': 'Final Selection Validation',
#  'difference_definition': 'with_sensitive - without_sensitive',
#  'not_test_evaluation': True,
#  'not_complete_fairness_result': True,
#  'without_sensitive_experiment_id': 'stage4g__final_tuning__candidate_c_flexible',
#  'without_sensitive_reused': True,
#  'with_sensitive_experiment_id': 'stage4h__final_selection_validation__with_sensitive',
#  'same_train_and_validation_rows': True,
#  'same_feature_pack': True,
#  'same_target_mode': True,
#  'same_parameters': True,
#  'same_fixed_iteration': True,
#  'same_seed': True,
#  'same_thread_count': True,
#  'differences': {'mae': -0.12455554714532013,
#   'mse': 134.51695149485386,
#   'rmse': 0.5087225287220178,
#   'mape_percent': 0.028233835141122654,
#   'r_squared': -0.00242838497530784,
#   'rmsle': None,
#   'rmsle_clipped_zero': 0.0024800135136117674,
#   'median_absolute_error': -0.03972548733003123,
#   'wape_percent': -0.05045471921824429,
#   'mean_signed_error': 0.03256345887773904,
#   'p90_absolute_error': -0.5669928781062197,
#   'negative_prediction_rate': -0.00011999999999999945,
#   'top_decile_mae': -0.3095776055500892,
#   'top_five_percent_mae': -0.9757577160739288},
#  'status': 'PASS'}

# %% [markdown]
# ### 37. Full-Training Models
#
# Reason: This section checks the saved evidence for Full-Training Models.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Both final models used all 399,788 Train rows and zero Test rows.

# %%
display(pd.DataFrame([show_json(f'artifacts/checkpoints/stage4/lightgbm/full_train_{mode}.json', ['sensitive_mode','training_row_count','test_row_count','fit_time_seconds','fixed_or_best_iteration','status']) for mode in ['without_sensitive','with_sensitive']]))
# Out:
# {'sensitive_mode': 'without_sensitive',
#  'training_row_count': 399788,
#  'test_row_count': 0,
#  'fit_time_seconds': 55.55995150000672,
#  'fixed_or_best_iteration': 1500,
#  'status': 'PASS'}
# {'sensitive_mode': 'with_sensitive',
#  'training_row_count': 399788,
#  'test_row_count': 0,
#  'fit_time_seconds': 63.530905099993106,
#  'fixed_or_best_iteration': 1500,
#  'status': 'PASS'}
#   stage_id                                         stage_name  \
# 0  stage4h  Stage 4H — Final LightGBM Sensitive Comparison...
# 1  stage4h  Stage 4H — Final LightGBM Sensitive Comparison...
#
#                             experiment_id    job_type         feature_pack  \
# 0  stage4h__full_train__without_sensitive  full_train  lightgbm_encoded_v1
# 1     stage4h__full_train__with_sensitive  full_train  lightgbm_encoded_v1
#
#                      feature_engineer_version selected_proposals target_mode  \
# 0  stage4b_initial_boosting_packs_v1_20260714                 []         raw
# 1  stage4b_initial_boosting_packs_v1_20260714                 []         raw
#
#       sensitive_mode                                         parameters  ...  \
# 0  without_sensitive  {'n_estimators': 1500, 'learning_rate': 0.05, ...  ...
# 1     with_sensitive  {'n_estimators': 1500, 'learning_rate': 0.05, ...  ...
#
#                                           model_path  \
# 0  artifacts\models\lightgbm\final\lightgbm_final...
# 1  artifacts\models\lightgbm\final\lightgbm_final...
#
#                                    native_model_path  \
# 0  artifacts\models\lightgbm\final\lightgbm_final...
# 1  artifacts\models\lightgbm\final\lightgbm_final...
#
#                                      prediction_path  \
# 0  artifacts\predictions\lightgbm\final\lightgbm_...
# 1  artifacts\predictions\lightgbm\final\lightgbm_...
#
#                                         model_sha256  \
# 0  b1216ea51eafcd7b53289b23a53a594b67b1f5f3015e95...
# 1  5adc210bd76c5347f32150c4c96ac5d68af178739df8e7...
#
#                                  native_model_sha256  \
# 0  9231fa6d28f786f6e5061acb4e8ece4d54cf864068bf0e...
# 1  41a3dddc4fe647f2c124d1dee0e1e9dba0830f921f3b73...
#
#                                    prediction_sha256 warnings  errors  status  \
# 0  f4271e9cb52329fcee05ba3aca058d2f43cfbe879db08d...       []      []    PASS
# 1  e37f6e1a8872526847b9103701fdf19daeb0c8eaf955a3...       []      []    PASS
#
#                      created_at_utc
# 0  2026-07-14T18:00:16.440407+00:00
# 1  2026-07-14T18:01:44.185676+00:00
#
# [2 rows x 33 columns]

# %% [markdown]
# ### 38. Final Model Manifests
#
# Reason: This section checks the saved evidence for Final Model Manifests.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Both bundles contain explicit provenance and native Boosters.

# %%
display(pd.DataFrame([show_json(f'artifacts/manifests/stage4/lightgbm/stage4h_final_model_manifest_{mode}.json', ['sensitive_mode','model_path','native_model_path','training_row_count','reload_status','status']) for mode in ['without_sensitive','with_sensitive']]))
# Out:
# {'sensitive_mode': 'without_sensitive',
#  'model_path': 'artifacts\\models\\lightgbm\\final\\lightgbm_final_without_sensitive.joblib',
#  'native_model_path': 'artifacts\\models\\lightgbm\\final\\lightgbm_final_without_sensitive.txt',
#  'training_row_count': 399788,
#  'reload_status': 'PASS',
#  'status': 'PASS'}
# {'sensitive_mode': 'with_sensitive',
#  'model_path': 'artifacts\\models\\lightgbm\\final\\lightgbm_final_with_sensitive.joblib',
#  'native_model_path': 'artifacts\\models\\lightgbm\\final\\lightgbm_final_with_sensitive.txt',
#  'training_row_count': 399788,
#  'reload_status': 'PASS',
#  'status': 'PASS'}
#   stage_id                        bundle_version     sensitive_mode  \
# 0  stage4h  stage4f_stage4h_lightgbm_v1_20260714  without_sensitive
# 1  stage4h  stage4f_stage4h_lightgbm_v1_20260714     with_sensitive
#
#           feature_pack target_mode  \
# 0  lightgbm_encoded_v1         raw
# 1  lightgbm_encoded_v1         raw
#
#                                           parameters  fixed_iteration  \
# 0  {'n_estimators': 1500, 'learning_rate': 0.05, ...             1500
# 1  {'n_estimators': 1500, 'learning_rate': 0.05, ...             1500
#
#    random_seed  thread_count  training_row_count  ...  \
# 0           42             2              399788  ...
# 1           42             2              399788  ...
#
#                            reference_prediction_path  \
# 0  artifacts\predictions\lightgbm\final\lightgbm_...
# 1  artifacts\predictions\lightgbm\final\lightgbm_...
#
#                                         model_sha256  \
# 0  b1216ea51eafcd7b53289b23a53a594b67b1f5f3015e95...
# 1  5adc210bd76c5347f32150c4c96ac5d68af178739df8e7...
#
#                                  native_model_sha256  \
# 0  9231fa6d28f786f6e5061acb4e8ece4d54cf864068bf0e...
# 1  41a3dddc4fe647f2c124d1dee0e1e9dba0830f921f3b73...
#
#                                     reference_sha256  \
# 0  f4271e9cb52329fcee05ba3aca058d2f43cfbe879db08d...
# 1  e37f6e1a8872526847b9103701fdf19daeb0c8eaf955a3...
#
#                                    embedded_metadata  \
# 0  {'bundle_version': 'stage4f_stage4h_lightgbm_v...
# 1  {'bundle_version': 'stage4f_stage4h_lightgbm_v...
#
#                                        reload_report reload_status  \
# 0  artifacts\reports\stage4h_final_reload_without...          PASS
# 1  artifacts\reports\stage4h_final_reload_with_se...          PASS
#
#                             importance_complete_path  \
# 0  artifacts\features\stage4\lightgbm\stage4h_imp...
# 1  artifacts\features\stage4\lightgbm\stage4h_imp...
#
#                                   shap_metadata_path status
# 0  artifacts\manifests\stage4\lightgbm\stage4h_sh...   PASS
# 1  artifacts\manifests\stage4\lightgbm\stage4h_sh...   PASS
#
# [2 rows x 23 columns]

# %% [markdown]
# ### 39. Clean-Process Reload
#
# Reason: This section checks the saved evidence for Clean-Process Reload.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Both final model forms reload and match references.

# %%
display(pd.DataFrame([show_json(f'artifacts/reports/stage4h_final_reload_{mode}.json', ['rows','finite_predictions','source_frame_unchanged','reference_prediction_match','native_prediction_match','status']) for mode in ['without_sensitive','with_sensitive']]))
# Out:
# {'rows': 500,
#  'finite_predictions': True,
#  'source_frame_unchanged': True,
#  'reference_prediction_match': True,
#  'native_prediction_match': True,
#  'status': 'PASS'}
# {'rows': 500,
#  'finite_predictions': True,
#  'source_frame_unchanged': True,
#  'reference_prediction_match': True,
#  'native_prediction_match': True,
#  'status': 'PASS'}
#                                           model_path  \
# 0  D:\SHARIF\TERM7\DATA\PROJECT\regresionpart2\ar...
# 1  D:\SHARIF\TERM7\DATA\PROJECT\regresionpart2\ar...
#
#                                    native_model_path  \
# 0  D:\SHARIF\TERM7\DATA\PROJECT\regresionpart2\ar...
# 1  D:\SHARIF\TERM7\DATA\PROJECT\regresionpart2\ar...
#
#                                      prediction_path  rows  \
# 0  D:\SHARIF\TERM7\DATA\PROJECT\regresionpart2\ar...   500
# 1  D:\SHARIF\TERM7\DATA\PROJECT\regresionpart2\ar...   500
#
#    finite_predictions  output_length_matches  source_frame_unchanged  \
# 0                True                   True                    True
# 1                True                   True                    True
#
#    reference_prediction_match  native_prediction_match  \
# 0                        True                     True
# 1                        True                     True
#
#    inverse_target_verified  native_booster_loaded status
# 0                     True                   True   PASS
# 1                     True                   True   PASS

# %% [markdown]
# ### 40. Final Gain and Split Importance
#
# Reason: This section checks the saved evidence for Final Gain and Split Importance.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Final Importance exists for both modes and is not causal evidence.

# %%
for mode in ['without_sensitive','with_sensitive']:
    print(mode)
    show_csv(f'artifacts/features/stage4/lightgbm/stage4h_importance_top20_{mode}.csv', ['source_feature','feature_origin','gain_importance','split_importance'], 10)
# Out:
# without_sensitive
#                        source_feature        feature_origin  gain_importance  \
# 0               applicant_income_000s      original_numeric    975768.775197
# 1                    lien_status_name  original_categorical    506256.324249
# 2  estimated_tract_family_income_000s    stage4b_engineered    349527.356979
# 3                           us_region  original_categorical    241809.525682
# 4              property_purpose_group    stage4b_engineered    225682.766552
# 5            hud_median_family_income      original_numeric    219595.370960
# 6   applicant_vs_area_income_gap_000s    stage4b_engineered    177001.494318
# 7     applicant_income_to_area_income      original_numeric    163260.017064
# 8           purpose_lien_status_group    stage4b_engineered    125508.884894
# 9                         county_name      high_cardinality    101735.469941
#
#    split_importance
# 0              4494
# 1               739
# 2              3846
# 3              1207
# 4               850
# 5              3466
# 6              2637
# 7              3147
# 8               703
# 9              3520
# with_sensitive
#                        source_feature        feature_origin  gain_importance  \
# 0               applicant_income_000s      original_numeric     1.247895e+06
# 1                    lien_status_name  original_categorical     4.373124e+05
# 2  estimated_tract_family_income_000s    stage4b_engineered     2.971272e+05
# 3              property_purpose_group    stage4b_engineered     2.410741e+05
# 4                           us_region  original_categorical     2.381746e+05
# 5            hud_median_family_income      original_numeric     1.838169e+05
# 6           purpose_lien_status_group    stage4b_engineered     1.422641e+05
# 7         occupancy_lien_status_group    stage4b_engineered     1.205542e+05
# 8                          msamd_name      high_cardinality     9.331846e+04
# 9                         county_name      high_cardinality     8.567065e+04
#
#    split_importance
# 0              4219
# 1               713
# 2              3499
# 3               758
# 4              1059
# 5              3099
# 6               683
# 7               766
# 8              2794
# 9              3279

# %% [markdown]
# ### 41. Final Tree SHAP
#
# Reason: This section checks the saved evidence for Final Tree SHAP.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Both modes use the same 300 deterministic SHAP row IDs.

# %%
ids = show_csv('artifacts/features/stage4/lightgbm/stage4h_shap_row_ids.csv', ['row_id'], 5)
for mode in ['without_sensitive','with_sensitive']:
    print(mode)
    show_csv(f'artifacts/features/stage4/lightgbm/stage4h_shap_top20_{mode}.csv', ['source_feature','feature_origin','mean_absolute_shap'], 10)
    display(Image(filename=str(ROOT / f'artifacts/figures/stage4/lightgbm/stage4h_shap_summary_{mode}.png')))
# Out:
#    row_id
# 0      15
# 1      26
# 2      29
# 3      47
# 4      67
# without_sensitive
#                        source_feature        feature_origin  \
# 0               applicant_income_000s      original_numeric
# 1  estimated_tract_family_income_000s    stage4b_engineered
# 2                           us_region  original_categorical
# 3            hud_median_family_income      original_numeric
# 4                    lien_status_name  original_categorical
# 5              property_purpose_group    stage4b_engineered
# 6   applicant_vs_area_income_gap_000s    stage4b_engineered
# 7                owner_occupancy_name  original_categorical
# 8           purpose_lien_status_group    stage4b_engineered
# 9                          state_name  original_categorical
#
#    mean_absolute_shap
# 0           57.897293
# 1           34.542129
# 2           23.241945
# 3           15.209853
# 4           13.856989
# 5           13.542435
# 6            9.843253
# 7            9.294513
# 8            9.259905
# 9            7.734902
# with_sensitive
#                        source_feature        feature_origin  \
# 0               applicant_income_000s      original_numeric
# 1  estimated_tract_family_income_000s    stage4b_engineered
# 2                           us_region  original_categorical
# 3              property_purpose_group    stage4b_engineered
# 4            hud_median_family_income      original_numeric
# 5                    lien_status_name  original_categorical
# 6           purpose_lien_status_group    stage4b_engineered
# 7                          msamd_name      high_cardinality
# 8                owner_occupancy_name  original_categorical
# 9         occupancy_lien_status_group    stage4b_engineered
#
#    mean_absolute_shap
# 0           68.619496
# 1           31.200717
# 2           22.720301
# 3           14.085515
# 4           13.748751
# 5           11.529874
# 6           10.091529
# 7            9.439810
# 8            8.379016
# 9            7.245489

# %% [markdown]
# ### 42. Previous-Stage Reference
#
# Reason: This section checks the saved evidence for Previous-Stage Reference.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: OOF and Final Selection results are labelled as different designs.

# %%
show_csv('artifacts/results/stage4/lightgbm/final/lightgbm_previous_stage_reference.csv', ['stage','model_name','evaluation_scheme','evaluation_rows','sensitive_mode','mae','rmse','rmsle','r_squared','runtime_seconds'], 10)
# Out:
#         stage              model_name           evaluation_scheme  \
# 0     Stage 2                   lasso              saved-fold OOF
# 1     Stage 3  hist_gradient_boosting              saved-fold OOF
# 2  Stage 4D-E                catboost  Final Selection validation
# 3  Stage 4G-H                lightgbm  Final Selection validation
#
#    evaluation_rows     sensitive_mode        mae        rmse     rmsle  \
# 0           399788  without_sensitive  72.230441  245.237341  0.441602
# 1           399788  without_sensitive  64.275669  249.121627  0.395075
# 2            25000  without_sensitive  63.376185  130.272187  0.390619
# 3            25000  without_sensitive  64.456751  131.956170  0.445551
#
#    r_squared  runtime_seconds
# 0   0.404243        65.342005
# 1   0.385222        40.657902
# 2   0.693632       320.629190
# 3   0.685660        14.205618
#         stage              model_name     sensitive_mode  \
# 0     Stage 2                   lasso  without_sensitive
# 1     Stage 3  hist_gradient_boosting  without_sensitive
# 2  Stage 4D-E                catboost  without_sensitive
# 3  Stage 4G-H                lightgbm  without_sensitive
#
#             evaluation_scheme  evaluation_rows        mae        rmse  \
# 0              saved-fold OOF           399788  72.230441  245.237341
# 1              saved-fold OOF           399788  64.275669  249.121627
# 2  Final Selection validation            25000  63.376185  130.272187
# 3  Final Selection validation            25000  64.456751  131.956170
#
#       rmsle  r_squared  runtime_seconds  prediction_runtime_seconds  \
# 0  0.441602   0.404243        65.342005                    1.740441
# 1  0.395075   0.385222        40.657902                    9.120964
# 2  0.390619   0.693632       320.629190                    0.384864
# 3  0.445551   0.685660        14.205618                    2.302812
#
#    directly_comparable_across_all_rows  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
#
#                                      comparison_note  \
# 0  OOF, Discovery validation, and Final Selection...
# 1  OOF, Discovery validation, and Final Selection...
# 2  OOF, Discovery validation, and Final Selection...
# 3  Stage 2 and Stage 3 use saved-fold OOF. CatBoo...
#
#                                     locked_test_note
# 0  The locked Test Set will later provide the com...
# 1  The locked Test Set will later provide the com...
# 2  The locked Test Set will later provide the com...
# 3  The locked Test Set will provide the final com...

# %% [markdown]
# ### 43. LightGBM Artifact Summary
#
# Reason: This section checks the saved evidence for LightGBM Artifact Summary.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: All required LightGBM artifact groups are present.

# %%
show_json('artifacts/reports/stage4h_artifact_summary.json')
# Out:
# {'stage_id': 'stage4h',
#  'lightgbm_registry_rows': 13,
#  'candidate_checkpoints': 4,
#  'feature_confirmation_checkpoints': 3,
#  'tuning_checkpoints': 3,
#  'sensitive_validation_checkpoints': 1,
#  'full_train_checkpoints': 2,
#  'final_bundles': 2,
#  'native_boosters': 2,
#  'reload_pass_count': 2,
#  'importance_modes': 2,
#  'shap_modes': 2,
#  'test_predictions': 0,
#  'status': 'PASS'}
# {'stage_id': 'stage4h',
#  'lightgbm_registry_rows': 13,
#  'candidate_checkpoints': 4,
#  'feature_confirmation_checkpoints': 3,
#  'tuning_checkpoints': 3,
#  'sensitive_validation_checkpoints': 1,
#  'full_train_checkpoints': 2,
#  'final_bundles': 2,
#  'native_boosters': 2,
#  'reload_pass_count': 2,
#  'importance_modes': 2,
#  'shap_modes': 2,
#  'test_predictions': 0,
#  'status': 'PASS'}

# %% [markdown]
# ### 44. Final Verification
#
# Reason: This section checks the saved evidence for Final Verification.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: Final LightGBM verification reports PASS after the independent review and accepted repairs.

# %%
show_json('artifacts/reports/stage4h_verification.json', ['stage_name','checks','reviewer','status','next_step'])
# Out:
# {'stage_name': 'Stage 4H — Final LightGBM Sensitive Comparison and Full-Train Models',
#  'checks': {'previous_required_stages_pass': True,
#   'protected_852_files_unchanged': True,
#   'test_remains_locked': True,
#   'discovery_sample_valid': True,
#   'feature_confirmation_sample_valid': True,
#   'final_selection_sample_valid': True,
#   'samples_mutually_disjoint_train_only': True,
#   'stage4f_candidate_budget_respected': True,
#   'stage4f_gate_pass': True,
#   'stage4g_confirmation_budget_respected': True,
#   'stage4g_tuning_exactly_three': True,
#   'stage4g_gate_pass': True,
#   'all_selection_non_sensitive': True,
#   'non_sensitive_validation_model_reused': True,
#   'exactly_one_sensitive_validation_fit': True,
#   'same_rows_and_frozen_configuration': True,
#   'two_full_train_models_saved': True,
#   'both_full_train_all_399788_rows': True,
#   'zero_test_rows_in_full_train': True,
#   'two_complete_bundles_and_native_boosters': True,
#   'two_clean_reload_tests_pass': True,
#   'final_importance_both_modes': True,
#   'final_shap_same_300_ids_both_modes': True,
#   'registry_ids_unique': True,
#   'prior_registry_bytes_restored': True,
#   'all_13_checkpoints_hash_and_provenance_valid': True,
#   'complete_notebook_run_pass': True,
#   'cache_only_notebook_run_pass': True,
#   'no_heavy_fit_repeats': True,
#   'notebook_outputs_saved': True,
#   'notebook_46_sections_and_em_dashes': True,
#   'reviewer_completed': True,
#   'accepted_critical_major_issues_fixed': True,
#   'state_files_current': True,
#   'xgboost_not_started': True},
#  'reviewer': {'report': 'artifacts/reports/stage4h_reviewer.md',
#   'adjudication': 'artifacts/reports/stage4h_reviewer_adjudication.md',
#   'critical_issues': 0,
#   'major_issues': 2,
#   'accepted_major_fixes': 2,
#   'status': 'PASS_AFTER_REPAIR'},
#  'status': 'PASS',
#  'next_step': 'Begin Stage 4I — Initial XGBoost Model and Importance Analysis.'}
# {'stage': 'stage4h',
#  'stage_name': 'Stage 4H — Final LightGBM Sensitive Comparison and Full-Train Models',
#  'created_at_utc': '2026-07-14T18:20:01.139842+00:00',
#  'protected_hash_report': 'artifacts/manifests/stage4/lightgbm/stage4h_protected_hashes_after.json',
#  'reviewer': {'report': 'artifacts/reports/stage4h_reviewer.md',
#   'adjudication': 'artifacts/reports/stage4h_reviewer_adjudication.md',
#   'critical_issues': 0,
#   'major_issues': 2,
#   'accepted_major_fixes': 2,
#   'status': 'PASS_AFTER_REPAIR'},
#  'registry': {'rows': 256,
#   'unique_ids': 256,
#   'lightgbm_rows': 13,
#   'prior_rows': 243,
#   'prior_registry_sha256_restored': '9a7aee16017c58b45313d68cab7067bbe9b683331a7fcd9e4096f241f9941bbd'},
#  'checks': {'previous_required_stages_pass': True,
#   'protected_852_files_unchanged': True,
#   'test_remains_locked': True,
#   'discovery_sample_valid': True,
#   'feature_confirmation_sample_valid': True,
#   'final_selection_sample_valid': True,
#   'samples_mutually_disjoint_train_only': True,
#   'stage4f_candidate_budget_respected': True,
#   'stage4f_gate_pass': True,
#   'stage4g_confirmation_budget_respected': True,
#   'stage4g_tuning_exactly_three': True,
#   'stage4g_gate_pass': True,
#   'all_selection_non_sensitive': True,
#   'non_sensitive_validation_model_reused': True,
#   'exactly_one_sensitive_validation_fit': True,
#   'same_rows_and_frozen_configuration': True,
#   'two_full_train_models_saved': True,
#   'both_full_train_all_399788_rows': True,
#   'zero_test_rows_in_full_train': True,
#   'two_complete_bundles_and_native_boosters': True,
#   'two_clean_reload_tests_pass': True,
#   'final_importance_both_modes': True,
#   'final_shap_same_300_ids_both_modes': True,
#   'registry_ids_unique': True,
#   'prior_registry_bytes_restored': True,
#   'all_13_checkpoints_hash_and_provenance_valid': True,
#   'complete_notebook_run_pass': True,
#   'cache_only_notebook_run_pass': True,
#   'no_heavy_fit_repeats': True,
#   'notebook_outputs_saved': True,
#   'notebook_46_sections_and_em_dashes': True,
#   'reviewer_completed': True,
#   'accepted_critical_major_issues_fixed': True,
#   'state_files_current': True,
#   'xgboost_not_started': True},
#  'limitations': ['The locked Test Set has not been evaluated.',
#   'Final Selection Validation is one holdout, not OOF.',
#   'Sensitive-mode differences may reflect proxies and are not a full fairness analysis.',
#   'The extreme target tail remains difficult.',
#   'Frequency and ordinal encoding compress category identity.',
#   'Tree SHAP is associative, not causal.'],
#  'next_step': 'Begin Stage 4I — Initial XGBoost Model and Importance Analysis.',
#  'status': 'PASS'}

# %% [markdown]
# ### 45. LightGBM Track Completion Note
#
# Reason: This section checks the saved evidence for LightGBM Track Completion Note.
#
# Interpretation: The output below is loaded from a validated LightGBM artifact. No model is fitted in this Notebook.
#
# Conclusion: The Notebook evidence is complete without running XGBoost.

# %%
display(Markdown('The complete LightGBM track reports PASS. Test is still locked, and XGBoost has not started.'))
print({'cache_only': CACHE_ONLY, 'fit_calls': 0, 'next_step': 'Begin Stage 4I — Initial XGBoost Model and Importance Analysis.'})
# Out:
# The complete LightGBM track reports PASS. Test is still locked, and XGBoost has not started.
# {'cache_only': True, 'fit_calls': 0, 'next_step': 'Begin Stage 4I — Initial XGBoost Model and Importance Analysis.'}
