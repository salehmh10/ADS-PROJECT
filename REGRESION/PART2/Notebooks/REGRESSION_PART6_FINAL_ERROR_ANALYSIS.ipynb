# %% [markdown]
# # Stage 6 — Final Error Analysis and Model Comparison

# %% [markdown]
# ## 0. Stage Objective and Post-Test Disclosure
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
from pathlib import Path
import json
import pandas as pd
from IPython.display import display
ROOT = Path.cwd()
print({'stage': 'Stage 6', 'analysis_label': 'Post-Test Error Analysis', 'stage4l_official_unchanged': True, 'model_selection': False})
# Out:
# {'stage': 'Stage 6', 'analysis_label': 'Post-Test Error Analysis', 'stage4l_official_unchanged': True, 'model_selection': False}

# %% [markdown]
# ## 1. Imports and Configuration
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
def show(path):
    path = ROOT / path
    if path.suffix == '.csv':
        display(pd.read_csv(path).head(12))
    else:
        payload = json.loads(path.read_text(encoding='utf-8'))
        print(json.dumps(payload, indent=2, ensure_ascii=False)[:5000])
print({'candidate_count': 3, 'source_csv_loads': 0, 'model_accesses': 0, 'prediction_generation_calls': 0})
# Out:
# {'candidate_count': 3, 'source_csv_loads': 0, 'model_accesses': 0, 'prediction_generation_calls': 0}

# %% [markdown]
# ## 2. State Reconstruction
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
print((ROOT / 'TASK.md').read_text(encoding='utf-8')[:3500])
# Out:
# # Target
#
# Complete Stage 6 — Final Error Analysis and Model Comparison in `REGRESSION_PART6_FINAL_ERROR_ANALYSIS.ipynb`. Analyze exactly three immutable saved Test prediction files, create reproducible descriptive error evidence, preserve Stage 4L as the official pre-registered primary, and stop before Stage 7.
#
# # Context
#
# Stage 5C is complete with PASS and its canonical Notebook hash is `7e4ae8b08ec8909dcc073f1f1f3eb822c063c35c6519059ed3027661213a2479`. Stage 5B is PASS with `ensemble_status = rejected`. Stage 5A remains `PASS_WITH_DOCUMENTED_GOVERNANCE_EXCEPTION`, including the visible historical literal zero-Test-loading failure. Stage 6 is saved-prediction-only `Post-Test Error Analysis`; it does not select or promote a model.
#
# # Assumptions
#
# ...

# %% [markdown]
# ## 3. Stage 5C Verification and Handoff
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/reports/stage5c_verification.json')
# Out:
# {
#   "checks": {
#     "accepted_ensemble_count_zero": true,
#     "all_results_post_test_label": true,
#     "authorized_fourth_notebook_run_pass": true,
#     "authorized_refresh_immutability_recheck_pass": true,
#     "authorized_section17_signed_bias_pass": true,
#     "authorized_section19_signed_bias_pass": true,
#     "bootstrap_settings_frozen": true,
#     "bundle_with_hash_pass": true,
#     "bundle_without_hash_pass": true,
#     "cache_only_notebook_run_pass": true,
#     "candidate_count_frozen": true,
#     "canonical_target_hash_exists": true,
#     "complete_metric_set_exists": true,
#     "complete_notebook_run_pass": true,
#     "decile_tail_disagreement_exist": true,
#     "deep_evaluation_eligible": true,
#     "ensemble_evaluation_ineligible": true,
#     "figure_scope_frozen": true,
#     "frozen_realmlp_raw_epoch30": true,
#     "metric_definitions_frozen": true,
#     "model_with_hash_pass": true,
#     "model_without_hash_pass": true,
# ...

# %% [markdown]
# ## 4. Candidate Roles
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
print({'stage4l__blend__without_sensitive': 'official_pre_registered_primary', 'stage5c__realmlp__without_sensitive__test_evaluation': 'post_test_extension', 'stage5c__realmlp__with_sensitive__test_evaluation': 'post_test_extension_accuracy_only'})
# Out:
# {'stage4l__blend__without_sensitive': 'official_pre_registered_primary', 'stage5c__realmlp__without_sensitive__test_evaluation': 'post_test_extension', 'stage5c__realmlp__with_sensitive__test_evaluation': 'post_test_extension_accuracy_only'}

# %% [markdown]
# ## 5. Protected File Baseline
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/manifests/stage6/stage6_protected_hashes_before.json')
# Out:
# {
#   "created_at_utc": "2026-07-16T12:15:58.908547+00:00",
#   "elapsed_seconds": 9.179902900010347,
#   "entries": [
#     {
#       "path": "artifacts/data_contract/feature_inventory.csv",
#       "sha256": "2a4f85d8862d9ea3d49b85665f0650a3094111d0b08849b5908afed00238ae0e",
#       "size_bytes": 4735
#     },
#     {
#       "path": "artifacts/figures/stage5c/plotting_data/stage5c_absolute_error_difference_distribution.csv",
#       "sha256": "9057cb67dfaee0aa8b52d290046d9cebc1038038a4aa5be7be2e1ff510423dd7",
#       "size_bytes": 3314
#     },
#     {
#       "path": "artifacts/figures/stage5c/plotting_data/stage5c_paired_bootstrap_interval.csv",
#       "sha256": "21c6a72b4abb3a7318d0a32cc64febddbc312676f37ae5b1c8aaaf15f3018e4f",
#       "size_bytes": 246
#     },
#     {
#       "path": "artifacts/figures/stage5c/plotting_data/stage5c_prediction_disagreement.csv",
#       "sha256": "b1cb6233e7a63b5d07072e0ca2b74974953ba0d1cec9e7c820b357da2f46b4df",
#       "size_bytes": 890745
# ...

# %% [markdown]
# ## 6. Pre-Analysis Freeze
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/reports/stage6_preanalysis_freeze.json')
# Out:
# {
#   "absolute_error_quantiles": [
#     0.5,
#     0.75,
#     0.9,
#     0.95,
#     0.99,
#     1.0
#   ],
#   "absolute_error_thresholds": [
#     50,
#     100,
#     200
#   ],
#   "analysis_label": "Post-Test Error Analysis",
#   "bootstrap_recomputation_count": 0,
#   "bundle_access_count": 0,
#   "candidates": [
#     {
#       "candidate_id": "stage4l__blend__without_sensitive",
#       "label": "Stage 4L Official Boosting Blend",
#       "prediction_path": "artifacts/predictions/final_test/stage4l__blend__without_sensitive.csv",
#       "prediction_sha256": "9f9efa21d95a466b8271cd0db0a1e6b2c1ed2b5f1cabfbbb7e081137b9e4b7ed",
#       "role": "official_pre_registered_primary"
#     },
#     {
#       "candidate_id": "stage5c__realmlp__without_sensitive__test_evaluation",
#       "label": "Frozen RealMLP Without Sensitive",
#       "prediction_path": "artifacts/predictions/stage5/posttest_evaluation/stage5c_test_predictions_without_sensitive.csv",
# ...

# %% [markdown]
# ## 7. Prediction Provenance
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/reports/stage6_prediction_access_audit.json')
# Out:
# {
#   "authorization_source": "Stage 6 bounded saved-prediction analysis request",
#   "bootstrap_recomputation_count": 0,
#   "bundle_access_count": 0,
#   "ensemble_construction_count": 0,
#   "first_prediction_value_access_timestamp": "2026-07-16T12:16:12.551073+00:00",
#   "model_access_count": 0,
#   "model_fit_count": 0,
#   "new_boosting_prediction_count": 0,
#   "preanalysis_freeze_path": "artifacts/reports/stage6_preanalysis_freeze.json",
#   "preanalysis_freeze_sha256": "c9ed0df8eb14a9220c7f80d18167d2744a267f18c38a619bf539dfaade56432d",
#   "prediction_generation_count": 0,
#   "prediction_inputs": [
#     {
#       "candidate_id": "stage4l__blend__without_sensitive",
#       "columns_parsed": [
#         "candidate_id",
#         "row_id",
#         "y_true",
#         "y_pred",
#         "absolute_error",
#         "signed_error",
#         "model_family",
#         "sensitive_mode",
#         "prediction_time_seconds",
#         "model_sha256",
# ...

# %% [markdown]
# ## 8. Input Alignment
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/reports/stage6_input_alignment_report.json')
# Out:
# {
#   "candidate_count": 3,
#   "created_at_utc": "2026-07-16T12:16:13.850159+00:00",
#   "deterministic_sorted_order": true,
#   "exact_test_membership": true,
#   "finite_predictions": true,
#   "identical_targets": true,
#   "original_target_scale": true,
#   "rows_per_candidate": 99948,
#   "stage_id": "stage6",
#   "status": "PASS",
#   "target_decile_reused": true,
#   "target_hash": "889e4253fb584c2a52a06d8b8e956beefad997ba18e4d736af0cd1738fb34a1a",
#   "test_row_id_hash": "e58e4d078c761f60405e644d4dd7ba368f364daffb73b44abb39095938ece95e",
#   "top_decile_threshold": 444.0,
#   "top_five_percent_threshold": 597.0,
#   "unique_row_ids": true,
#   "zero_train_overlap": true
# }

# %% [markdown]
# ## 9. Error Definitions and Validation
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/reports/stage6_error_column_validation.json')
# Out:
# {
#   "created_at_utc": "2026-07-16T12:16:13.849159+00:00",
#   "mean_signed_error_direction": "closer_to_zero",
#   "signed_error_formula": "y_pred - y_true",
#   "stage_id": "stage6",
#   "status": "PASS",
#   "validations": [
#     {
#       "candidate_id": "stage4l__blend__without_sensitive",
#       "max_absolute_difference": 4.547473508864641e-13,
#       "passes": true,
#       "saved_column": "signed_error"
#     },
#     {
#       "candidate_id": "stage4l__blend__without_sensitive",
#       "max_absolute_difference": 4.547473508864641e-13,
#       "passes": true,
#       "saved_column": "absolute_error"
#     },
#     {
#       "candidate_id": "stage5c__realmlp__without_sensitive__test_evaluation",
#       "max_absolute_difference": 4.547473508864641e-13,
#       "passes": true,
#       "saved_column": "signed_error"
#     },
#     {
#       "candidate_id": "stage5c__realmlp__without_sensitive__test_evaluation",
#       "max_absolute_difference": 4.547473508864641e-13,
# ...

# %% [markdown]
# ## 10. Candidate Metric Snapshot
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/results/stage6/error_analysis/stage6_candidate_metric_snapshot.csv')
# Out:
#                                         candidate_id  \
# 0                  stage4l__blend__without_sensitive
# 1  stage5c__realmlp__without_sensitive__test_eval...
# 2  stage5c__realmlp__with_sensitive__test_evaluation
#
#                     candidate_label                      official_role  \
# 0  Stage 4L Official Boosting Blend    official_pre_registered_primary
# 1  Frozen RealMLP Without Sensitive                post_test_extension
# 2     Frozen RealMLP With Sensitive  post_test_extension_accuracy_only
#
#              analysis_label  row_count  \
# 0  Post-Test Error Analysis      99948
# 1  Post-Test Error Analysis      99948
# 2  Post-Test Error Analysis      99948
#
#                                      prediction_path  \
# 0  artifacts/predictions/final_test/stage4l__blen...
# 1  artifacts/predictions/stage5/posttest_evaluati...
# 2  artifacts/predictions/stage5/posttest_evaluati...
#
#                                    prediction_sha256  \
# ...

# %% [markdown]
# ## 11. Error Distribution Summary
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/results/stage6/error_analysis/stage6_error_distribution_summary.csv')
# Out:
#                                         candidate_id  \
# 0                  stage4l__blend__without_sensitive
# 1  stage5c__realmlp__without_sensitive__test_eval...
# 2  stage5c__realmlp__with_sensitive__test_evaluation
#
#                     candidate_label                      official_role  \
# 0  Stage 4L Official Boosting Blend    official_pre_registered_primary
# 1  Frozen RealMLP Without Sensitive                post_test_extension
# 2     Frozen RealMLP With Sensitive  post_test_extension_accuracy_only
#
#    row_count  mean_signed_error  absolute_mean_signed_error  \
# 0      99948          -9.554174                    9.554174
# 1      99948          -7.013757                    7.013757
# 2      99948          -6.440910                    6.440910
#
#    median_signed_error  signed_error_std  signed_error_min  signed_error_max  \
# 0            -0.862367        125.425095      -7245.141721       1409.139050
# ...

# %% [markdown]
# ## 12. Error Quantiles and Exceedance
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/results/stage6/error_analysis/stage6_error_quantiles.csv')
# Out:
#                                         candidate_id  \
# 0                  stage4l__blend__without_sensitive
# 1  stage5c__realmlp__without_sensitive__test_eval...
# 2  stage5c__realmlp__with_sensitive__test_evaluation
#
#                     candidate_label        p50        p75         p90  \
# 0  Stage 4L Official Boosting Blend  35.589702  72.645884  131.507953
# 1  Frozen RealMLP Without Sensitive  36.401075  73.851281  132.683744
# 2     Frozen RealMLP With Sensitive  36.132471  73.309763  131.474865
#
#           p95         p99      maximum            analysis_label
# 0  189.545210  437.307324  7245.141721  Post-Test Error Analysis
# 1  190.337321  431.673722  7449.380595  Post-Test Error Analysis
# 2  189.436451  436.207861  7371.388799  Post-Test Error Analysis

# %% [markdown]
# ## 13. Error Concentration
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/results/stage6/error_analysis/stage6_error_concentration.csv')
# Out:
#                                         candidate_id  \
# 0                  stage4l__blend__without_sensitive
# 1                  stage4l__blend__without_sensitive
# 2                  stage4l__blend__without_sensitive
# 3  stage5c__realmlp__without_sensitive__test_eval...
# 4  stage5c__realmlp__without_sensitive__test_eval...
# 5  stage5c__realmlp__without_sensitive__test_eval...
# 6  stage5c__realmlp__with_sensitive__test_evaluation
# 7  stage5c__realmlp__with_sensitive__test_evaluation
# 8  stage5c__realmlp__with_sensitive__test_evaluation
#
#                     candidate_label  worst_proportion  row_count  \
# 0  Stage 4L Official Boosting Blend              0.01       1000
# 1  Stage 4L Official Boosting Blend              0.05       4998
# 2  Stage 4L Official Boosting Blend              0.10       9995
# 3  Frozen RealMLP Without Sensitive              0.01       1000
# 4  Frozen RealMLP Without Sensitive              0.05       4998
# ...

# %% [markdown]
# ## 14. Target-Decile Analysis
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/results/stage6/error_analysis/stage6_target_decile_analysis.csv')
# Out:
#                                          candidate_id  \
# 0                   stage4l__blend__without_sensitive
# 1                   stage4l__blend__without_sensitive
# 2                   stage4l__blend__without_sensitive
# 3                   stage4l__blend__without_sensitive
# 4                   stage4l__blend__without_sensitive
# 5                   stage4l__blend__without_sensitive
# 6                   stage4l__blend__without_sensitive
# 7                   stage4l__blend__without_sensitive
# 8                   stage4l__blend__without_sensitive
# 9                   stage4l__blend__without_sensitive
# 10  stage5c__realmlp__without_sensitive__test_eval...
# 11  stage5c__realmlp__without_sensitive__test_eval...
#
#                      candidate_label  target_decile  row_count  target_min  \
# 0   Stage 4L Official Boosting Blend              1      10221         1.0
# 1   Stage 4L Official Boosting Blend              2       9892        66.0
# ...

# %% [markdown]
# ## 15. Target-Tail Analysis
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/results/stage6/error_analysis/stage6_target_tail_analysis.csv')
# Out:
#                                         candidate_id  \
# 0                  stage4l__blend__without_sensitive
# 1                  stage4l__blend__without_sensitive
# 2  stage5c__realmlp__without_sensitive__test_eval...
# 3  stage5c__realmlp__without_sensitive__test_eval...
# 4  stage5c__realmlp__with_sensitive__test_evaluation
# 5  stage5c__realmlp__with_sensitive__test_evaluation
#
#                     candidate_label   tail_definition  row_count  target_min  \
# 0  Stage 4L Official Boosting Blend        top_decile      10017       444.0
# 1  Stage 4L Official Boosting Blend  top_five_percent       5006       597.0
# 2  Frozen RealMLP Without Sensitive        top_decile      10017       444.0
# 3  Frozen RealMLP Without Sensitive  top_five_percent       5006       597.0
# 4     Frozen RealMLP With Sensitive        top_decile      10017       444.0
# 5     Frozen RealMLP With Sensitive  top_five_percent       5006       597.0
#
# ...

# %% [markdown]
# ## 16. Underprediction and Overprediction
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/results/stage6/error_analysis/stage6_under_over_analysis.csv')
# Out:
#                          candidate_id                   candidate_label  \
# 0   stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
# 1   stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
# 2   stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
# 3   stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
# 4   stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
# 5   stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
# 6   stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
# 7   stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
# 8   stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
# 9   stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
# 10  stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
# 11  stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
#
# ...

# %% [markdown]
# ## 17. Calibration by Target Decile
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/results/stage6/error_analysis/stage6_calibration_by_target_decile.csv')
# Out:
#                                          candidate_id  \
# 0                   stage4l__blend__without_sensitive
# 1                   stage4l__blend__without_sensitive
# 2                   stage4l__blend__without_sensitive
# 3                   stage4l__blend__without_sensitive
# 4                   stage4l__blend__without_sensitive
# 5                   stage4l__blend__without_sensitive
# 6                   stage4l__blend__without_sensitive
# 7                   stage4l__blend__without_sensitive
# 8                   stage4l__blend__without_sensitive
# 9                   stage4l__blend__without_sensitive
# 10  stage5c__realmlp__without_sensitive__test_eval...
# 11  stage5c__realmlp__without_sensitive__test_eval...
#
#                      candidate_label  target_decile  mean_actual_target  \
# 0   Stage 4L Official Boosting Blend              1           31.981117
# 1   Stage 4L Official Boosting Blend              2           87.735847
# ...

# %% [markdown]
# ## 18. Pairwise Model Disagreement
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/results/stage6/error_analysis/stage6_pairwise_disagreement_summary.csv')
# Out:
#                                 pair_id  \
# 0    stage6__deep_without_minus_stage4l
# 1       stage6__deep_with_minus_stage4l
# 2  stage6__deep_with_minus_deep_without
#
#                                   first_candidate_id  \
# 0  stage5c__realmlp__without_sensitive__test_eval...
# 1  stage5c__realmlp__with_sensitive__test_evaluation
# 2  stage5c__realmlp__with_sensitive__test_evaluation
#
#                                  second_candidate_id  \
# 0                  stage4l__blend__without_sensitive
# 1                  stage4l__blend__without_sensitive
# 2  stage5c__realmlp__without_sensitive__test_eval...
#
#    pearson_prediction_correlation  spearman_prediction_correlation  \
# 0                        0.984343                         0.988733
# 1                        0.980527                         0.986985
# 2                        0.989189                         0.992052
#
#    pearson_residual_correlation  spearman_residual_correlation  \
# ...

# %% [markdown]
# ## 19. Pairwise Error Differences
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/results/stage6/error_analysis/stage6_pairwise_error_delta_quantiles.csv')
# Out:
#                                 pair_id        p01        p05        p10  \
# 0    stage6__deep_without_minus_stage4l -84.200365 -31.775772 -19.810829
# 1       stage6__deep_with_minus_stage4l -94.068921 -35.438528 -22.048917
# 2  stage6__deep_with_minus_deep_without -67.279115 -28.932945 -18.704393
#
#         p25       p50       p75        p90        p95        p99  \
# 0 -7.736110  0.595243  9.369775  21.671400  33.252753  80.849238
# 1 -8.781923  0.451184  9.923250  23.254275  35.455202  86.105495
# 2 -7.993337 -0.161181  7.455934  17.806005  27.620466  63.960444
#
#              analysis_label
# 0  Post-Test Error Analysis
# 1  Post-Test Error Analysis
# 2  Post-Test Error Analysis

# %% [markdown]
# ## 20. Worst Predictions
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/results/stage6/error_analysis/stage6_worst_predictions.csv')
# Out:
#                          candidate_id                   candidate_label  \
# 0   stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
# 1   stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
# 2   stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
# 3   stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
# 4   stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
# 5   stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
# 6   stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
# 7   stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
# 8   stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
# 9   stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
# 10  stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
# 11  stage4l__blend__without_sensitive  Stage 4L Official Boosting Blend
#
# ...

# %% [markdown]
# ## 21. Worst-Case Overlap
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/results/stage6/error_analysis/stage6_worst_prediction_overlap.csv')
# Out:
#                                 pair_id  \
# 0    stage6__deep_without_minus_stage4l
# 1       stage6__deep_with_minus_stage4l
# 2  stage6__deep_with_minus_deep_without
#
#                                   first_candidate_id  \
# 0  stage5c__realmlp__without_sensitive__test_eval...
# 1  stage5c__realmlp__with_sensitive__test_evaluation
# 2  stage5c__realmlp__with_sensitive__test_evaluation
#
#                                  second_candidate_id  \
# 0                  stage4l__blend__without_sensitive
# 1                  stage4l__blend__without_sensitive
# 2  stage5c__realmlp__without_sensitive__test_eval...
#
#    top100_intersection_count  top100_union_count  jaccard_overlap  \
# 0                         85                 115         0.739130
# 1                         81                 119         0.680672
# 2                         87                 113         0.769912
#
#    percent_first_worst_in_second  percent_second_worst_in_first  \
# ...

# %% [markdown]
# ## 22. High-Disagreement and Representative Cases
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/results/stage6/error_analysis/stage6_representative_cases.csv')
# Out:
#                      case_type  case_rank  row_id   y_true  \
# 0           common_large_error          1  436983  10000.0
# 1           common_large_error          2  215439   9000.0
# 2           common_large_error          3   19494   6500.0
# 3           common_large_error          4  353835   7000.0
# 4           common_large_error          5  170281   6000.0
# 5   stage4l_beats_deep_without          1  273781   1118.0
# 6   stage4l_beats_deep_without          2  234600   2297.0
# 7   stage4l_beats_deep_without          3  251605    278.0
# 8   stage4l_beats_deep_without          4  381977    374.0
# 9   stage4l_beats_deep_without          5  380475   1000.0
# 10  deep_without_beats_stage4l          1  303221   4913.0
# 11  deep_without_beats_stage4l          2  312109   3150.0
#
#                        candidate_1_id  candidate_1_prediction  \
# 0   stage4l__blend__without_sensitive             2754.858279
# 1   stage4l__blend__without_sensitive             2657.226436
# ...

# %% [markdown]
# ## 23. Sensitive-Mode Accuracy Profile
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis. The sensitive-mode comparison is accuracy-only, not a fairness audit or causal conclusion.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/results/stage6/error_analysis/stage6_sensitive_accuracy_profile.csv')
# Out:
#             scope_type scope_value  row_count  with_minus_without_mae  \
# 0              overall         all      99948               -0.338631
# 1        target_decile           1      10221               -0.084365
# 2        target_decile           2       9892               -0.193535
# 3        target_decile           3       9951               -0.367706
# 4        target_decile           4      10095                0.241787
# 5        target_decile           5       9892               -0.102266
# 6        target_decile           6       9936               -0.420773
# 7        target_decile           7      10012               -0.531106
# 8        target_decile           8      10084               -0.358338
# 9        target_decile           9       9884               -0.805944
# 10       target_decile          10       9981               -0.777608
# 11  frozen_target_tail  top_decile      10017               -0.784191
#
# ...

# %% [markdown]
# ## 24. Model Error Profile
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/results/stage6/error_analysis/stage6_model_error_profile.json')
# Out:
# {
#   "analysis_label": "Post-Test Error Analysis",
#   "candidate_profiles": [
#     {
#       "candidate_id": "stage4l__blend__without_sensitive",
#       "candidate_role": "official_pre_registered_primary",
#       "deciles_with_highest_mae": [
#         10
#       ],
#       "deciles_with_strongest_signed_bias": [
#         10
#       ],
#       "dominant_error_direction": "underprediction",
#       "error_concentration": [
#         {
#           "share_of_total_absolute_error_percent": 12.776816241233913,
#           "worst_proportion": 0.01
#         },
#         {
#           "share_of_total_absolute_error_percent": 30.051681066948248,
#           "worst_proportion": 0.05
#         },
#         {
#           "share_of_total_absolute_error_percent": 42.71182867990157,
#           "worst_proportion": 0.1
#         }
#       ],
#       "error_exceedance_rates": [
#         {
#           "percentage_above_threshold": 37.87769640212911,
#           "threshold": 50.0
#         },
# ...

# %% [markdown]
# ## 25. Stage 6 Visualizations
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/manifests/stage6/stage6_visualization_manifest.json')
# Out:
# {
#   "created_at_utc": "2026-07-16T12:16:20.527162+00:00",
#   "entries": [
#     {
#       "analysis_label": "Post-Test Error Analysis",
#       "candidate_ids": [
#         "stage4l__blend__without_sensitive",
#         "stage5c__realmlp__without_sensitive__test_evaluation",
#         "stage5c__realmlp__with_sensitive__test_evaluation"
#       ],
#       "figure_id": "stage6_absolute_error_ecdf",
#       "figure_path": "artifacts/figures/stage6/stage6_absolute_error_ecdf.png",
#       "figure_sha256": "f2496f2b78fb7679b05b39efa301f34b1d692a60f65265da139cf88d54048d44",
#       "interpretation_scope": "Descriptive Post-Test evidence only; no model selection.",
#       "plotting_data_path": "artifacts/figures/stage6/plotting_data/stage6_absolute_error_ecdf.csv",
#       "plotting_data_sha256": "6c26d0a215f14b89eb78ba075fa8623a5929356ea060ddabc92a96307fbb6068",
#       "row_id_hash": "e58e4d078c761f60405e644d4dd7ba368f364daffb73b44abb39095938ece95e",
# ...

# %% [markdown]
# ## 26. Registry Update
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/reports/stage6_registry_update.json')
# Out:
# {
#   "action": "ADDED",
#   "analysis_label": "Post-Test Error Analysis",
#   "prior_prefix_preserved": true,
#   "prior_sha256": "27b0ef62e59dec653c6a68459db765790b8ad1947f62fa5caaca6e84cf975522",
#   "registry_row_count": 370,
#   "registry_sha256": "dda43c0ce481212b8beec46f7da7b29b15acb8ab8847dc20a8819abb11b6ad76",
#   "registry_unique_ids": true,
#   "second_action": "REUSED",
#   "stage6_registry_ids": [
#     "stage6__stage4l_primary__error_profile",
#     "stage6__realmlp_without_sensitive__error_profile",
#     "stage6__realmlp_with_sensitive__error_profile",
#     "stage6__deep_without_vs_stage4l__comparison",
#     "stage6__deep_with_vs_stage4l__comparison",
#     "stage6__deep_with_vs_without__accuracy_profile",
#     "stage6__error_analysis_summary",
#     "stage6__stage7_handoff"
#   ],
#   "stage6_row_count": 8,
#   "stage_id": "stage6",
#   "status": "PASS"
# }

# %% [markdown]
# ## 27. Stage 7 Handoff
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/manifests/stage6/stage6_stage7_handoff.json')
# Out:
# {
#   "candidate_metric_snapshot": {
#     "path": "artifacts/results/stage6/error_analysis/stage6_candidate_metric_snapshot.csv",
#     "sha256": "db09c011296b97981c0b202e569661dd244b851b72cc1e36d6043f4feaa759b5"
#   },
#   "created_at_utc": "2026-07-16T12:16:20.559164+00:00",
#   "decile_analysis": {
#     "path": "artifacts/results/stage6/error_analysis/stage6_target_decile_analysis.csv",
#     "sha256": "c8b505e4c2f6920827046e58238549dd1573d41f87fc1aae5a01a08869d8606b"
#   },
#   "deep_with_sensitive_candidate_id": "stage5c__realmlp__with_sensitive__test_evaluation",
#   "deep_with_sensitive_prediction": {
#     "path": "artifacts/predictions/stage5/posttest_evaluation/stage5c_test_predictions_with_sensitive.csv",
#     "sha256": "b4b11779a2d85209b2082c003ce79db2b657acd52c816c5e5345aaa6671f5e99"
#   },
#   "deep_without_sensitive_candidate_id": "stage5c__realmlp__without_sensitive__test_evaluation",
#   "deep_without_sensitive_prediction": {
# ...

# %% [markdown]
# ## 28. Independent Review and Verification
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/reports/stage6_protected_recheck.json')
# Out:
# {
#   "created_at_utc": "2026-07-16T12:16:51.140442+00:00",
#   "mismatches": [],
#   "prior_registry_sha256": "27b0ef62e59dec653c6a68459db765790b8ad1947f62fa5caaca6e84cf975522",
#   "protected_file_count": 688,
#   "protected_mismatch_count": 0,
#   "registry_prior_prefix_preserved": true,
#   "stage_id": "stage6",
#   "status": "PASS"
# }

# %% [markdown]
# ## 29. Stage 6 Completion Note
#
# Stage 4L remains the official pre-registered primary. This is descriptive Post-Test Error Analysis.
#
# The displayed artifact matters because it makes this step reproducible. The conclusion is limited to saved predictions; raw Features were not analyzed.

# %%
show('artifacts/results/stage6/error_analysis/stage6_artifact_summary.json')
# Out:
# {
#   "analysis_label": "Post-Test Error Analysis",
#   "artifacts": [
#     {
#       "path": "artifacts/results/stage6/error_analysis/stage6_calibration_by_target_decile.csv",
#       "sha256": "75cd613b59bc45a0e1838a79d86d6bd467711ae271b20ef6c7c8fbd86130c346",
#       "size_bytes": 7025
#     },
#     {
#       "path": "artifacts/results/stage6/error_analysis/stage6_candidate_metric_snapshot.csv",
#       "sha256": "db09c011296b97981c0b202e569661dd244b851b72cc1e36d6043f4feaa759b5",
#       "size_bytes": 2269
#     },
#     {
#       "path": "artifacts/results/stage6/error_analysis/stage6_error_concentration.csv",
#       "sha256": "849c9476a680ca42312c47eaec665784e7ff99862f3bc4408f70cbb624689c09",
#       "size_bytes": 1287
#     },
#     {
#       "path": "artifacts/results/stage6/error_analysis/stage6_error_distribution_summary.csv",
#       "sha256": "66d74099000613126ac2e1ed8623b988e147f2b1d6a1a577e2b2b8cd48540490",
#       "size_bytes": 1917
#     },
#     {
# ...
