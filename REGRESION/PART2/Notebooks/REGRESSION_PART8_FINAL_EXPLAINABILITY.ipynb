# %% [markdown]
# # Stage 8 — Final Explainability and Feature Interpretation
#
# Saved-Decile Recovery under authorization `stage8_saved_decile_registry_recovery_20260716`. The invalid initial attempt remains preserved.

# %% [markdown]
# ## 0. Stage Objective and Post-Test Disclosure
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
from pathlib import Path
import os, json
ROOT = Path.cwd()
MODE = os.environ.get('STAGE8_RECOVERY_NOTEBOOK_MODE', 'artifact_loading')
assert ROOT.name == 'regresionpart2'
display({'stage': 'Stage 8 Recovery', 'authorization_id': 'stage8_saved_decile_registry_recovery_20260716', 'mode': MODE, 'post_test': True, 'initial_attempt_invalidated': True, 'stage4l_official': True, 'stage9_started': False})
# Out:
# {'stage': 'Stage 8 Recovery',
#  'authorization_id': 'stage8_saved_decile_registry_recovery_20260716',
#  'mode': 'cache_only',
#  'post_test': True,
#  'initial_attempt_invalidated': True,
#  'stage4l_official': True,
#  'stage9_started': False}

# %% [markdown]
# ## 1. Imports and Configuration
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
import pandas as pd
import numpy as np
from IPython.display import display, Markdown, Image
RECOVERY_RESULTS = ROOT / 'artifacts/results/stage8/recovery'
RECOVERY_MANIFESTS = ROOT / 'artifacts/manifests/stage8/recovery'
REPORTS = ROOT / 'artifacts/reports'
assert MODE in {'artifact_loading', 'cache_only'}
display({'configuration': 'saved-artifact loading only', 'source_csv_loads': 0, 'model_loads': 0, 'inference_calls': 0, 'fit_calls': 0, 'registry_writes': 0})
# Out:
# {'configuration': 'saved-artifact loading only',
#  'source_csv_loads': 0,
#  'model_loads': 0,
#  'inference_calls': 0,
#  'fit_calls': 0,
#  'registry_writes': 0}

# %% [markdown]
# ## 2. State Reconstruction
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
data=json.loads((REPORTS/'stage8_recovery_notebook_preparation.json').read_text(encoding='utf-8'))
display(data)
display(Markdown('The initial Stage 8 sample and background were invalid. This Notebook loads only validated Recovery artifacts.'))
# Out:
# {'authorization_id': 'stage8_saved_decile_registry_recovery_20260716',
#  'complete_local_dispersion_validated': True,
#  'figures_validated': True,
#  'notebook_artifact_loading_only_required': True,
#  'registry_path_b_validated': True,
#  'reviewer_finalization_occurs_after_two_notebook_runs': True,
#  'scientific_artifacts_validated': True,
#  'stage9_started': False,
#  'status': 'PASS'}
# The initial Stage 8 sample and background were invalid. This Notebook loads only validated Recovery artifacts.

# %% [markdown]
# ## 3. Stage 7 Verification and Stage 8 Handoff
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
data=json.loads((REPORTS/'stage8_recovery_sample_freeze.json').read_text(encoding='utf-8'))
display({'status': data['status'], 'authorization_id': data['authorization_id'], 'stage4l_official': data['candidate_ids'][0], 'stage5b_ensemble': 'rejected', 'stage9_started': data['stage9_started']})
# Out:
# {'status': 'PASS',
#  'authorization_id': 'stage8_saved_decile_registry_recovery_20260716',
#  'stage4l_official': 'stage4l__blend__without_sensitive',
#  'stage5b_ensemble': 'rejected',
#  'stage9_started': False}

# %% [markdown]
# ## 4. Explainability Scope and Method Limitations
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
text=(RECOVERY_RESULTS/'stage8_recovery_feature_interpretation_report.md').read_text(encoding='utf-8')
display(Markdown(text))
# Out:
# # Stage 8 Recovery Feature Interpretation Report
#
# > This is Post-Test descriptive explainability. Stage 4L remains the official pre-registered primary.
#
# ## Scope
# Exactly three frozen Candidate predictors and five frozen model identities are described. No model is selected or changed.
#
# ## Corrected sample
# The Recovery uses exactly 2,000 Test rows sampled from saved Stage 5C target deciles, with 200 rows per decile. The 40-row background has four rows per saved decile.
#
# ## Global methods
# Common grouped permutation uses original target units, seeds 42 and 43, and the same semantic-unit row permutations. Saved native Importance, saved native SHAP, and saved Stage 5A attribution are reuse-only.
#
# ## Official blend
# The Stage 4L blend is explained by original-scale grouped permutation. Component SHAP values are not added because their output scales differ.
#
# ## RealMLP
# ...

# %% [markdown]
# ## 5. Frozen Candidates and Model Identities
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
data=json.loads((REPORTS/'stage8_recovery_model_validation.json').read_text(encoding='utf-8'))
display(pd.DataFrame(data['models']))
display({'model_count': data['model_count'], 'fit_calls': data['model_fit_calls'], 'preprocessing_fit_calls': data['preprocessing_fit_calls']})
# Out:
#                                          bundle_path  \
# 0  artifacts/models/catboost/final/catboost_final...
# 1  artifacts/models/lightgbm/final/lightgbm_final...
# 2  artifacts/models/xgboost/final/xgboost_final_w...
# 3  artifacts/models/deep/core_final/stage5a2__rea...
# 4  artifacts/models/deep/core_final/stage5a2__rea...
#
#                                        bundle_sha256    family  \
# 0  57672c581ce91dfabb83a75ceaf074adaaab1b3ace7f94...  CatBoost
# 1  b1216ea51eafcd7b53289b23a53a594b67b1f5f3015e95...  LightGBM
# 2  2a6bb80dacae81510592e9aea3477820cd3a7b66676d6e...   XGBoost
# 3  0d2dc108578512022608fee31676ced4d3d65d178f3d77...   RealMLP
# 4  d8b74180385cae7c0cfb9570ef124e9061c4ee398a68a7...   RealMLP
#
#                                             model_id  physical_attempts  \
# 0               stage4l__catboost__without_sensitive                  1
# 1               stage4l__lightgbm__without_sensitive                  1
# ...

# %% [markdown]
# ## 6. Protected File Baseline
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
data=json.loads((RECOVERY_MANIFESTS/'stage8_recovery_protected_baseline.json').read_text(encoding='utf-8'))
display({'status': data['status'], 'protected_file_count': data['protected_file_count'], 'registry': data['registry'], 'blocked_notebook': data['blocked_notebook']})
# Out:
# {'status': 'PASS',
#  'protected_file_count': 917,
#  'registry': {'experiment_ids': ['p2__ridge__without_sensitive__raw__development_scaler__fold-0__cfg-2f70ddab1e03',
#    'p2__ridge__without_sensitive__log1p__development_scaler__fold-0__cfg-be6714210aca',
#    'p2__ridge__without_sensitive__raw__development_scaler__fold-0__cfg-48378a298b48',
#    'p2__ridge__without_sensitive__log1p__development_scaler__fold-0__cfg-498cb8cb26af',
#    'p2__dummy_median__without_sensitive__raw__development_dummy_median__fold-0__cfg-8543c24384a2',
#    'p2__linear_regression__without_sensitive__raw__development_linear_regression__fold-0__cfg-e153937e6bf2',
#    'p2__linear_regression__without_sensitive__log1p__development_linear_regression__fold-0__cfg-0a554c89bf3a',
#    'p2__ridge__without_sensitive__raw__development_ridge__fold-0__cfg-52f134e5ac5c',
#    'p2__ridge__without_sensitive__raw__development_ridge__fold-0__cfg-f18559df5815',
# ...

# %% [markdown]
# ## 7. Pre-Explainability Freeze
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
data=json.loads((REPORTS/'stage8_recovery_sample_freeze.json').read_text(encoding='utf-8'))
display({'freeze_status': data['status'], 'sample': data['sample'], 'background': data['background'], 'permutation_seeds': data['permutation_seeds'], 'blend_weights': data['blend_weights']})
# Out:
# {'freeze_status': 'PASS',
#  'sample': {'counts': {'1': 200,
#    '10': 200,
#    '2': 200,
#    '3': 200,
#    '4': 200,
#    '5': 200,
#    '6': 200,
#    '7': 200,
#    '8': 200,
#    '9': 200},
#   'path': 'artifacts/manifests/stage8/recovery/stage8_recovery_global_sample_row_ids.csv',
#   'row_count': 2000,
#   'row_id_hash': 'd7791b5e12cae7d6069419efdb1e4a9bc28c586cb1bc5ae2584d1b08c3a0358f',
#   'sha256': '7d2bfd9b85887e203e176a2323e9ffe531d857907ad3c026e4f709c7b9ba84c9',
#   'size_bytes': 19674,
#   'target_hash': 'b67a34138a7f7f956f5573a090132acf2ec44d87ac34cb6fe9ca57840336a8c0'},
#  'background': {'counts': {'1': 4,
#    '10': 4,
#    '2': 4,
#    '3': 4,
#    '4': 4,
#    '5': 4,
#    '6': 4,
#    '7': 4,
#    '8': 4,
#    '9': 4},
#   'local_case_overlap': 0,
#   'path': 'artifacts/manifests/stage8/recovery/stage8_recovery_local_background_row_ids.csv',
#   'row_count': 40,
#   'row_id_hash': '80a30da8f60aa3b5db6ec82847bfc0490359bc2412c3329ceb1f9915bfeb2efd',
# ...

# %% [markdown]
# ## 8. Existing Explainability Artifact Inventory
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
data=json.loads((REPORTS/'stage8_recovery_existing_shap_provenance.json').read_text(encoding='utf-8'))
display(pd.DataFrame(data['artifacts']))
display({'global_shap_recomputations': data['global_shap_recomputations'], 'lineage_source': data['lineage_source']})
# Out:
#             additivity_evidence_presence                base_value_presence  \
# 0  not_revalidated_without_recomputation  not_available_from_saved_artifact
# 1  not_revalidated_without_recomputation  not_available_from_saved_artifact
# 2  not_revalidated_without_recomputation  not_available_from_saved_artifact
# 3  not_revalidated_without_recomputation  not_available_from_saved_artifact
# 4  not_revalidated_without_recomputation  not_available_from_saved_artifact
# 5  not_revalidated_without_recomputation  not_available_from_saved_artifact
#
#    feature_count  finite_value_status  \
# 0              4                 True
# 1              4                 True
# 2             35                 True
# 3             43                 True
# 4              1                 True
# 5              1                 True
#
#                                             metadata metadata_status  \
# 0  {'path': 'artifacts/manifests/stage4/catboost/...            PASS
# ...

# %% [markdown]
# ## 9. Global Sample and Local Case Freeze
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
sample=pd.read_csv(RECOVERY_MANIFESTS/'stage8_recovery_global_sample_row_ids.csv')
background=pd.read_csv(RECOVERY_MANIFESTS/'stage8_recovery_local_background_row_ids.csv')
cases=pd.read_csv(ROOT/'artifacts/manifests/stage8/stage8_local_case_manifest.csv')
display(sample.groupby('target_decile').size().rename('sample_rows').to_frame())
display(background.groupby('target_decile').size().rename('background_rows').to_frame())
display({'sample_rows': len(sample), 'background_rows': len(background), 'local_cases': len(cases), 'sample_hash': json.loads((REPORTS/'stage8_recovery_sample_freeze.json').read_text())['sample']['row_id_hash'], 'background_hash': json.loads((REPORTS/'stage8_recovery_sample_freeze.json').read_text())['background']['row_id_hash']})
# Out:
#                sample_rows
# target_decile
# 1                      200
# 2                      200
# 3                      200
# 4                      200
# 5                      200
# 6                      200
# 7                      200
# 8                      200
# 9                      200
# 10                     200
#                background_rows
# target_decile
# 1                            4
# 2                            4
# 3                            4
# 4                            4
# 5                            4
# 6                            4
# 7                            4
# 8                            4
# 9                            4
# 10                           4
# {'sample_rows': 2000,
#  'background_rows': 40,
#  'local_cases': 20,
#  'sample_hash': 'd7791b5e12cae7d6069419efdb1e4a9bc28c586cb1bc5ae2584d1b08c3a0358f',
#  'background_hash': '80a30da8f60aa3b5db6ec82847bfc0490359bc2412c3329ceb1f9915bfeb2efd'}

# %% [markdown]
# ## 10. Safe Bounded Feature Loading
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
data=json.loads((REPORTS/'stage8_recovery_feature_access_audit.json').read_text(encoding='utf-8'))
display({'status': data['status'], 'access_attempts': data['access_attempts'], 'rows_materialized': data['rows_materialized'], 'train_rows': data['train_rows_materialized'], 'excluded_rows_converted': data['excluded_rows_converted'], 'source_targets': data['source_target_values_materialized'], 'source_hashes_after': data['source_hashes_after_access']})
# Out:
# {'status': 'PASS',
#  'access_attempts': {'with_sensitive': 1, 'without_sensitive': 1},
#  'rows_materialized': {'with_sensitive': 2019, 'without_sensitive': 2019},
#  'train_rows': 0,
#  'excluded_rows_converted': 0,
#  'source_targets': 0,
#  'source_hashes_after': {'with_sensitive': '6dc52dca5a8a7196a75213fab4a5a5c0a541f84390219459afb0b2be7b77aede',
#   'without_sensitive': 'e90f7bb49cce5584c7ab250c1db6a107de5cf640c7839f318d7f3cb995edd93c'}}

# %% [markdown]
# ## 11. Model and Bundle Validation
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
data=json.loads((REPORTS/'stage8_recovery_model_validation.json').read_text(encoding='utf-8'))
display(pd.DataFrame(data['models'])[['model_id','family','sensitive_mode','target_mode','physical_attempts','status']])
# Out:
#                                             model_id    family  \
# 0               stage4l__catboost__without_sensitive  CatBoost
# 1               stage4l__lightgbm__without_sensitive  LightGBM
# 2                stage4l__xgboost__without_sensitive   XGBoost
# 3  stage5c__realmlp__without_sensitive__test_eval...   RealMLP
# 4  stage5c__realmlp__with_sensitive__test_evaluation   RealMLP
#
#       sensitive_mode target_mode  physical_attempts status
# 0  without_sensitive       log1p                  1   PASS
# 1  without_sensitive         raw                  1   PASS
# 2  without_sensitive       log1p                  1   PASS
# 3  without_sensitive         raw                  1   PASS
# 4     with_sensitive         raw                  1   PASS

# %% [markdown]
# ## 12. Prediction Reconciliation
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
data=pd.read_csv(REPORTS/'stage8_recovery_prediction_reconciliation.csv')
display(data)
assert data.status.eq('PASS').all()
# Out:
#                                model_or_candidate_id  row_count  \
# 0               stage4l__catboost__without_sensitive       2000
# 1               stage4l__lightgbm__without_sensitive       2000
# 2                stage4l__xgboost__without_sensitive       2000
# 3                  stage4l__blend__without_sensitive       2000
# 4  stage5c__realmlp__without_sensitive__test_eval...       2000
# 5  stage5c__realmlp__with_sensitive__test_evaluation       2000
#
#                                saved_prediction_path  \
# 0  artifacts/predictions/final_test/stage4l__catb...
# 1  artifacts/predictions/final_test/stage4l__ligh...
# 2  artifacts/predictions/final_test/stage4l__xgbo...
# 3  artifacts/predictions/final_test/stage4l__blen...
# 4  artifacts/predictions/stage5/posttest_evaluati...
# 5  artifacts/predictions/stage5/posttest_evaluati...
#
#    maximum_absolute_difference  mean_absolute_difference  tolerance status
# ...

# %% [markdown]
# ## 13. Existing Tree Feature Importance
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
data=pd.read_csv(ROOT/'artifacts/results/stage8/explainability/stage8_existing_importance_long.csv')
display(data.sort_values(['model_family','within_method_rank']).groupby(['model_family','method']).head(5))
display(Markdown('Reused native Importance. No value was recomputed.'))
# Out:
#     model_family     sensitive_mode                  method  \
# 0       CatBoost  without_sensitive  PredictionValuesChange
# 216     CatBoost     with_sensitive  PredictionValuesChange
# 1       CatBoost  without_sensitive  PredictionValuesChange
# 217     CatBoost     with_sensitive  PredictionValuesChange
# 2       CatBoost  without_sensitive  PredictionValuesChange
# 35      LightGBM  without_sensitive                    gain
# 36      LightGBM  without_sensitive                   split
# 259     LightGBM     with_sensitive                    gain
# 260     LightGBM     with_sensitive                   split
# 37      LightGBM  without_sensitive                    gain
# 66      LightGBM  without_sensitive                   split
# 261     LightGBM     with_sensitive                    gain
# 292     LightGBM     with_sensitive                   split
# 39      LightGBM  without_sensitive                    gain
# 78      LightGBM  without_sensitive                   split
# ...

# %% [markdown]
# ## 14. Existing Tree SHAP
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values. Native SHAP output scales are declared and incompatible raw magnitudes are not combined.

# %%
data=pd.read_csv(ROOT/'artifacts/results/stage8/explainability/stage8_existing_shap_global.csv')
display(data.sort_values(['model_family','within_method_rank']).groupby('model_family').head(5))
display(Markdown('Reused saved SHAP. Native output scales differ; raw values are not combined. Base/additivity gaps remain reported honestly.'))
# Out:
#     model_family     sensitive_mode                        feature_name  \
# 0       CatBoost  without_sensitive               applicant_income_000s
# 107     CatBoost     with_sensitive               applicant_income_000s
# 1       CatBoost  without_sensitive         occupancy_lien_status_group
# 108     CatBoost     with_sensitive         occupancy_lien_status_group
# 2       CatBoost  without_sensitive             state_lien_status_group
# 37      LightGBM  without_sensitive               applicant_income_000s
# 153     LightGBM     with_sensitive               applicant_income_000s
# 43      LightGBM  without_sensitive  estimated_tract_family_income_000s
# 164     LightGBM     with_sensitive  estimated_tract_family_income_000s
# 69      LightGBM  without_sensitive                           us_region
# 84       XGBoost  without_sensitive                    lien_status_name
# 213      XGBoost     with_sensitive                    lien_status_name
# ...

# %% [markdown]
# ## 15. Existing Deep Attribution
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
data=pd.read_csv(RECOVERY_RESULTS/'stage8_recovery_deep_attribution_comparison.csv')
display(data.sort_values('stage8_rank').head(15))
display(Markdown('Stage 5A uses a Train-only sample; Stage 8 Recovery uses a Post-Test saved-decile sample. Differences are not model drift.'))
# Out:
#            semantic_feature_unit  stage5a_rank  stage5a_mae_increase  \
# 1               applicant_income             1             43.368393
# 8               lien_status_name             5             16.662079
# 12                    msamd_name             3              6.288571
# 14          owner_occupancy_name             9              5.094881
# 24            tract_income_ratio             2              7.080904
# 25                     us_region            11              1.552516
# 7       hud_median_family_income            10              2.601944
# 10             loan_purpose_name             8              2.950310
# 21                 respondent_id             4              3.588242
# 11                loan_type_name            12              1.245836
# 4                    county_name             6              4.847942
# 15     owner_occupied_unit_ratio            13              1.056520
# 20            property_type_name            18              1.052592
# ...

# %% [markdown]
# ## 16. Common Global Permutation Importance
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values. Effects use original target units. Local reference substitution is not SHAP, additive, or causal.

# %%
data=pd.read_csv(RECOVERY_RESULTS/'stage8_recovery_common_permutation_importance.csv')
display(data.sort_values(['candidate_id','rank']).groupby('candidate_id').head(10))
display(pd.read_csv(RECOVERY_RESULTS/'stage8_recovery_permutation_repeat_stability.csv'))
# Out:
#                                          candidate_id  \
# 0                   stage4l__blend__without_sensitive
# 1                   stage4l__blend__without_sensitive
# 2                   stage4l__blend__without_sensitive
# 3                   stage4l__blend__without_sensitive
# 4                   stage4l__blend__without_sensitive
# 5                   stage4l__blend__without_sensitive
# 6                   stage4l__blend__without_sensitive
# 7                   stage4l__blend__without_sensitive
# 8                   stage4l__blend__without_sensitive
# 9                   stage4l__blend__without_sensitive
# 27  stage5c__realmlp__with_sensitive__test_evaluation
# 28  stage5c__realmlp__with_sensitive__test_evaluation
# 29  stage5c__realmlp__with_sensitive__test_evaluation
# 30  stage5c__realmlp__with_sensitive__test_evaluation
# 31  stage5c__realmlp__with_sensitive__test_evaluation
# 32  stage5c__realmlp__with_sensitive__test_evaluation
# ...

# %% [markdown]
# ## 17. Semantic Feature Units and Families
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
data=pd.read_csv(ROOT/'artifacts/results/stage8/explainability/stage8_feature_unit_mapping.csv')
display(data.head(20))
display(Markdown('Lineage comes from saved schemas and deterministic names, not explanation outcomes.'))
# Out:
#                candidate_or_component_id  \
# 0   stage4l__catboost__without_sensitive
# 1   stage4l__catboost__without_sensitive
# 2   stage4l__catboost__without_sensitive
# 3   stage4l__catboost__without_sensitive
# 4   stage4l__catboost__without_sensitive
# 5   stage4l__catboost__without_sensitive
# 6   stage4l__catboost__without_sensitive
# 7   stage4l__catboost__without_sensitive
# 8   stage4l__catboost__without_sensitive
# 9   stage4l__catboost__without_sensitive
# 10  stage4l__catboost__without_sensitive
# 11  stage4l__catboost__without_sensitive
# 12  stage4l__catboost__without_sensitive
# 13  stage4l__catboost__without_sensitive
# 14  stage4l__catboost__without_sensitive
# 15  stage4l__catboost__without_sensitive
# 16  stage4l__catboost__without_sensitive
# 17  stage4l__catboost__without_sensitive
# 18  stage4l__catboost__without_sensitive
# 19  stage4l__catboost__without_sensitive
#
#                             input_column  \
# 0                  applicant_income_000s
# ...

# %% [markdown]
# ## 18. Cross-Model Feature Comparison
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
display(pd.read_csv(RECOVERY_RESULTS/'stage8_recovery_cross_model_agreement.csv'))
display(pd.read_csv(RECOVERY_RESULTS/'stage8_recovery_cross_model_feature_comparison.csv').sort_values('official_blend_rank').head(20))
# Out:
#                                              model_a  \
# 0                  stage4l__blend__without_sensitive
# 1                  stage4l__blend__without_sensitive
# 2  stage5c__realmlp__without_sensitive__test_eval...
#
#                                              model_b  shared_feature_count  \
# 0  stage5c__realmlp__without_sensitive__test_eval...                    26
# 1  stage5c__realmlp__with_sensitive__test_evaluation                    26
# 2  stage5c__realmlp__with_sensitive__test_evaluation                    26
#
#    spearman_rank_correlation  kendall_rank_correlation  top_10_intersection  \
# 0                   0.870085                  0.710769                    8
# 1                   0.928889                  0.784615                    8
# 2                   0.932308                  0.815385                   10
#
#    top_10_jaccard  top_20_intersection  top_20_jaccard
# 0        0.666667                   17        0.739130
# ...

# %% [markdown]
# ## 19. Cross-Method Agreement
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values. Native SHAP output scales are declared and incompatible raw magnitudes are not combined.

# %%
data=pd.read_csv(RECOVERY_RESULTS/'stage8_recovery_cross_method_agreement.csv')
display(data)
display(Markdown('Rank-only comparison is used when native explanation scales differ.'))
# Out:
#   model_family     sensitive_mode                                method_a  \
# 0     CatBoost  without_sensitive                  PredictionValuesChange
# 1     LightGBM  without_sensitive                                    gain
# 2     LightGBM  without_sensitive                                   split
# 3      XGBoost  without_sensitive                                    gain
# 4      XGBoost  without_sensitive                              total_gain
# 5      RealMLP  without_sensitive  Stage 5A saved permutation attribution
#
#                                method_b  shared_feature_count  \
# 0                    mean_absolute_SHAP                    37
# 1                    mean_absolute_SHAP                    37
# 2                    mean_absolute_SHAP                    37
# 3                    mean_absolute_SHAP                    39
# 4                    mean_absolute_SHAP                    39
# 5  Stage 8 Recovery grouped permutation                    26
#
# ...

# %% [markdown]
# ## 20. Sensitive Feature Dependence and Proxy Limitations
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
display(pd.read_csv(RECOVERY_RESULTS/'stage8_recovery_sensitive_feature_dependence.csv')[['semantic_feature_unit','mae_increase','mean_absolute_prediction_change','positive_importance_normalized_share','rank']])
display(pd.read_csv(RECOVERY_RESULTS/'stage8_recovery_potential_proxy_overlap.csv').sort_values(['candidate_id','rank']).groupby('candidate_id').head(8))
display(Markdown('Sensitive importance is aggregate-only. It does not prove discrimination, fairness, causality, or legal compliance.'))
# Out:
#                semantic_feature_unit  mae_increase  \
# 0            sensitive_context_block      1.785733
# 1  explicit_sensitive_identity_block      0.445498
#
#    mean_absolute_prediction_change  positive_importance_normalized_share  rank
# 0                        12.511228                              0.015746    11
# 1                         8.158598                              0.003928    19
#                                          candidate_id  \
# 0                   stage4l__blend__without_sensitive
# 1                   stage4l__blend__without_sensitive
# 2                   stage4l__blend__without_sensitive
# 3                   stage4l__blend__without_sensitive
# 4                   stage4l__blend__without_sensitive
# 5                   stage4l__blend__without_sensitive
# 6                   stage4l__blend__without_sensitive
# 7                   stage4l__blend__without_sensitive
# 21  stage5c__realmlp__with_sensitive__test_evaluation
# ...

# %% [markdown]
# ## 21. Local Attribution Method
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values. Effects use original target units. Local reference substitution is not SHAP, additive, or causal.

# %%
data=pd.read_csv(RECOVERY_RESULTS/'stage8_recovery_local_attributions_public.csv')
required=['effect_standard_deviation','effect_minimum','effect_maximum','mean_absolute_effect']
assert data[required].notna().all().all()
display(data.sort_values(['case_public_id','candidate_id','absolute_effect_rank']).head(20))
display({'public_rows': len(data), 'dispersion_complete': True, 'raw_sensitive_values': 0, 'method': 'reference substitution, not SHAP'})
# Out:
#            case_public_id           case_type  case_rank  row_id  \
# 1   common_large_error__1  common_large_error          1  436983
# 25  common_large_error__1  common_large_error          1  436983
# 0   common_large_error__1  common_large_error          1  436983
# 5   common_large_error__1  common_large_error          1  436983
# 13  common_large_error__1  common_large_error          1  436983
# 3   common_large_error__1  common_large_error          1  436983
# 8   common_large_error__1  common_large_error          1  436983
# 9   common_large_error__1  common_large_error          1  436983
# 6   common_large_error__1  common_large_error          1  436983
# 2   common_large_error__1  common_large_error          1  436983
# 11  common_large_error__1  common_large_error          1  436983
# 12  common_large_error__1  common_large_error          1  436983
# 19  common_large_error__1  common_large_error          1  436983
# ...

# %% [markdown]
# ## 22. Official Blend Local Explanations
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values. Effects use original target units. Local reference substitution is not SHAP, additive, or causal.

# %%
data=pd.read_csv(RECOVERY_RESULTS/'stage8_recovery_local_attributions_public.csv')
display(data[data.candidate_id=='stage4l__blend__without_sensitive'].sort_values(['case_public_id','absolute_effect_rank']).groupby('case_public_id').head(5))
# Out:
#                         case_public_id                   case_type  case_rank  \
# 1                common_large_error__1          common_large_error          1
# 25               common_large_error__1          common_large_error          1
# 0                common_large_error__1          common_large_error          1
# 5                common_large_error__1          common_large_error          1
# 13               common_large_error__1          common_large_error          1
# ...                                ...                         ...        ...
# 1540  stage4l_beats_realmlp_without__5  stage4l_beats_deep_without          5
# 1564  stage4l_beats_realmlp_without__5  stage4l_beats_deep_without          5
# 1544  stage4l_beats_realmlp_without__5  stage4l_beats_deep_without          5
# 1552  stage4l_beats_realmlp_without__5  stage4l_beats_deep_without          5
# 1539  stage4l_beats_realmlp_without__5  stage4l_beats_deep_without          5
#
# ...

# %% [markdown]
# ## 23. RealMLP Local Explanations
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values. Effects use original target units. Local reference substitution is not SHAP, additive, or causal.

# %%
data=pd.read_csv(RECOVERY_RESULTS/'stage8_recovery_local_attributions_public.csv')
display(data[data.candidate_id.str.startswith('stage5c__realmlp')].sort_values(['case_public_id','candidate_id','absolute_effect_rank']).groupby(['case_public_id','candidate_id']).head(5))
display(Markdown('Explicit identity and sensitive context are replaced as joint blocks. No raw sensitive value is published.'))
# Out:
#                         case_public_id                   case_type  case_rank  \
# 28               common_large_error__1          common_large_error          1
# 53               common_large_error__1          common_large_error          1
# 40               common_large_error__1          common_large_error          1
# 46               common_large_error__1          common_large_error          1
# 49               common_large_error__1          common_large_error          1
# ...                                ...                         ...        ...
# 1595  stage4l_beats_realmlp_without__5  stage4l_beats_deep_without          5
# 1598  stage4l_beats_realmlp_without__5  stage4l_beats_deep_without          5
# 1618  stage4l_beats_realmlp_without__5  stage4l_beats_deep_without          5
# 1594  stage4l_beats_realmlp_without__5  stage4l_beats_deep_without          5
# 1606  stage4l_beats_realmlp_without__5  stage4l_beats_deep_without          5
#
# ...

# %% [markdown]
# ## 24. Case Synthesis and Explanation Stability
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values. Effects use original target units. Local reference substitution is not SHAP, additive, or causal.

# %%
display(pd.read_csv(RECOVERY_RESULTS/'stage8_recovery_case_explanation_synthesis.csv'))
display(pd.read_csv(RECOVERY_RESULTS/'stage8_recovery_local_explanation_stability.csv'))
display(pd.read_csv(RECOVERY_RESULTS/'stage8_recovery_local_prediction_reconciliation.csv').groupby(['candidate_id','status']).size().rename('case_count').to_frame())
# Out:
#                       case_public_id                        case_type  \
# 0              common_large_error__1               common_large_error
# 1              common_large_error__2               common_large_error
# 2              common_large_error__3               common_large_error
# 3              common_large_error__4               common_large_error
# 4              common_large_error__5               common_large_error
# 5           sensitive_improvement__1  deep_with_improves_over_without
# 6           sensitive_improvement__2  deep_with_improves_over_without
# 7           sensitive_improvement__3  deep_with_improves_over_without
# 8           sensitive_improvement__4  deep_with_improves_over_without
# 9           sensitive_improvement__5  deep_with_improves_over_without
# 10  realmlp_without_beats_stage4l__1       deep_without_beats_stage4l
# 11  realmlp_without_beats_stage4l__2       deep_without_beats_stage4l
# ...

# %% [markdown]
# ## 25. Explainability Limitations
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
text=(RECOVERY_RESULTS/'stage8_recovery_feature_interpretation_report.md').read_text(encoding='utf-8')
display(Markdown(text))
# Out:
# # Stage 8 Recovery Feature Interpretation Report
#
# > This is Post-Test descriptive explainability. Stage 4L remains the official pre-registered primary.
#
# ## Scope
# Exactly three frozen Candidate predictors and five frozen model identities are described. No model is selected or changed.
#
# ## Corrected sample
# The Recovery uses exactly 2,000 Test rows sampled from saved Stage 5C target deciles, with 200 rows per decile. The 40-row background has four rows per saved decile.
#
# ## Global methods
# Common grouped permutation uses original target units, seeds 42 and 43, and the same semantic-unit row permutations. Saved native Importance, saved native SHAP, and saved Stage 5A attribution are reuse-only.
#
# ## Official blend
# The Stage 4L blend is explained by original-scale grouped permutation. Component SHAP values are not added because their output scales differ.
#
# ## RealMLP
# ...

# %% [markdown]
# ## 26. Stage 8 Visualizations
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
data=json.loads((RECOVERY_MANIFESTS/'stage8_recovery_visualization_manifest.json').read_text(encoding='utf-8'))
display({'status': data['status'], 'figure_count': data['figure_count'], 'plotting_data_count': data['plotting_data_count'], 'invalid_initial_figures_counted': data['invalid_initial_figures_counted'], 'public_raw_sensitive_values': data['public_raw_sensitive_values']})
display(pd.DataFrame(data['figures'])[['figure_id','title','method','sample_role','sample_row_count','privacy_status']])
# Out:
# {'status': 'PASS',
#  'figure_count': 15,
#  'plotting_data_count': 15,
#  'invalid_initial_figures_counted': 0,
#  'public_raw_sensitive_values': 0}
#     figure_id                                              title  \
# 0           1    Explainability artifact coverage and provenance
# 1           2  Official Stage 4L blend grouped permutation Im...
# 2           3  RealMLP without-sensitive grouped permutation ...
# 3           4  RealMLP with-sensitive grouped permutation Imp...
# 4           5                   Cross-model Feature-rank heatmap
# 5           6         Feature-family importance-share comparison
# 6           7  CatBoost native Importance versus SHAP rank ag...
# 7           8  LightGBM native Importance versus SHAP rank ag...
# 8           9  XGBoost native Importance versus SHAP rank agr...
# 9          10  Saved Deep attribution versus Stage 8 Deep per...
# 10         11  Explicit-sensitive and contextual-sensitive ag...
# ...

# %% [markdown]
# ## 27. Registry Update
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
rows=pd.read_csv(RECOVERY_RESULTS/'stage8_recovery_registry_rows.csv')
adjudication=json.loads((REPORTS/'stage8_registry_governance_adjudication.json').read_text(encoding='utf-8'))
display(rows[['experiment_id','status','notes']])
display({'path': adjudication['registry_resolution_path'], 'status': adjudication['status'], 'exact_old_bytes_found': adjudication['exact_pre_stage8_bytes_found'], 'first_378_semantic_rows_validated': adjudication['first_378_semantic_rows_validated'], 'existing_386_bytes_modified': adjudication['existing_386_bytes_modified'], 'recovery_rows_appended': adjudication['recovery_rows_appended'], 'second_action': adjudication['second_action'], 'raw_prefix_preservation_claimed': adjudication['raw_prefix_preservation_claimed']})
# Out:
#                                        experiment_id  \
# 0     stage8r1__stage4l_official__global_explanation
# 1  stage8r1__realmlp_without_sensitive__global_ex...
# 2  stage8r1__realmlp_with_sensitive__global_expla...
# 3                     stage8r1__tree_shap__synthesis
# 4          stage8r1__cross_model__feature_comparison
# 5                stage8r1__local_cases__explanations
# 6                   stage8r1__explainability_summary
# 7                           stage8r1__stage9_handoff
#
#                                               status  \
# 0  PASS_WITH_DOCUMENTED_REGISTRY_GOVERNANCE_EXCEP...
# 1  PASS_WITH_DOCUMENTED_REGISTRY_GOVERNANCE_EXCEP...
# 2  PASS_WITH_DOCUMENTED_REGISTRY_GOVERNANCE_EXCEP...
# 3  PASS_WITH_DOCUMENTED_REGISTRY_GOVERNANCE_EXCEP...
# 4  PASS_WITH_DOCUMENTED_REGISTRY_GOVERNANCE_EXCEP...
# 5  PASS_WITH_DOCUMENTED_REGISTRY_GOVERNANCE_EXCEP...
# 6  PASS_WITH_DOCUMENTED_REGISTRY_GOVERNANCE_EXCEP...
# 7  PASS_WITH_DOCUMENTED_REGISTRY_GOVERNANCE_EXCEP...
#
# ...

# %% [markdown]
# ## 28. Stage 9 Handoff
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
data=json.loads((RECOVERY_MANIFESTS/'stage8_recovery_stage9_handoff.json').read_text(encoding='utf-8'))
display(data)
display(Markdown('Stage 9 is not started. Final handoff activation waits for Recovery Reviewer and Verification closure.'))
# Out:
# {'artifacts': {'corrected_local_public_summary': {'path': 'artifacts/results/stage8/recovery/stage8_recovery_local_attributions_public.csv',
#    'sha256': 'a06d244e3d5ea2b4ac53c66a102df58df5411743f1d60206bab9751845129dd5',
#    'size_bytes': 526735},
#   'corrected_local_reference_effects': {'path': 'artifacts/results/stage8/recovery/stage8_recovery_local_reference_effects.csv.gz',
#    'sha256': '77db6a7bcdbc670976ba7720a504e8e8250093fe066d74213fa8e82eb5cf5ca4',
#    'size_bytes': 1104854},
#   'corrected_permutation': {'path': 'artifacts/results/stage8/recovery/stage8_recovery_common_permutation_importance.csv',
#    'sha256': 'f020e8f9839b11db2def0813b025341e8d41915ac4d394e06ae0ae3601963b1e',
#    'size_bytes': 37429},
#   'global_summary': {'path': 'artifacts/results/stage8/recovery/stage8_recovery_global_explanation_summary.json',
#    'sha256': '17a8c5f6fb178c75b6fa1ced9fb19a7804f6a718bf3f5857dca2c1b4e48930b6',
#    'size_bytes': 8721},
# ...

# %% [markdown]
# ## 29. Independent Review and Verification
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
preparation=json.loads((REPORTS/'stage8_recovery_notebook_preparation.json').read_text(encoding='utf-8'))
invalidation=json.loads((RECOVERY_MANIFESTS/'stage8_initial_attempt_invalidation_manifest.json').read_text(encoding='utf-8'))
display(preparation)
display({'initial_attempt_status': invalidation['status'], 'invalidated_artifact_count': invalidation['entry_count'], 'final_independent_review_occurs_after_both_notebook_runs': True})
# Out:
# {'authorization_id': 'stage8_saved_decile_registry_recovery_20260716',
#  'complete_local_dispersion_validated': True,
#  'figures_validated': True,
#  'notebook_artifact_loading_only_required': True,
#  'registry_path_b_validated': True,
#  'reviewer_finalization_occurs_after_two_notebook_runs': True,
#  'scientific_artifacts_validated': True,
#  'stage9_started': False,
#  'status': 'PASS'}
# {'initial_attempt_status': 'invalidated_by_stage8_saved_decile_recovery',
#  'invalidated_artifact_count': 53,
#  'final_independent_review_occurs_after_both_notebook_runs': True}

# %% [markdown]
# ## 30. Stage 8 Completion Note
#
# This section loads compact saved evidence. It does not train, tune, select, recompute SHAP, or expose raw sensitive values.

# %%
summary=json.loads((RECOVERY_RESULTS/'stage8_recovery_global_explanation_summary.json').read_text(encoding='utf-8'))
coverage=json.loads((REPORTS/'stage8_recovery_local_coverage.json').read_text(encoding='utf-8'))
adjudication=json.loads((REPORTS/'stage8_registry_governance_adjudication.json').read_text(encoding='utf-8'))
display({'stage': 'Stage 8 Recovery', 'current_execution_gate': 'PASS_PENDING_FINAL_INDEPENDENT_REVIEW', 'registry_status': adjudication['status'], 'sample_hash': json.loads((REPORTS/'stage8_recovery_sample_freeze.json').read_text())['sample']['row_id_hash'], 'background_hash': json.loads((REPORTS/'stage8_recovery_sample_freeze.json').read_text())['background']['row_id_hash'], 'local_reference_rows': coverage['actual_cartesian_rows'], 'dispersion_complete': coverage['dispersion_complete'], 'model_fit_calls': summary['model_fit_calls'], 'preprocessing_fit_calls': summary['preprocessing_fit_calls'], 'global_shap_recomputations': summary['global_shap_recomputations'], 'new_evaluation_prediction_files': summary['new_evaluation_prediction_files'], 'stage4l_official': summary['stage4l_remains_official'], 'initial_invalid_attempt_disclosed': True, 'stage9_started': False})
# Out:
# {'stage': 'Stage 8 Recovery',
#  'current_execution_gate': 'PASS_PENDING_FINAL_INDEPENDENT_REVIEW',
#  'registry_status': 'PASS_WITH_DOCUMENTED_REGISTRY_GOVERNANCE_EXCEPTION',
#  'sample_hash': 'd7791b5e12cae7d6069419efdb1e4a9bc28c586cb1bc5ae2584d1b08c3a0358f',
#  'background_hash': '80a30da8f60aa3b5db6ec82847bfc0490359bc2412c3329ceb1f9915bfeb2efd',
#  'local_reference_rows': 64800,
#  'dispersion_complete': True,
#  'model_fit_calls': 0,
#  'preprocessing_fit_calls': 0,
#  'global_shap_recomputations': 0,
#  'new_evaluation_prediction_files': 0,
#  'stage4l_official': True,
#  'initial_invalid_attempt_disclosed': True,
#  'stage9_started': False}
