# %% [markdown]
# # Stage 4L — Final Model Integration and Locked Test Evaluation
#
# This independent Notebook reports the frozen one-time Test evaluation. It never fits or changes a model.

# %% [markdown]
# ## 0. Stage Objective
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
print({'objective': 'Report the frozen Stage 4L locked Test evaluation', 'model_fit_calls': 0, 'model_decisions_changed': False})
# Out:
# {'objective': 'Report the frozen Stage 4L locked Test evaluation', 'model_fit_calls': 0, 'model_decisions_changed': False}

# %% [markdown]
# ## 1. Imports and Configuration
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
from pathlib import Path
import json, os
import pandas as pd
from IPython.display import display, Image, Markdown
ROOT = Path.cwd()
CACHE_ONLY = os.environ.get('STAGE4L_CACHE_ONLY', '0') == '1'
def show_artifact(relative_path, rows=8):
    path = ROOT / relative_path
    if path.suffix.lower() == '.json':
        payload = json.loads(path.read_text(encoding='utf-8'))
        if isinstance(payload, dict) and 'candidates' in payload:
            columns = ['candidate_id', 'stage', 'model_family', 'sensitive_mode', 'target_mode', 'status']
            display(pd.DataFrame(payload['candidates'])[[value for value in columns if value in payload['candidates'][0]]])
        elif isinstance(payload, dict) and 'entries' in payload:
            display(pd.DataFrame(payload['entries'])[['figure_id', 'file_path', 'status']])
        elif isinstance(payload, dict):
            compact = {key: value for key, value in payload.items() if not isinstance(value, (dict, list))}
            if 'checks' in payload:
                compact['checks_passed'] = sum(bool(value) for value in payload['checks'].values())
                compact['checks_total'] = len(payload['checks'])
            display(pd.Series(compact, dtype='object').to_frame('value'))
        else:
            display(payload)
    else:
        display(pd.read_csv(path).head(rows))
print({'stage': 'stage4l', 'cache_only': CACHE_ONLY, 'model_fit_calls': 0})
# Out:
# {'stage': 'stage4l', 'cache_only': True, 'model_fit_calls': 0}

# %% [markdown]
# ## 2. Previous-Stage Verification
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/reports/stage4l_pretest_freeze.json')
# Out:
#                                                                              value
# candidate_count                                                                 14
# candidate_manifest_sha256        b9e2acf238c90d440347e665c9084178bc00e53672b6ae...
# decision_lock_statement          Candidate membership, primary model, blend wei...
# freeze_timestamp_utc                              2026-07-14T21:44:51.558337+00:00
# no_fit_rule                      Stage 4L is prediction-only and permits zero m...
# optional_blend_status                                                     ACCEPTED
# paired_sensitive_candidate                          stage4l__blend__with_sensitive
# primary_non_sensitive_candidate                  stage4l__blend__without_sensitive
# primary_selection_reason         The accepted non-sensitive blend had the lowes...
# protected_file_count                                                          1029
# ...

# %% [markdown]
# ## 3. Protected File Baseline
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/manifests/stage4/stage4l_protected_hashes_before.json')
# Out:
#                                                               value
# created_at_utc                     2026-07-14T21:44:44.143323+00:00
# file_count                                                     1029
# protected_digest  c3ed7af34870b226687e228c03c5e3a2e6ecc9b962aa64...
# stage                                                       stage4l
# status                                                         PASS

# %% [markdown]
# ## 4. Final Model Discovery
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/manifests/stage4/stage4l_candidate_manifest.json')
# Out:
#                                          candidate_id       stage  \
# 0                        stage4l__train_mean_baseline    Stage 4L
# 1                      stage4l__train_median_baseline    Stage 4L
# 2                   stage4l__lasso__without_sensitive     Stage 2
# 3                      stage4l__lasso__with_sensitive     Stage 2
# 4   stage4l__hist_gradient_boosting__without_sensi...     Stage 3
# 5     stage4l__hist_gradient_boosting__with_sensitive     Stage 3
# 6                stage4l__catboost__without_sensitive  Stage 4D-E
# 7                   stage4l__catboost__with_sensitive  Stage 4D-E
# 8                stage4l__lightgbm__without_sensitive    Stage 4H
# 9                   stage4l__lightgbm__with_sensitive    Stage 4H
# 10                stage4l__xgboost__without_sensitive    Stage 4K
# 11                   stage4l__xgboost__with_sensitive    Stage 4K
# 12                  stage4l__blend__without_sensitive    Stage 4L
# ...

# %% [markdown]
# ## 5. Candidate Manifest
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/manifests/stage4/stage4l_candidate_manifest.json')
# Out:
#                                          candidate_id       stage  \
# 0                        stage4l__train_mean_baseline    Stage 4L
# 1                      stage4l__train_median_baseline    Stage 4L
# 2                   stage4l__lasso__without_sensitive     Stage 2
# 3                      stage4l__lasso__with_sensitive     Stage 2
# 4   stage4l__hist_gradient_boosting__without_sensi...     Stage 3
# 5     stage4l__hist_gradient_boosting__with_sensitive     Stage 3
# 6                stage4l__catboost__without_sensitive  Stage 4D-E
# 7                   stage4l__catboost__with_sensitive  Stage 4D-E
# 8                stage4l__lightgbm__without_sensitive    Stage 4H
# 9                   stage4l__lightgbm__with_sensitive    Stage 4H
# 10                stage4l__xgboost__without_sensitive    Stage 4K
# 11                   stage4l__xgboost__with_sensitive    Stage 4K
# 12                  stage4l__blend__without_sensitive    Stage 4L
# ...

# %% [markdown]
# ## 6. Pre-Test Model Evidence
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/reports/stage4l_blend_validation_evidence.json')
# Out:
#                                                                                 value
# accepted                                                                         True
# best_individual                                                              catboost
# grid_combination_count                                                             66
# search_design                       equal weights plus 66 non-negative step-0.1 co...
# status                                                                           PASS
# top_decile_mae_change_percent                                                0.112786
# validation_mae_improvement_percent                                           0.387034

# %% [markdown]
# ## 7. Optional Validation-Frozen Blend
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/reports/stage4l_blend_validation_evidence.json')
# Out:
#                                                                                 value
# accepted                                                                         True
# best_individual                                                              catboost
# grid_combination_count                                                             66
# search_design                       equal weights plus 66 non-negative step-0.1 co...
# status                                                                           PASS
# top_decile_mae_change_percent                                                0.112786
# validation_mae_improvement_percent                                           0.387034

# %% [markdown]
# ## 8. Pre-Test Primary Model
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/reports/stage4l_pretest_freeze.json')
# Out:
#                                                                              value
# candidate_count                                                                 14
# candidate_manifest_sha256        b9e2acf238c90d440347e665c9084178bc00e53672b6ae...
# decision_lock_statement          Candidate membership, primary model, blend wei...
# freeze_timestamp_utc                              2026-07-14T21:44:51.558337+00:00
# no_fit_rule                      Stage 4L is prediction-only and permits zero m...
# optional_blend_status                                                     ACCEPTED
# paired_sensitive_candidate                          stage4l__blend__with_sensitive
# primary_non_sensitive_candidate                  stage4l__blend__without_sensitive
# primary_selection_reason         The accepted non-sensitive blend had the lowes...
# protected_file_count                                                          1029
# ...

# %% [markdown]
# ## 9. Pre-Test Freeze Manifest
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/reports/stage4l_pretest_freeze.json')
# Out:
#                                                                              value
# candidate_count                                                                 14
# candidate_manifest_sha256        b9e2acf238c90d440347e665c9084178bc00e53672b6ae...
# decision_lock_statement          Candidate membership, primary model, blend wei...
# freeze_timestamp_utc                              2026-07-14T21:44:51.558337+00:00
# no_fit_rule                      Stage 4L is prediction-only and permits zero m...
# optional_blend_status                                                     ACCEPTED
# paired_sensitive_candidate                          stage4l__blend__with_sensitive
# primary_non_sensitive_candidate                  stage4l__blend__without_sensitive
# primary_selection_reason         The accepted non-sensitive blend had the lowes...
# protected_file_count                                                          1029
# ...

# %% [markdown]
# ## 10. Locked Test Opening
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/reports/stage4l_test_unlock_audit.json')
# Out:
#                                                                                     value
# candidate_count                                                                        14
# common_feature_equality_across_sources                                               True
# fit_operations_allowed                                                              False
# freeze_manifest_sha256                  6c4aece5c82077be1932060f935fb4ce70213ded591ccd...
# permanent_statement                     The Test Set has been consumed. No later model...
# stage                                                                             stage4l
# status                                                                               PASS
# target_equality_across_sources                                                       True
# target_finite                                                                        True
# ...

# %% [markdown]
# ## 11. Test Data Integrity
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/reports/stage4l_test_unlock_audit.json')
# Out:
#                                                                                     value
# candidate_count                                                                        14
# common_feature_equality_across_sources                                               True
# fit_operations_allowed                                                              False
# freeze_manifest_sha256                  6c4aece5c82077be1932060f935fb4ce70213ded591ccd...
# permanent_statement                     The Test Set has been consumed. No later model...
# stage                                                                             stage4l
# status                                                                               PASS
# target_equality_across_sources                                                       True
# target_finite                                                                        True
# ...

# %% [markdown]
# ## 12. Train Mean and Median Baselines
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/manifests/stage4/stage4l_candidate_manifest.json')
# Out:
#                                          candidate_id       stage  \
# 0                        stage4l__train_mean_baseline    Stage 4L
# 1                      stage4l__train_median_baseline    Stage 4L
# 2                   stage4l__lasso__without_sensitive     Stage 2
# 3                      stage4l__lasso__with_sensitive     Stage 2
# 4   stage4l__hist_gradient_boosting__without_sensi...     Stage 3
# 5     stage4l__hist_gradient_boosting__with_sensitive     Stage 3
# 6                stage4l__catboost__without_sensitive  Stage 4D-E
# 7                   stage4l__catboost__with_sensitive  Stage 4D-E
# 8                stage4l__lightgbm__without_sensitive    Stage 4H
# 9                   stage4l__lightgbm__with_sensitive    Stage 4H
# 10                stage4l__xgboost__without_sensitive    Stage 4K
# 11                   stage4l__xgboost__with_sensitive    Stage 4K
# 12                  stage4l__blend__without_sensitive    Stage 4L
# ...

# %% [markdown]
# ## 13. Saved Model Reload Validation
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/manifests/stage4/stage4l_candidate_manifest.json')
# Out:
#                                          candidate_id       stage  \
# 0                        stage4l__train_mean_baseline    Stage 4L
# 1                      stage4l__train_median_baseline    Stage 4L
# 2                   stage4l__lasso__without_sensitive     Stage 2
# 3                      stage4l__lasso__with_sensitive     Stage 2
# 4   stage4l__hist_gradient_boosting__without_sensi...     Stage 3
# 5     stage4l__hist_gradient_boosting__with_sensitive     Stage 3
# 6                stage4l__catboost__without_sensitive  Stage 4D-E
# 7                   stage4l__catboost__with_sensitive  Stage 4D-E
# 8                stage4l__lightgbm__without_sensitive    Stage 4H
# 9                   stage4l__lightgbm__with_sensitive    Stage 4H
# 10                stage4l__xgboost__without_sensitive    Stage 4K
# 11                   stage4l__xgboost__with_sensitive    Stage 4K
# 12                  stage4l__blend__without_sensitive    Stage 4L
# ...

# %% [markdown]
# ## 14. Test Prediction Generation
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/reports/stage4l_prediction_generation.json')
# Out:
#                                                                       value
# candidate_count                                                          14
# fit_call_count                                                            0
# freeze_manifest_sha256    6c4aece5c82077be1932060f935fb4ce70213ded591ccd...
# model_load_seconds                                                 2.751388
# prediction_seconds                                                24.851573
# saved_model_worker_count                                                 10
# stage                                                               stage4l
# status                                                                 PASS
# unlock_timestamp_utc                       2026-07-14T21:46:59.238934+00:00
# wall_seconds                                                      78.322576

# %% [markdown]
# ## 15. Prediction Artifact Validation
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/reports/stage4l_prediction_validation.csv')
# Out:
#    candidate_id  row_count  unique_row_ids  exact_row_order  \
# 0          True       True            True             True
# 1          True       True            True             True
# 2          True       True            True             True
# 3          True       True            True             True
# 4          True       True            True             True
# 5          True       True            True             True
# 6          True       True            True             True
# 7          True       True            True             True
#
#    zero_train_overlap  finite_prediction  finite_target  model_hash  \
# 0                True               True           True        True
# 1                True               True           True        True
# 2                True               True           True        True
# 3                True               True           True        True
# 4                True               True           True        True
# ...

# %% [markdown]
# ## 16. Common Test Metrics
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/results/stage4/final_integration/stage4l_test_leaderboard.csv')
# Out:
#    rank                                     candidate_id       stage  \
# 0     1                   stage4l__blend__with_sensitive    Stage 4L
# 1     2                stage4l__catboost__with_sensitive  Stage 4D-E
# 2     3                stage4l__blend__without_sensitive    Stage 4L
# 3     4             stage4l__catboost__without_sensitive  Stage 4D-E
# 4     5                stage4l__lightgbm__with_sensitive    Stage 4H
# 5     6             stage4l__lightgbm__without_sensitive    Stage 4H
# 6     7                 stage4l__xgboost__with_sensitive    Stage 4K
# 7     8  stage4l__hist_gradient_boosting__with_sensitive     Stage 3
#
#                        model_family     sensitive_mode  \
# 0  validation_frozen_boosting_blend     with_sensitive
# 1                          catboost     with_sensitive
# 2  validation_frozen_boosting_blend  without_sensitive
# 3                          catboost  without_sensitive
# 4                          lightgbm     with_sensitive
# ...

# %% [markdown]
# ## 17. Final Test Leaderboard
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/results/stage4/final_integration/stage4l_test_leaderboard.csv')
# Out:
#    rank                                     candidate_id       stage  \
# 0     1                   stage4l__blend__with_sensitive    Stage 4L
# 1     2                stage4l__catboost__with_sensitive  Stage 4D-E
# 2     3                stage4l__blend__without_sensitive    Stage 4L
# 3     4             stage4l__catboost__without_sensitive  Stage 4D-E
# 4     5                stage4l__lightgbm__with_sensitive    Stage 4H
# 5     6             stage4l__lightgbm__without_sensitive    Stage 4H
# 6     7                 stage4l__xgboost__with_sensitive    Stage 4K
# 7     8  stage4l__hist_gradient_boosting__with_sensitive     Stage 3
#
#                        model_family     sensitive_mode  \
# 0  validation_frozen_boosting_blend     with_sensitive
# 1                          catboost     with_sensitive
# 2  validation_frozen_boosting_blend  without_sensitive
# 3                          catboost  without_sensitive
# 4                          lightgbm     with_sensitive
# ...

# %% [markdown]
# ## 18. Bootstrap Confidence Intervals
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/results/stage4/final_integration/stage4l_bootstrap_confidence_intervals.csv')
# Out:
#                                       candidate_id  bootstrap_resamples  \
# 0                   stage4l__blend__with_sensitive                  500
# 1                stage4l__catboost__with_sensitive                  500
# 2                stage4l__blend__without_sensitive                  500
# 3             stage4l__catboost__without_sensitive                  500
# 4                stage4l__lightgbm__with_sensitive                  500
# 5             stage4l__lightgbm__without_sensitive                  500
# 6                 stage4l__xgboost__with_sensitive                  500
# 7  stage4l__hist_gradient_boosting__with_sensitive                  500
#
#    random_seed        mae  mae_ci_low  mae_ci_high        rmse  rmse_ci_low  \
# 0           42  61.281367   60.640309    61.920577  125.516343   118.669023
# 1           42  61.397646   60.752708    62.050256  125.840653   119.220008
# 2           42  61.511631   60.867002    62.143362  125.788460   118.908567
# ...

# %% [markdown]
# ## 19. Paired Model Differences
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/results/stage4/final_integration/stage4l_paired_model_differences.csv')
# Out:
#                 primary_candidate_id  \
# 0  stage4l__blend__without_sensitive
# 1  stage4l__blend__without_sensitive
# 2  stage4l__blend__without_sensitive
# 3  stage4l__blend__without_sensitive
#
#                              challenger_candidate_id  \
# 0               stage4l__catboost__without_sensitive
# 1               stage4l__lightgbm__without_sensitive
# 2                stage4l__xgboost__without_sensitive
# 3  stage4l__hist_gradient_boosting__without_sensi...
#
#       difference_definition  mae_difference  mae_difference_ci_low  \
# 0  challenger_minus_primary        0.052746              -0.007469
# 1  challenger_minus_primary        1.101557               0.990966
# 2  challenger_minus_primary        1.634171               1.471424
# 3  challenger_minus_primary        1.713733               1.587901
#
#    mae_difference_ci_high  rmse_difference  rmse_difference_ci_low  \
# 0                0.113960         0.067459               -0.426453
# ...

# %% [markdown]
# ## 20. Sensitive Versus Non-Sensitive Comparison
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/results/stage4/final_integration/stage4l_sensitive_comparison.csv')
# Out:
#              model_family                     without_sensitive_candidate_id  \
# 0                   lasso                  stage4l__lasso__without_sensitive
# 1  hist_gradient_boosting  stage4l__hist_gradient_boosting__without_sensi...
# 2                catboost               stage4l__catboost__without_sensitive
# 3                lightgbm               stage4l__lightgbm__without_sensitive
# 4                 xgboost                stage4l__xgboost__without_sensitive
# 5                   blend                  stage4l__blend__without_sensitive
#
#                        with_sensitive_candidate_id  mae_without_sensitive  \
# 0                   stage4l__lasso__with_sensitive              71.808684
# 1  stage4l__hist_gradient_boosting__with_sensitive              63.225365
# 2                stage4l__catboost__with_sensitive              61.564378
# 3                stage4l__lightgbm__with_sensitive              62.613189
# ...

# %% [markdown]
# ## 21. Error by Target Decile
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/results/stage4/final_integration/stage4l_error_by_decile.csv')
# Out:
#                         candidate_id  target_decile  row_count        mae  \
# 0  stage4l__blend__without_sensitive              1      10221  26.882273
# 1  stage4l__blend__without_sensitive              2       9892  41.904705
# 2  stage4l__blend__without_sensitive              3       9951  36.781228
# 3  stage4l__blend__without_sensitive              4      10095  37.374846
# 4  stage4l__blend__without_sensitive              5       9892  38.009654
# 5  stage4l__blend__without_sensitive              6       9936  44.971094
# 6  stage4l__blend__without_sensitive              7      10012  49.709994
# 7  stage4l__blend__without_sensitive              8      10084  61.548825
#
#         rmse  mean_signed_error
# 0  46.990603          22.073110
# 1  61.628817          33.634989
# 2  54.764106          23.703652
# 3  56.332616          17.334614
# 4  56.548760           7.533381
# 5  64.876093           3.909475
# 6  69.378948          -8.602889
# 7  82.447553         -19.726540

# %% [markdown]
# ## 22. Tail and Worst-Error Analysis
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/results/stage4/final_integration/stage4l_tail_metrics.csv')
# Out:
#                         candidate_id  top_decile_mae  top_five_percent_mae  \
# 0  stage4l__blend__without_sensitive      195.498099            287.063969
# 1     stage4l__blend__with_sensitive      194.733053            285.763856
#
#    underestimation_rate  overestimation_rate  mean_signed_error
# 0              0.509035             0.490965          -9.554174
# 1              0.510155             0.489845          -9.615048

# %% [markdown]
# ## 23. Accuracy, Runtime, and Model Size
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/results/stage4/final_integration/stage4l_model_efficiency.csv')
# Out:
#                                       candidate_id  \
# 0                   stage4l__blend__with_sensitive
# 1                stage4l__catboost__with_sensitive
# 2                stage4l__blend__without_sensitive
# 3             stage4l__catboost__without_sensitive
# 4                stage4l__lightgbm__with_sensitive
# 5             stage4l__lightgbm__without_sensitive
# 6                 stage4l__xgboost__with_sensitive
# 7  stage4l__hist_gradient_boosting__with_sensitive
#
#                        model_family     sensitive_mode        mae  \
# 0  validation_frozen_boosting_blend     with_sensitive  61.281367
# 1                          catboost     with_sensitive  61.397646
# 2  validation_frozen_boosting_blend  without_sensitive  61.511631
# 3                          catboost  without_sensitive  61.564378
# 4                          lightgbm     with_sensitive  62.351251
# 5                          lightgbm  without_sensitive  62.613189
# ...

# %% [markdown]
# ## 24. Test Leaderboard Visualization
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact. A chart is descriptive and does not change the frozen model decision.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
display(Image(filename=str(ROOT / 'artifacts/figures/stage4l/stage4l_test_mae_leaderboard.png')))
print({'figure_files_displayed': True, 'decision_changed': False})
# Out:
# {'figure_files_displayed': True, 'decision_changed': False}

# %% [markdown]
# ## 25. Confidence-Interval Visualization
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact. A chart is descriptive and does not change the frozen model decision.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
display(Image(filename=str(ROOT / 'artifacts/figures/stage4l/stage4l_mae_confidence_intervals.png')))
print({'figure_files_displayed': True, 'decision_changed': False})
# Out:
# {'figure_files_displayed': True, 'decision_changed': False}

# %% [markdown]
# ## 26. Multi-Metric Model Visualization
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact. A chart is descriptive and does not change the frozen model decision.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
display(Image(filename=str(ROOT / 'artifacts/figures/stage4l/stage4l_multi_metric_comparison.png')))
print({'figure_files_displayed': True, 'decision_changed': False})
# Out:
# {'figure_files_displayed': True, 'decision_changed': False}

# %% [markdown]
# ## 27. Validation Versus Test Visualization
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact. A chart is descriptive and does not change the frozen model decision.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
display(Image(filename=str(ROOT / 'artifacts/figures/stage4l/stage4l_validation_vs_test_mae.png')))
print({'figure_files_displayed': True, 'decision_changed': False})
# Out:
# {'figure_files_displayed': True, 'decision_changed': False}

# %% [markdown]
# ## 28. Sensitive-Mode Visualization
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact. A chart is descriptive and does not change the frozen model decision.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
display(Image(filename=str(ROOT / 'artifacts/figures/stage4l/stage4l_sensitive_mae_comparison.png')))
print({'figure_files_displayed': True, 'decision_changed': False})
# Out:
# {'figure_files_displayed': True, 'decision_changed': False}

# %% [markdown]
# ## 29. Actual Versus Predicted Visualization
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact. A chart is descriptive and does not change the frozen model decision.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
display(Image(filename=str(ROOT / 'artifacts/figures/stage4l/stage4l_primary_actual_vs_predicted.png')))
display(Image(filename=str(ROOT / 'artifacts/figures/stage4l/stage4l_best_observed_actual_vs_predicted.png')))
print({'figure_files_displayed': True, 'decision_changed': False})
# Out:
# {'figure_files_displayed': True, 'decision_changed': False}

# %% [markdown]
# ## 30. Residual Visualizations
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact. A chart is descriptive and does not change the frozen model decision.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
display(Image(filename=str(ROOT / 'artifacts/figures/stage4l/stage4l_primary_residual_vs_predicted.png')))
display(Image(filename=str(ROOT / 'artifacts/figures/stage4l/stage4l_primary_residual_distribution.png')))
print({'figure_files_displayed': True, 'decision_changed': False})
# Out:
# {'figure_files_displayed': True, 'decision_changed': False}

# %% [markdown]
# ## 31. Error-by-Decile Visualization
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact. A chart is descriptive and does not change the frozen model decision.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
display(Image(filename=str(ROOT / 'artifacts/figures/stage4l/stage4l_error_by_target_decile.png')))
print({'figure_files_displayed': True, 'decision_changed': False})
# Out:
# {'figure_files_displayed': True, 'decision_changed': False}

# %% [markdown]
# ## 32. Model-Efficiency Visualization
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact. A chart is descriptive and does not change the frozen model decision.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
display(Image(filename=str(ROOT / 'artifacts/figures/stage4l/stage4l_model_efficiency.png')))
print({'figure_files_displayed': True, 'decision_changed': False})
# Out:
# {'figure_files_displayed': True, 'decision_changed': False}

# %% [markdown]
# ## 33. Paired-Difference Visualization
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact. A chart is descriptive and does not change the frozen model decision.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
display(Image(filename=str(ROOT / 'artifacts/figures/stage4l/stage4l_paired_mae_differences.png')))
print({'figure_files_displayed': True, 'decision_changed': False})
# Out:
# {'figure_files_displayed': True, 'decision_changed': False}

# %% [markdown]
# ## 34. Optional Blend Visualization
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact. A chart is descriptive and does not change the frozen model decision.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
display(Image(filename=str(ROOT / 'artifacts/figures/stage4l/stage4l_blend_weights.png')))
display(Image(filename=str(ROOT / 'artifacts/figures/stage4l/stage4l_blend_performance.png')))
print({'figure_files_displayed': True, 'decision_changed': False})
# Out:
# {'figure_files_displayed': True, 'decision_changed': False}

# %% [markdown]
# ## 35. Pre-Test Primary Evaluation
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/results/stage4/final_integration/stage4l_final_recommendation.json')
# Out:
#                                                                              value
# best_observed_mae                                                        61.281367
# best_observed_minus_primary_mae                                          -0.230265
# best_observed_test_candidate                        stage4l__blend__with_sensitive
# created_at_utc                                    2026-07-14T21:56:06.559451+00:00
# interpretability_level           Low to medium: a fixed weighted average of thr...
# model_size_bytes                                                          92680671
# no_retuning_statement            No model, Feature, target mode, parameter, Can...
# operational_recommendation       Keep the frozen non-sensitive blend as the pri...
# optional_blend_status                                         ACCEPTED before Test
# prediction_time_seconds                                                  10.065198
# ...

# %% [markdown]
# ## 36. Best Observed Test Candidate
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/results/stage4/final_integration/stage4l_final_recommendation.json')
# Out:
#                                                                              value
# best_observed_mae                                                        61.281367
# best_observed_minus_primary_mae                                          -0.230265
# best_observed_test_candidate                        stage4l__blend__with_sensitive
# created_at_utc                                    2026-07-14T21:56:06.559451+00:00
# interpretability_level           Low to medium: a fixed weighted average of thr...
# model_size_bytes                                                          92680671
# no_retuning_statement            No model, Feature, target mode, parameter, Can...
# operational_recommendation       Keep the frozen non-sensitive blend as the pri...
# optional_blend_status                                         ACCEPTED before Test
# prediction_time_seconds                                                  10.065198
# ...

# %% [markdown]
# ## 37. Final Recommendation
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/results/stage4/final_integration/stage4l_final_recommendation.json')
# Out:
#                                                                              value
# best_observed_mae                                                        61.281367
# best_observed_minus_primary_mae                                          -0.230265
# best_observed_test_candidate                        stage4l__blend__with_sensitive
# created_at_utc                                    2026-07-14T21:56:06.559451+00:00
# interpretability_level           Low to medium: a fixed weighted average of thr...
# model_size_bytes                                                          92680671
# no_retuning_statement            No model, Feature, target mode, parameter, Can...
# operational_recommendation       Keep the frozen non-sensitive blend as the pri...
# optional_blend_status                                         ACCEPTED before Test
# prediction_time_seconds                                                  10.065198
# ...

# %% [markdown]
# ## 38. Stage 4L Artifact Summary
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
paths = sorted(str(path.relative_to(ROOT)) for base in [ROOT/'artifacts/predictions/final_test', ROOT/'artifacts/results/stage4/final_integration', ROOT/'artifacts/figures/stage4l'] for path in base.glob('*') if path.is_file())
display(pd.DataFrame({'artifact_path': paths}))
print({'artifact_count': len(paths)})
# Out:
#                                         artifact_path
# 0   artifacts\figures\stage4l\stage4l_best_observe...
# 1   artifacts\figures\stage4l\stage4l_best_observe...
# 2   artifacts\figures\stage4l\stage4l_blend_perfor...
# 3   artifacts\figures\stage4l\stage4l_blend_perfor...
# 4   artifacts\figures\stage4l\stage4l_blend_weight...
# ..                                                ...
# 63  artifacts\results\stage4\final_integration\sta...
# 64  artifacts\results\stage4\final_integration\sta...
# 65  artifacts\results\stage4\final_integration\sta...
# 66  artifacts\results\stage4\final_integration\sta...
# 67  artifacts\results\stage4\final_integration\sta...
#
# [68 rows x 1 columns]
# {'artifact_count': 68}

# %% [markdown]
# ## 39. Visualization Manifest
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
show_artifact('artifacts/manifests/stage4/stage4l_visualization_manifest.json')
# Out:
#                                          figure_id  \
# 0                stage4l_test_mae_leaderboard__png
# 1                stage4l_test_mae_leaderboard__svg
# 2            stage4l_mae_confidence_intervals__png
# 3            stage4l_mae_confidence_intervals__svg
# 4             stage4l_multi_metric_comparison__png
# 5             stage4l_multi_metric_comparison__svg
# 6              stage4l_validation_vs_test_mae__png
# 7              stage4l_validation_vs_test_mae__svg
# 8            stage4l_sensitive_mae_comparison__png
# 9            stage4l_sensitive_mae_comparison__svg
# 10        stage4l_primary_actual_vs_predicted__png
# 11        stage4l_primary_actual_vs_predicted__svg
# 12  stage4l_best_observed_actual_vs_predicted__png
# 13  stage4l_best_observed_actual_vs_predicted__svg
# 14      stage4l_primary_residual_vs_predicted__png
# 15      stage4l_primary_residual_vs_predicted__svg
# 16      stage4l_primary_residual_distribution__png
# ...

# %% [markdown]
# ## 40. Stage 4L Verification
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
final_path = ROOT / 'artifacts/reports/stage4l_verification.json'
path = final_path if final_path.exists() else ROOT / 'artifacts/reports/stage4l_notebook_readiness.json'
show_artifact(str(path.relative_to(ROOT)))
# Out:
#                                                             value
# created_at_utc                   2026-07-14T21:58:49.965708+00:00
# note            All implementation artifacts pass. Independent...
# stage                                                     stage4l
# status                                                       PASS
# checks_passed                                                   8
# checks_total                                                    8

# %% [markdown]
# ## 41. Stage 4L Completion Note
#
# This section checks saved Stage 4L evidence so the result is reproducible. The output comes from a validated artifact.
#
# **Conclusion:** The saved evidence is used as the source of truth.

# %%
unlock = json.loads((ROOT/'artifacts/reports/stage4l_test_unlock_audit.json').read_text(encoding='utf-8'))
print(unlock['permanent_statement'])
print({'stage4l_artifacts_complete': True, 'model_fit_calls': 0, 'stage5_started': False})
# Out:
# The Test Set has been consumed. No later model or Feature decision may use its results. A new independent holdout would be required for another unbiased final evaluation.
# {'stage4l_artifacts_complete': True, 'model_fit_calls': 0, 'stage5_started': False}
